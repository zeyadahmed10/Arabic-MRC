# %%
import os
import shutil
from collections import Counter
import numpy as np
import json
import torch
import torch.nn as nn
import torch.nn.functional as F
from transformers import AutoTokenizer, ElectraForQuestionAnswering, DataCollatorWithPadding,BertModel, ElectraForSequenceClassification, ElectraModel
from Preprocess.arabertpreprocess import ArabertPreprocessor
import matplotlib.pyplot as plt
import seaborn as sns
import csv
torch.manual_seed(3407)

# %% [markdown]
# ## Preprocessing

# %%
def add_end_index(answer, context):
  ## 1 if span match the context 0 otherwise
  text = answer['text']
  start_idx = answer['answer_start']
  end_idx = start_idx + len(text)
  answer['answer_end'] = end_idx
  if text == context[start_idx:end_idx]:
    answer['answer_end'] = end_idx
    return False
  for i in range(1,3):
    if text == context[start_idx-i:end_idx-i]:
      answer['answer_end']= end_idx-1
      answer['answer_start'] = start_idx-1
      return False
  return True

# %%
def arabert_preprocess(context,question, answer, arabert_prep):
    answer['text'] = arabert_prep.preprocess(answer['text'])
    context = arabert_prep.preprocess(context)
    question = arabert_prep.preprocess(question)
    res = context.find(answer['text'])
    if res !=-1:
        answer['answer_start'] = res
    return context, question, answer, res

# %%
def Read_AAQAD(path,arabert_prep):
  contexts =[]
  answers =[]
  questions =[]
  IDs= []
  plausible = []
  with open(path) as f:
    aaqad_dict = json.load(f)
    for article in aaqad_dict['data']:
      for passage in article['paragraphs']:
        context = passage['context']
        for qa in passage['qas']:
          question = qa['question']
          if 'plausible_answers' in qa.keys():# there is two cases if the question have no answer then use plausible answer
            access = 'plausible_answers'
            plausible.append(True)
          else:
            access = 'answers'
            plausible.append(False)
          for answer in qa[access]:
            contexts.append(context)
            answers.append(answer)
            questions.append(question)
            IDs.append(int(qa['id']))
  return contexts,questions,answers,plausible,IDs

# %%
def fix_ids_span(path):
  #IDs need to be fixed for evaluating purposes
    a_file = open(path, "r")
    json_object = json.load(a_file)
    a_file.close()
    newIDCnt = 0
    for article in json_object['data']:
      for passage in article['paragraphs']:
        context = passage['context']
        for qa in passage['qas']:
            qa['id'] = str(newIDCnt)
            newIDCnt = newIDCnt +1
            if 'plausible_answers' in qa.keys():
              qa['plausible_answers'][0]['answer_start'] = 0
    a_file = open(path, "w")
    json.dump(json_object, a_file)
    a_file.close()

# %%
model_name = "araelectra-base-discriminator"
arabert_prep = ArabertPreprocessor(model_name=model_name)
fix_ids_span('Data/asquadv2-train.json')
fix_ids_span('Data/asquadv2-val.json')
fix_ids_span('Data/asquadv2-test.json')
aqad_train_contexts, aqad_train_questions, aqad_train_answers,aqad_train_plausible, aqad_train_ids = Read_AAQAD('Data/asquadv2-train.json', arabert_prep)
aqad_val_contexts, aqad_val_questions, aqad_val_answers,aqad_val_plausible, aqad_val_ids = Read_AAQAD('Data/asquadv2-val.json', arabert_prep)
aqad_test_contexts, aqad_test_questions, aqad_test_answers,aqad_test_plausible, aqad_test_ids = Read_AAQAD('Data/asquadv2-test.json', arabert_prep)

# %%
for i in range(len(aqad_train_contexts)):
    if aqad_train_answers[i]['answer_start']==-2:
        print(True, aqad_train_plausible[i])
    else:
        print(False,aqad_train_plausible[i])
# Out:
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# True False
# False True
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# False True
# False True
# False True
# False True
# False True
# True False
# False True
# True False
# False True
# False True
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# False True
# False True
# False True
# True False
# True False
# False True
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# False True
# True False
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# False True
# False True
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# ...
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# False True
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# False True
# True False
# False True
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# True False
# True False
# True False
# False True
# False True
# True False
# True False
# True False
# False True
# False True

# %%
def get_answered_feat(contexts, questions, answers, plausible):
    new_contexts, new_questions, new_answers = [], [], []
    for i in range(len(answers)):
        if plausible[i] == False:
            new_contexts.append(contexts[i])
            new_questions.append(questions[i])
            new_answers.append(answers[i])
    return new_contexts, new_questions, new_answers
span_train_contexts, span_train_questions, span_train_answers = get_answered_feat(aqad_train_contexts, aqad_train_questions, aqad_train_answers, aqad_train_plausible)

# %%
print(len(span_train_contexts), len(span_train_questions))
# Out:
# 34798 34798

# %% [markdown]
# ## Tokenization

# %%
#Creating the tokenizer
model_name = model_name = "aubmindlab/araelectra-base-discriminator"
araelectra_tokenizer = AutoTokenizer.from_pretrained(model_name,do_lower_case=False)

# %%
train_encodings = araelectra_tokenizer(aqad_train_questions, aqad_train_contexts, truncation=True)
span_train_encodings = araelectra_tokenizer(span_train_questions, span_train_contexts, truncation=True)
val_encodings = araelectra_tokenizer(aqad_val_questions, aqad_val_contexts, truncation=True)
test_encodings = araelectra_tokenizer(aqad_test_questions, aqad_test_contexts,truncation= True)

# %%
def index_to_token_position(encodings , answers):
  start_positions = list()
  end_positions = list()
  for i in range(len(answers)):
    start_positions.append(encodings.char_to_token(i, answers[i]['answer_start'], 1))
    end_positions.append(encodings.char_to_token(i, answers[i]['answer_end'], 1))
    #if context truncated
    if start_positions[-1] is None: 
      start_positions[-1] = araelectra_tokenizer.model_max_length
    #if end index is space
    itt = 1
    while end_positions[-1] is None: 
      end_positions[-1] = encodings.char_to_token(i, answers[i]['answer_end']-itt, 1)
      itt = itt + 1 
  encodings.update({'start_positions': torch.tensor(start_positions), 'end_positions': torch.tensor(end_positions)})
  encodings['start_positions'] = encodings['start_positions'].view(len(answers), 1)
  encodings['end_positions'] = encodings['end_positions'].view(len(answers), 1)

# %%
for i in range(len(span_train_answers)):
    print(span_train_answers[i])
# Out:
# {'text': 'إسبانيا', 'answer_start': -2}
# {'text': 'الحكومة الماركسية اللينينية', 'answer_start': -2}
# {'text': 'كوبا', 'answer_start': -2}
# {'text': '1959', 'answer_start': -2}
# {'text': 'العقود القانونية والزيجات والأحكام الجنائية', 'answer_start': -2}
# {'text': 'العلاقة بين الدول', 'answer_start': -2}
# {'text': 'الدفاع العسكري والمدني', 'answer_start': -2}
# {'text': 'القدرة على قبول دول جديدة في الاتحاد', 'answer_start': -2}
# {'text': 'البند الإقليمي من الدستور الأمريكي', 'answer_start': -2}
# {'text': 'قانون بورتوريكو للديمقراطية ( H . R . 2499 )', 'answer_start': -2}
# {'text': 'كومنولث بويرتو', 'answer_start': -2}
# {'text': 'ألفريد دي غراتسيا', 'answer_start': -2}
# {'text': 'التمويل السنوي والدعم الدفاعي الذي تتلقاه من الولايات المتحدة', 'answer_start': -2}
# {'text': '2003', 'answer_start': -2}
# {'text': 'نجمتان من أجل السلام', 'answer_start': -2}
# {'text': 'التدخل الأمريكي الإيجابي في الحرب العالمية الأولى', 'answer_start': -2}
# {'text': 'جيمس بافيت', 'answer_start': -2}
# {'text': 'الحرب الباردة', 'answer_start': -2}
# {'text': 'مؤيد بشدة للولايات المتحدة', 'answer_start': -2}
# {'text': 'قوة كبيرة', 'answer_start': -2}
# {'text': '1951', 'answer_start': -2}
# {'text': '1952', 'answer_start': -2}
# {'text': 'وجه الكونغرس الأمريكي الحكومة المحلية لتنظيم مؤتمر دستوري', 'answer_start': -2}
# {'text': 'بند الامتيازات والحصانات', 'answer_start': -2}
# {'text': 'عندما وجه الكونغرس الأمريكي الحكومة المحلية لتنظيم مؤتمر دستوري', 'answer_start': -2}
# {'text': 'إنهاء الشكل الحالي للوضع الإقليمي والبدء في عملية قبول بورتوريكو في الاتحاد كدولة', 'answer_start': -2}
# {'text': '54 %', 'answer_start': -2}
# {'text': '61 %', 'answer_start': -2}
# {'text': 'بويرتوريكو', 'answer_start': -2}
# {'text': 'ديسمبر 11 , 2012', 'answer_start': -2}
# {'text': 'العديد من السياسيين وغيرهم', 'answer_start': -2}
# {'text': 'جامعة أكوريري', 'answer_start': -2}
# {'text': '100 مليون دولار', 'answer_start': -2}
# {'text': 'الليبراليين', 'answer_start': -2}
# {'text': 'الليبراليين', 'answer_start': -2}
# {'text': '" هنا نرسم الخط . "', 'answer_start': -2}
# {'text': 'في الانتخابات الفيدرالية لعام 1988', 'answer_start': -2}
# {'text': 'جيمس ماديسون', 'answer_start': -2}
# {'text': 'الدستور لا يحدد حدا أدنى للحجم', 'answer_start': -2}
# {'text': 'الاتحادية رقم 43', 'answer_start': -2}
# {'text': 'الكونجرس', 'answer_start': -2}
# {'text': 'استعادت فرجينيا الجزء من المقاطعة جنوب بوتوماك', 'answer_start': -2}
# {'text': 'إيدي راما', 'answer_start': -2}
# {'text': 'إيدي راما', 'answer_start': -2}
# {'text': '1992', 'answer_start': -2}
# {'text': 'كامب بوندستيل', 'answer_start': -2}
# {'text': 'في مايو 15 , 2013', 'answer_start': -2}
# {'text': 'استفتاء ملزم يعقد في بورتوريكو يسأل عما إذا كان الإقليم يريد أن يتم قبوله كدولة', 'answer_start': -2}
# {'text': 'سيطلب من الرئيس تقديم تشريع إلى الكونغرس لقبول بورتوريكو كولاية .', 'answer_start': -2}
# {'text': 'تحديد عملية قبول بورتوريكو كدولة من دول الاتحاد', 'answer_start': -2}
# {'text': 'الكونجرس', 'answer_start': -2}
# {'text': '" حكومة مسؤولة " مستقلة', 'answer_start': -2}
# {'text': 'في أواخر 1940s', 'answer_start': -2}
# {'text': 'دومينيون نيوفاوندلاند', 'answer_start': -2}
# {'text': 'فشلت الحركة في نهاية المطاف', 'answer_start': -2}
# {'text': 'الولايات المتحدة', 'answer_start': -2}
# {'text': 'أبريل 1952', 'answer_start': -2}
# {'text': 'كدفاع عن اليابان', 'answer_start': -2}
# {'text': '15 مايو 1972', 'answer_start': -2}
# {'text': 'السخرية من كندا كجار غير مهم', 'answer_start': -2}
# {'text': '40 . 16 ٪ ( PQ ) و 1 . 22 ٪ ( NPDQ )', 'answer_start': -2}
# {'text': '1989', 'answer_start': -2}
# {'text': '3 , 846 الأصوات', 'answer_start': -2}
# {'text': 'الجدل الدائر حول إنشاء محيط دفاعي مشترك', 'answer_start': -2}
# {'text': 'إذا تم اتخاذ مسار سياسي معين ، فإن مصير كندا سيكون أكثر بقليل من جزء من الولايات المتحدة .', 'answer_start': -2}
# {'text': '1992', 'answer_start': -2}
# {'text': '1999', 'answer_start': -2}
# {'text': '1988', 'answer_start': -2}
# {'text': '61 في المئة', 'answer_start': -2}
# {'text': 'استفتاء 2012', 'answer_start': -2}
# {'text': 'وحصل خيار إقامة الدولة على 45 في المئة فقط من الأصوات إذا تم تضمين الامتناع عن التصويت .', 'answer_start': -2}
# {'text': 'تموز - يوليه - آب - أغسطس 1943', 'answer_start': -2}
# {'text': '40 , 000 عضو', 'answer_start': -2}
# {'text': 'أن يتم قبول صقلية كولاية أمريكية', 'answer_start': -2}
# {'text': 'حزب إعادة الإعمار في صقلية', 'answer_start': -2}
# {'text': 'الحزب الاتحادي', 'answer_start': -2}
# {'text': 'الفلبين', 'answer_start': -2}
# {'text': 'جمهوري', 'answer_start': -2}
# {'text': 'الحرب الإسبانية الأمريكية', 'answer_start': -2}
# {'text': 'أكثر من قرن', 'answer_start': -2}
# {'text': 'إسبانيا', 'answer_start': -2}
# {'text': 'ذا هيل', 'answer_start': -2}
# {'text': 'ذا هيل', 'answer_start': -2}
# {'text': 'عضو الكونغرس الأمريكي لويس غوتيريز عضو الكونغرس الأمريكي نيديا فيلاسكيز', 'answer_start': -2}
# {'text': 'بنما', 'answer_start': -2}
# {'text': 'منذ عام 1981', 'answer_start': -2}
# {'text': '19 و 20', 'answer_start': -2}
# {'text': '2001', 'answer_start': -2}
# {'text': 'أراضي بئر الطويل الصغيرة غير المطالب بها بين مصر والسودان والقارة القطبية الجنوبية والمحيطات والأجرام السماوية', 'answer_start': -2}
# {'text': 'بين مصر والسودان', 'answer_start': -2}
# {'text': 'معاهدة أنتاركتيكا ، واتفاقية الأمم المتحدة لقانون البحار ، ومعاهدة الفضاء الخارجي', 'answer_start': -2}
# {'text': 'منع الاستعمار والدولة المحتملة لأي من هذه الأراضي غير المأهولة ( وبالنظر إلى التكنولوجيا الحالية ، ليست صالحة للسكن بشكل دائم )', 'answer_start': -2}
# {'text': 'أربعة', 'answer_start': -2}
# {'text': 'راديو أستراليا', 'answer_start': -2}
# {'text': 'مايو 2008', 'answer_start': -2}
# {'text': 'جزر فرجن التابعة للولايات المتحدة', 'answer_start': -2}
# {'text': 'حالة', 'answer_start': -2}
# {'text': 'المفوض المقيم بيدرو بيرلويزي', 'answer_start': -2}
# {'text': 'كتب رسائل منفصلة إلى رئيس الولايات المتحدة باراك أوباما', 'answer_start': -2}
# {'text': 'صرح المدير السابق لوسائل الإعلام من أصل إسباني في البيت الأبيض', 'answer_start': -2}
# {'text': 'الحاكم المنتخب أليخاندرو غارسيا باديلا', 'answer_start': -2}
# {'text': '2010', 'answer_start': -2}
# {'text': 'علم الولايات المتحدة مع 51 نجمة', 'answer_start': -2}
# {'text': 'باولوس تيلفر', 'answer_start': -2}
# {'text': 'لا يزال الحزب غير مسجل ولا يمكنه الظهور في ورقة اقتراع', 'answer_start': -2}
# {'text': '1978', 'answer_start': -2}
# {'text': 'فرع حزب الخضر المحلي', 'answer_start': -2}
# {'text': 'نيو كولومبيا', 'answer_start': -2}
# {'text': '1763', 'answer_start': -2}
# {'text': 'ضم كندا', 'answer_start': -2}
# {'text': 'الجيش القاري', 'answer_start': -2}
# {'text': '1763', 'answer_start': -2}
# {'text': 'بويرتوريكو', 'answer_start': -2}
# {'text': 'بشأن المسائل التي يمثل فيها التصويت مشاركة حاسمة', 'answer_start': -2}
# {'text': 'المؤتمر ال 110', 'answer_start': -2}
# {'text': '( أ ) مفوض مقيم', 'answer_start': -2}
# {'text': '1898', 'answer_start': -2}
# {'text': 'ضريبة الدخل الفيدرالية', 'answer_start': -2}
# {'text': 'الضرائب الفيدرالية الأمريكية', 'answer_start': -2}
# {'text': '52', 'answer_start': -2}
# {'text': 'ضرائب الاستيراد - التصدير ، ضرائب السلع الفيدرالية ، ضرائب الضمان الاجتماعي', 'answer_start': -2}
# {'text': 'افتقارهم إلى التمثيل في الكونغرس', 'answer_start': -2}
# {'text': 'العبارة مطبوعة الآن على لوحات ترخيص واشنطن . C الصادرة حديثا', 'answer_start': -2}
# {'text': 'في بداية ولايته الثانية', 'answer_start': -2}
# {'text': 'بيل كلينتون', 'answer_start': -2}
# {'text': 'أصبحت ثقافتهم المحلية أو الوطنية أمريكية للغاية', 'answer_start': -2}
# {'text': 'منطقة أو إقليم متوافق وداعم ومفضي إلى الولايات المتحدة', 'answer_start': -2}
# {'text': 'التأثير أو السيطرة الثقافية أو العسكرية الأمريكية المفرطة', 'answer_start': -2}
# {'text': 'منطقة أو إقليم متحالف وداعم ومفضي إلى الولايات المتحدة ، بحيث يكون مثل دولة أمريكية', 'answer_start': -2}
# {'text': 'منطقة أو منطقة ينظر إليها على أنها تحت تأثير أو سيطرة ثقافية أو عسكرية أمريكية مفرطة', 'answer_start': -2}
# {'text': 'ASCII', 'answer_start': -2}
# {'text': 'كانون الأول - ديسمبر 2007', 'answer_start': -2}
# {'text': 'النص في أجهزة الكمبيوتر', 'answer_start': -2}
# {'text': 'يو تي إف - 8', 'answer_start': -2}
# {'text': '" عودة النقل " ( التي تحرك رأس الطباعة إلى بداية السطر ) و " تغذية الخط " ( التي تقدم الورق سطرا واحدا دون تحريك رأس الطباعة )', 'answer_start': -2}
# {'text': 'الغموض المتأصل في العديد من شخصيات التحكم ، جنبا إلى جنب مع استخدامها التاريخي', 'answer_start': -2}
# {'text': 'يمين', 'answer_start': -2}
# {'text': 'تغذية الخط', 'answer_start': -2}
# {'text': 'عودة النقل', 'answer_start': -2}
# {'text': 'كونترول - Z', 'answer_start': -2}
# {'text': 'ينهي الأبجدية', 'answer_start': -2}
# {'text': 'كونترول - سي', 'answer_start': -2}
# {'text': 'MS - DOS', 'answer_start': -2}
# {'text': '1981', 'answer_start': -2}
# {'text': 'EBCDIC', 'answer_start': -2}
# {'text': 'RT - 11', 'answer_start': -2}
# {'text': 'بحيث يمكن دعم الاتصالات بين المضيفين مع مختلف اصطلاحات نهاية الأسطر ومجموعات الأحرف', 'answer_start': -2}
# {'text': 'اذا', 'answer_start': -2}
# {'text': 'عن طريق إرسال تنسيق نص قياسي عبر الشبكة', 'answer_start': -2}
# {'text': 'CR - LF', 'answer_start': -2}
# {'text': 'ما يسمى ب " رمز الهروب ANSI "', 'answer_start': -2}
# {'text': 'إرسال ESC من المحطة الطرفية', 'answer_start': -2}
# {'text': 'طلب لإجهاض تشغيله الحالي أو الخروج منه ( إنهائه ) تماما', 'answer_start': -2}
# {'text': 'إرسال أحرف تحكم أخرى كحروف بدلا من استدعاء معناها', 'answer_start': -2}
# {'text': 'في واجهة المستخدم الرسومية ( GUI ) وأنظمة النوافذ', 'answer_start': -2}
# {'text': 'المتغيرات في منتصف الكلمات', 'answer_start': -2}
# {'text': 'الولايات المتحدة - ASCII', 'answer_start': -2}
# {'text': 'بوب بيمر', 'answer_start': -2}
# {'text': 'تقنية ITA2 خماسية البت', 'answer_start': -2}
# {'text': 'نظام طابعة تلكس عن بعد', 'answer_start': -2}
# {'text': 'رمز بيمر - روس', 'answer_start': -2}
# {'text': 'وضعت في الفضاء الفارغ', 'answer_start': -2}
# {'text': 'الياقوت', 'answer_start': -2}
# {'text': 'حذف', 'answer_start': -2}
# {'text': 'لجعله حرفا متجاهلا', 'answer_start': -2}
# {'text': 'للحفاظ على الخيارات متاحة للأحرف الصغيرة والرسومات الأخرى', 'answer_start': -2}
# {'text': 'لدعم الحروف الهجائية الكبيرة المكونة من 64 حرفا', 'answer_start': -2}
# {'text': '41 عرافة', 'answer_start': -2}
# {'text': 'لسهولة التعرف', 'answer_start': -2}
# {'text': '32 وظيفة', 'answer_start': -2}
# {'text': '1967', 'answer_start': -2}
# {'text': 'الرموز التلغرافية', 'answer_start': -2}
# {'text': '1963', 'answer_start': -2}
# {'text': 'يو تي إف - 8', 'answer_start': -2}
# {'text': 'ASCII', 'answer_start': -2}
# {'text': 'ملف ASCII يحتوي على نفس تسلسل الأحرف', 'answer_start': -2}
# {'text': '128 رمزا', 'answer_start': -2}
# {'text': '1878', 'answer_start': -2}
# {'text': 'باستخدام O ( حرف كبير o ) و l ( حرف صغير L ) بدلا من ذلك ،', 'answer_start': -2}
# {'text': 'الذي استخدم التخطيط الذي تم تحريكه إلى اليسار والمقابل ل ASCII', 'answer_start': -2}
# {'text': 'الرمز 15 ( Control - O ، Shift In )', 'answer_start': -2}
# {'text': 'محطة طباعة مزودة بقارئ شرائط - تثقيب ورقي متوفر', 'answer_start': -2}
# {'text': 'حتى 1980s', 'answer_start': -2}
# {'text': 'أقل تكلفة وأقل هشاشة من بعض النواحي', 'answer_start': -2}
# {'text': 'تيليتايب موديل 33 ASR', 'answer_start': -2}
# {'text': 'أكثر من 64 رمز', 'answer_start': -2}
# {'text': 'أنظمة ترميز الطابعة عن بعد', 'answer_start': -2}
# {'text': 'التواصل مع بعضهم البعض ومعالجة وتخزين وتوصيل المعلومات الموجهة نحو الشخصية', 'answer_start': -2}
# {'text': '11 إلى 25 رمزا رسوميا خاصا', 'answer_start': -2}
# {'text': 'أنماط البت الرقمية ورموز الأحرف', 'answer_start': -2}
# {'text': 'صفحة الكود 437', 'answer_start': -2}
# {'text': 'الرموز الرسومية مثل الوجوه المبتسمة', 'answer_start': -2}
# {'text': 'مجموعات الأحرف الخاصة بهم 8 بت', 'answer_start': -2}
# {'text': 'يتسبب في تقدم طابعة لورقتها', 'answer_start': -2}
# {'text': 'مساحة خلفية', 'answer_start': -2}
# {'text': 'أحرف التحكم التي لا تتضمن إرجاع النقل أو موجز الأسطر أو المسافة البيضاء كأحرف تحكم غير بيضاء', 'answer_start': -2}
# {'text': 'حرف 10', 'answer_start': -2}
# {'text': 'عنصر تحكم ثان', 'answer_start': -2}
# {'text': 'أ التحكم - S', 'answer_start': -2}
# {'text': 'كونترول - كيو', 'answer_start': -2}
# {'text': 'المصافحه', 'answer_start': -2}
# {'text': 'التحكم - R ( DC2 ) والتحكم - T ( DC4 )', 'answer_start': -2}
# {'text': 'تعيين معاني خاصة', 'answer_start': -2}
# {'text': 'إزالة الحرف الموجود في المؤشر', 'answer_start': -2}
# {'text': 'بكالوريوس', 'answer_start': -2}
# {'text': 'منذ أن استبدلت Apple أنظمة التشغيل هذه بنظام التشغيل OS X المستند إلى Unix', 'answer_start': -2}
# {'text': 'أنظمة يونكس وأنظمة شبيهة بيونكس ، وأنظمة أميغا', 'answer_start': -2}
# {'text': 'يقدم تعقيدات غير ضرورية وأسئلة حول كيفية تفسير كل حرف عند مواجهته بمفرده', 'answer_start': -2}
# {'text': 'تغذية الخط ( LF ) وحدها كمنهي خط', 'answer_start': -2}
# {'text': 'نظام التشغيل ماكنتوش و Apple DOS و ProDOS', 'answer_start': -2}
# {'text': 'مجموعة العمل X3 . 2 . 4', 'answer_start': -2}
# {'text': 'مطابقة الأحرف المبسطة غير الحساسة لحالة الأحرف وبناء لوحات المفاتيح والطابعات', 'answer_start': -2}
# {'text': 'فرقة العمل CCITT المعنية بأبجدية التلغراف الجديدة', 'answer_start': -2}
# {'text': '1967', 'answer_start': -2}
# {'text': 'ISO - IEC 646 ( 1972 )', 'answer_start': -2}
# {'text': 'يبدو أن خيارات ASCII لأحرف الاستخدام الوطني هي معايير فعلية للعالم', 'answer_start': -2}
# {'text': 'بمجرد أن تبدأ البلدان الأخرى في القيام بمهامها الخاصة', 'answer_start': -2}
# {'text': 'ISO - IEC 646 ( 1972 )', 'answer_start': -2}
# {'text': 'أقل موثوقية لنقل البيانات لأن الخطأ في إرسال رمز التحول عادة ما يجعل جزءا طويلا من الإرسال غير قابل للقراءة', 'answer_start': -2}
# {'text': 'سيسمح بتمثيل أكثر من 64 رمزا برمز سداسي البت', 'answer_start': -2}
# {'text': 'يتطلب ASCII رمزا من سبعة بت على الأقل', 'answer_start': -2}
# {'text': 'رمز متحولة', 'answer_start': -2}
# {'text': 'تحدد بعض رموز الأحرف الخيارات بين الخيارات لرموز الأحرف التالية', 'answer_start': -2}
# {'text': 'الشريط المثقب في ذلك الوقت يمكن أن يسجل ثمانية بتات في موضع واحد', 'answer_start': -2}
# {'text': 'تقليل التكاليف المرتبطة بنقل البيانات', 'answer_start': -2}
# {'text': '0', 'answer_start': -2}
# {'text': 'ثمانية بتات ( ثماني بتات ) تسمح لنمطين من أربعة بت بترميز رقمين بكفاءة باستخدام أرقام عشرية ثنائية الترميز', 'answer_start': -2}
# {'text': 'تمانية', 'answer_start': -2}
# {'text': 'ملحقات للأحرف خارج الأبجدية الإنجليزية والرموز المستخدمة خارج الولايات المتحدة', 'answer_start': -2}
# {'text': 'كندا', 'answer_start': -2}
# {'text': 'ASCII تناسب احتياجات الولايات المتحدة الأمريكية فقط وعدد قليل من البلدان الأخرى', 'answer_start': -2}
# {'text': 'يتم تعريف ASCII الحقيقي بدقة فقط من خلال معيار ANSI', 'answer_start': -2}
# {'text': 'آلات التليتايب', 'answer_start': -2}
# {'text': '128 حرفا محددا', 'answer_start': -2}
# {'text': 'ASCII', 'answer_start': -2}
# {'text': 'الإنكليزية', 'answer_start': -2}
# {'text': 'تطوير كورال كابيلا', 'answer_start': -2}
# {'text': 'مدرسة أدولف فريدريك للموسيقى', 'answer_start': -2}
# {'text': 'عدد كبير من المدارس الابتدائية والثانوية شعبية جدا', 'answer_start': -2}
# {'text': 'هناك تقليد قديم ، نسبة كبيرة بشكل غير عادي من السكان ( غالبا ما يتم الاستشهاد ب 5 ٪ ) يغنون بانتظام في الجوقات', 'answer_start': -2}
# {'text': 'كريستين أندرسون لوبيز وجيمس ألين فورد وروس كابلان وسارة وردزورث', 'answer_start': -2}
# {'text': 'أثناء العبور', 'answer_start': -2}
# {'text': '5 أكتوبر 2010', 'answer_start': -2}
# {'text': 'الملاكمة الصوتية', 'answer_start': -2}
# {'text': 'الكتب المقدسة المسيحية', 'answer_start': -2}
# {'text': '33 م إلى 180 م', 'answer_start': -2}
# {'text': 'مسيحي', 'answer_start': -2}
# {'text': '( 33 م إلى 180 م )', 'answer_start': -2}
# {'text': 'فهم أفضل لرغبة الله في الكنيسة', 'answer_start': -2}
# {'text': 'الأدوات نفسها', 'answer_start': -2}
# {'text': 'آباء الكنيسة', 'answer_start': -2}
# {'text': 'الأدوات نفسها', 'answer_start': -2}
# {'text': 'كلمات هراء', 'answer_start': -2}
# {'text': 'مسجل رباعي المسارات', 'answer_start': -2}
# {'text': 'قرع صوتي', 'answer_start': -2}
# {'text': 'الأغنية الرئيسية لسلسلة عائلة آدامز الجديدة', 'answer_start': -2}
# {'text': 'ساحة تومبكينز', 'answer_start': -2}
# {'text': 'محاكاته الآلية', 'answer_start': -2}
# {'text': 'أخذ العينات الصوتية وغير المقسمة', 'answer_start': -2}
# {'text': 'جوسكوين دي بريز', 'answer_start': -2}
# {'text': 'تعدد الأصوات من موسيقى كريستيان كابيلا', 'answer_start': -2}
# {'text': 'يرافقه عضو " يضاعف " بعض أو كل الأصوات', 'answer_start': -2}
# {'text': 'بدأ تعدد الأصوات في موسيقى كريستيان كابيلا في التطور في أوروبا', 'answer_start': -2}
# {'text': 'باليسترينا', 'answer_start': -2}
# {'text': 'عضو', 'answer_start': -2}
# {'text': 'في أسلوب أوراتوريو', 'answer_start': -2}
# {'text': 'باخ', 'answer_start': -2}
# {'text': '1610', 'answer_start': -2}
# {'text': 'نجاح الفرقة', 'answer_start': -2}
# {'text': 'المزج والتجويد والصياغة والملعب', 'answer_start': -2}
# {'text': 'ف . ميليوس كريستيانسن', 'answer_start': -2}
# {'text': 'كابيلا', 'answer_start': -2}
# {'text': 'كلية سانت أولاف', 'answer_start': -2}
# {'text': 'ف . ميليوس كريستيانسن', 'answer_start': -2}
# {'text': 'المعمدانيون النظاميون القدامى ، المعمدانيون البدائيون ، إخوة بليموث ، كنائس المسيح ، الإخوة المعمدان الألمان القدامى ،', 'answer_start': -2}
# {'text': 'الهيئات الدينية المسيحية', 'answer_start': -2}
# {'text': 'القيثارة المقدسة', 'answer_start': -2}
# {'text': 'المعمدانيون النظاميون القدامى ، المعمدانيون البدائيون ، إخوة بليموث ، كنائس المسيح ، الإخوة المعمدانيون الألمان القدامى', 'answer_start': -2}
# {'text': 'القداس الكاثوليكي الروماني والخدمة الإلهية اللوثرية', 'answer_start': -2}
# {'text': 'Dil se', 'answer_start': -2}
# {'text': '2001', 'answer_start': -2}
# {'text': 'بن ماسالا', 'answer_start': -2}
# {'text': 'مجموعات الكليات الهندية والإنجليزية', 'answer_start': -2}
# {'text': 'كابيلا', 'answer_start': -2}
# {'text': 'كابيلا', 'answer_start': -2}
# {'text': 'شارع X', 'answer_start': -2}
# {'text': 'شارع X', 'answer_start': -2}
# {'text': 'شارع X', 'answer_start': -2}
# {'text': '77', 'answer_start': -2}
# {'text': '28 كانون الثاني - يناير 1994', 'answer_start': -2}
# {'text': 'كابيلا', 'answer_start': -2}
# {'text': 'ذا مادريغال', 'answer_start': -2}
# {'text': 'عصر النهضة', 'answer_start': -2}
# {'text': 'في الموسيقى الدينية', 'answer_start': -2}
# {'text': 'اليهود والمسيحيين', 'answer_start': -2}
# {'text': 'مادريجال', 'answer_start': -2}
# {'text': 'غالبية الموسيقى الصوتية العلمانية', 'answer_start': -2}
# {'text': 'الإنشاد الميلادي', 'answer_start': -2}
# {'text': 'جاكسون 5 ، بات بيناتار ، بيلي أيدول ، مارفن غاي ، فضيحة ، تيفاني ، الرومانسيون ، الأدعياء ،', 'answer_start': -2}
# {'text': 'مسرح رو بلوط المسرح', 'answer_start': -2}
# {'text': 'صليب بين مذبح بويز و 25th السنوي مقاطعة بوتنام تهجئة النحل', 'answer_start': -2}
# {'text': 'الانسجام التام', 'answer_start': -2}
# {'text': 'أكتوبر , 2010', 'answer_start': -2}
# {'text': 'كوميديا', 'answer_start': -2}
# {'text': 'مسرح ستونهام', 'answer_start': -2}
# {'text': 'khorov ye kontsert ( كورال كونسيرتو )', 'answer_start': -2}
# {'text': 'تفسير صارم للمزامير 150', 'answer_start': -2}
# {'text': 'سلوك كابيلا', 'answer_start': -2}
# {'text': 'أواخر القرن 17', 'answer_start': -2}
# {'text': 'نيكولاي ديليتسكي', 'answer_start': -2}
# {'text': 'khorov ye kontsert', 'answer_start': -2}
# {'text': 'موسيكا', 'answer_start': -2}
# {'text': 'Grammatika musikiyskaya', 'answer_start': -2}
# {'text': 'مجموعات كابيلا', 'answer_start': -2}
# {'text': 'خارج سياق الشعائر الدينية الرسمية', 'answer_start': -2}
# {'text': 'آلات موسيقية', 'answer_start': -2}
# {'text': 'استخدام الآلات الموسيقية', 'answer_start': -2}
# {'text': 'الموسيقى الآلية', 'answer_start': -2}
# {'text': 'استخدام الآلات الموسيقية', 'answer_start': -2}
# {'text': 'آلات موسيقية', 'answer_start': -2}
# {'text': 'استخدام الآلات الموسيقية', 'answer_start': -2}
# {'text': '1953', 'answer_start': -2}
# {'text': 'حلو أديلين', 'answer_start': -2}
# {'text': '600', 'answer_start': -2}
# {'text': '25 , 000', 'answer_start': -2}
# {'text': 'سويت أديلاينز الدولية', 'answer_start': -2}
# {'text': 'مرحبا لوس والطلاب الأربعة الجدد', 'answer_start': -2}
# {'text': 'موسيقى كابيلا', 'answer_start': -2}
# {'text': 'الأكثر مبيعا', 'answer_start': -2}
# {'text': 'في 1950s', 'answer_start': -2}
# {'text': 'الاهتمام بعروض كابيلا للمجموعات الصغيرة', 'answer_start': -2}
# {'text': '" كومين " في جناح وصلاة "', 'answer_start': -2}
# {'text': 'فقط أنت', 'answer_start': -2}
# {'text': 'الصكوك', 'answer_start': -2}
# {'text': 'الصكوك', 'answer_start': -2}
# {'text': 'استخدام أداة في العبادة', 'answer_start': -2}
# {'text': 'الصكوك', 'answer_start': -2}
# {'text': 'قلب ميدلوثيان', 'answer_start': -2}
# {'text': 'المشيخية الاسكتلندية', 'answer_start': -2}
# {'text': 'الإصلاحيون البروتستانت', 'answer_start': -2}
# {'text': 'الصكوك', 'answer_start': -2}
# {'text': 'يشير إلى استخدام أداة في العبادة باسم " جرس البقر في حفلة موسيقية "', 'answer_start': -2}
# {'text': 'الصكوك', 'answer_start': -2}
# {'text': 'مجموعات الرجال', 'answer_start': -2}
# {'text': 'كول بورتر', 'answer_start': -2}
# {'text': 'The Whiffenpoofs of Yale University', 'answer_start': -2}
# {'text': 'طوال القرن 20th', 'answer_start': -2}
# {'text': 'بدءا من 1990s', 'answer_start': -2}
# {'text': 'جمعية الحفاظ على وتشجيع الغناء الرباعي لصالون الحلاقة في أمريكا ( S . P . E . B . S . Q . S . A )', 'answer_start': -2}
# {'text': 'أول منظمة رسمية لصالون الحلاقة للرجال', 'answer_start': -2}
# {'text': 'جمعية هارموني صالون الحلاقة ( BHS )', 'answer_start': -2}
# {'text': 'في صالونات الحلاقة', 'answer_start': -2}
# {'text': 'كانتاتا', 'answer_start': -2}
# {'text': 'alla breve', 'answer_start': -2}
# {'text': 'كابيلا', 'answer_start': -2}
# {'text': 'تجدد الاهتمام بتعدد الأصوات في عصر النهضة إلى جانب الجهل بحقيقة أن الأجزاء الصوتية غالبا ما كانت تتضاعف من قبل العازفين', 'answer_start': -2}
# {'text': 'تعدد الأصوات في عصر النهضة وكونسيرتاتو الباروك', 'answer_start': -2}
# {'text': 'مرافقة الآلات', 'answer_start': -2}
# {'text': 'الاهتمام بتعدد الأصوات في عصر النهضة', 'answer_start': -2}
# {'text': 'كابيلا', 'answer_start': -2}
# {'text': 'تعدد الأصوات في عصر النهضة وأسلوب كونسيرتاتو الباروكي', 'answer_start': -2}
# {'text': 'بعض الطوائف', 'answer_start': -2}
# {'text': 'كابيلا معاصرة', 'answer_start': -2}
# {'text': 'بعض الطوائف', 'answer_start': -2}
# {'text': 'Straight No Chaser , Pentatonix , The House Jacks , Rockapella , Mosaic , and M - pact .', 'answer_start': -2}
# {'text': 'الإيقاع الصوتي أو البيتبوكسينغ', 'answer_start': -2}
# {'text': 'صوت واحد يغني اللحن الرئيسي ، وواحد يغني خط باس إيقاعي ، والأصوات المتبقية تساهم في مرافقة وترية أو متعددة الأصوات', 'answer_start': -2}
# {'text': 'كابيلا', 'answer_start': -2}
# {'text': 'داخل الموسيقى المسيحية', 'answer_start': -2}
# {'text': 'الثناء بدون أدوات', 'answer_start': -2}
# {'text': 'من روش شودش إيلول حتى نهاية يوم الغفران', 'answer_start': -2}
# {'text': 'في حد ذاته ، دون أي مرافقة صوتية', 'answer_start': -2}
# {'text': 'فيلو', 'answer_start': -2}
# {'text': 'صوتي', 'answer_start': -2}
# {'text': 'الهتاف اليهودي', 'answer_start': -2}
# {'text': 'فيلو', 'answer_start': -2}
# {'text': '20 قبل الميلاد', 'answer_start': -2}
# {'text': 'الشوفار', 'answer_start': -2}
# {'text': 'الرب', 'answer_start': -2}
# {'text': 'ديسمبر 2009', 'answer_start': -2}
# {'text': '100 , 000 دولار وعقد تسجيل مع Epic Records - Sony Music', 'answer_start': -2}
# {'text': 'تمانية', 'answer_start': -2}
# {'text': 'قانون الحقوق المدنية', 'answer_start': -2}
# {'text': 'دمج المرافق العامة', 'answer_start': -2}
# {'text': 'إنهاء التمييز', 'answer_start': -2}
# {'text': 'اقتصاد', 'answer_start': -2}
# {'text': 'الطلاب البيض', 'answer_start': -2}
# {'text': 'كاليفورنيا', 'answer_start': -2}
# {'text': 'رتبة الصف', 'answer_start': -2}
# {'text': 'الدخول إلى أي جامعة حكومية إذا أنهى الطالب في أعلى 10 ٪ من فصله المتخرج', 'answer_start': -2}
# {'text': 'ترتيب فيلادلفيا', 'answer_start': -2}
# {'text': 'النقابات الحرفية', 'answer_start': -2}
# {'text': 'نيكسون', 'answer_start': -2}
# {'text': 'آرثر فليتشر', 'answer_start': -2}
# {'text': 'عمل إيجابي', 'answer_start': -2}
# {'text': 'نائب الرئيس جونسون', 'answer_start': -2}
# {'text': 'هوبارت تايلور جونيور', 'answer_start': -2}
# {'text': 'الأمر التنفيذي رقم 10925', 'answer_start': -2}
# {'text': 'ف ورد', 'answer_start': -2}
# {'text': 'أصبحت أقل انتشارا', 'answer_start': -2}
# {'text': 'وهناك مجالات أخرى تحتاج إلى التركيز', 'answer_start': -2}
# {'text': '8 ملايين', 'answer_start': -2}
# {'text': 'فرص التعليم العالي', 'answer_start': -2}
# {'text': 'قروض بنفس معدل البيض', 'answer_start': -2}
# {'text': 'دوايت أيزنهاور في مشروع قانون GI', 'answer_start': -2}
# {'text': 'الحرب العالمية الثانية', 'answer_start': -2}
# {'text': '52 مليون فدان', 'answer_start': -2}
# {'text': 'التحفظات', 'answer_start': -2}
# {'text': '1877', 'answer_start': -2}
# {'text': '1865', 'answer_start': -2}
# {'text': 'ويليام تيكومسيه شيرمان', 'answer_start': -2}
# {'text': 'الرئيس جون كينيدي', 'answer_start': -2}
# {'text': 'يجب على المجتمع اليوم التعويض عن الإصابات', 'answer_start': -2}
# {'text': 'حجة التعويض', 'answer_start': -2}
# {'text': 'المعاملة التفضيلية لهذه السمة نفسها غير منطقية', 'answer_start': -2}
# {'text': 'لا ينبغي معاقبة البيض اليوم الذين استفادوا ببراءة من المظالم السابقة على شيء لم يكن لديهم سيطرة عليه .', 'answer_start': -2}
# {'text': 'ثالث', 'answer_start': -2}
# {'text': 'حلقة نقاش', 'answer_start': -2}
# {'text': 'الأمر التنفيذي رقم 10925', 'answer_start': -2}
# {'text': 'المساعدة في فتح الأبواب أمام المجموعات المستبعدة تاريخيا', 'answer_start': -2}
# {'text': 'جذب المواهب والأفكار من جميع شرائح السكان', 'answer_start': -2}
# {'text': 'نظام الحصص بحكم الأمر الواقع', 'answer_start': -2}
# {'text': 'الباب السابع', 'answer_start': -2}
# {'text': 'زعيم الأقلية في مجلس الشيوخ', 'answer_start': -2}
# {'text': 'هوبرت همفري', 'answer_start': -2}
# {'text': 'ريتشي ضد إسبانيا دي ستيفانو', 'answer_start': -2}
# {'text': '17', 'answer_start': -2}
# {'text': '23', 'answer_start': -2}
# {'text': 'قانون الهجرة لعام 1924', 'answer_start': -2}
# {'text': 'الفصل المدرسي', 'answer_start': -2}
# {'text': 'الولايات المتحدة', 'answer_start': -2}
# {'text': 'إجراء دراسات استقصائية للتكوين العرقي للموظفين الفيدراليين والمقاولين المدعومين من الضرائب', 'answer_start': -2}
# {'text': 'نائب الرئيس ريتشارد نيكسون', 'answer_start': -2}
# {'text': 'لجنة العقود الحكومية', 'answer_start': -2}
# {'text': 'وزير الداخلية', 'answer_start': -2}
# {'text': 'لجنة ممارسات التوظيف العادلة', 'answer_start': -2}
# {'text': 'الأمر التنفيذي رقم 8802', 'answer_start': -2}
# {'text': 'هارولد ل . آيكس', 'answer_start': -2}
# {'text': 'توظيف نسبة ثابتة من العمال السود', 'answer_start': -2}
# {'text': 'طلاب للقبول العادل', 'answer_start': -2}
# {'text': 'نوفمبر 17 , 2014', 'answer_start': -2}
# {'text': 'مشروع التمثيل العادل', 'answer_start': -2}
# {'text': 'اللوائح المنظمة لممارسات التوظيف داخل المؤسسة الاتحادية', 'answer_start': -2}
# {'text': 'إنشاء لجنة الرئيس المعنية بالمساواة في المعاملة والفرص في القوات المسلحة', 'answer_start': -2}
# {'text': 'اثنان', 'answer_start': -2}
# {'text': 'يوليو 26', 'answer_start': -2}
# {'text': 'ليندون جونسون', 'answer_start': -2}
# {'text': 'لجنة الرئيس المعنية بالحقوق المدنية', 'answer_start': -2}
# {'text': '1947', 'answer_start': -2}
# {'text': 'الإسكان المدعوم اتحاديا', 'answer_start': -2}
# {'text': 'إلغاء العقد', 'answer_start': -2}
# {'text': 'لجنة الرئيس المعنية بتكافؤ فرص العمل', 'answer_start': -2}
# {'text': 'ريتشموند ضد شركة جيه إيه كروسون', 'answer_start': -2}
# {'text': 'ضروري لتعزيز مصلحة حكومية ملحة', 'answer_start': -2}
# {'text': 'جنسي', 'answer_start': -2}
# {'text': 'المحكمة العليا الأمريكية', 'answer_start': -2}
# {'text': 'القبول القديم', 'answer_start': -2}
# {'text': 'باك ضد الولايات المتحدة الحكام', 'answer_start': -2}
# {'text': 'القبول في الجامعات وغيرها من أشكال التعليم العالي', 'answer_start': -2}
# {'text': 'وضع أهداف رقمية محددة بناء على العرق للقبول أو التوظيف', 'answer_start': -2}
# {'text': '1976', 'answer_start': -2}
# {'text': 'الاستفادة من سياسات تفضيلات المجموعة', 'answer_start': -2}
# {'text': 'العمل الإيجابي في جميع أنحاء العالم : دراسة تجريبية', 'answer_start': -2}
# {'text': 'جامعة مدينة نيويورك', 'answer_start': -2}
# {'text': 'أبيض', 'answer_start': -2}
# {'text': 'مكتب الحقوق المدنية ضد', 'answer_start': -2}
# {'text': 'جانيت رابلي', 'answer_start': -2}
# {'text': 'قائمة الانتظار', 'answer_start': -2}
# {'text': 'مدني ودستوري', 'answer_start': -2}
# {'text': 'سياسة واعية للعرق', 'answer_start': -2}
# {'text': 'جامعة تكساس', 'answer_start': -2}
# {'text': 'أعلى واحد في المئة', 'answer_start': -2}
# {'text': 'أكثر من 60', 'answer_start': -2}
# {'text': 'إدارات التعليم والعدل', 'answer_start': -2}
# {'text': 'جامعة هارفارد', 'answer_start': -2}
# {'text': 'اتحادي', 'answer_start': -2}
# {'text': 'تساو', 'answer_start': -2}
# {'text': 'نصب لينكولن التذكاري', 'answer_start': -2}
# {'text': '10 , 000', 'answer_start': -2}
# {'text': 'التمييز العكسي', 'answer_start': -2}
# {'text': 'التمييز العكسي', 'answer_start': -2}
# {'text': 'الموظفون المرتبطون بالنقابات', 'answer_start': -2}
# {'text': 'قانون علاقات العمل الوطنية', 'answer_start': -2}
# {'text': 'السيناتور الأمريكي روبرت فاغنر', 'answer_start': -2}
# {'text': 'الاقليات', 'answer_start': -2}
# {'text': 'شركة لوكهيد للطائرات', 'answer_start': -2}
# {'text': 'NAACP', 'answer_start': -2}
# {'text': 'هربرت هيل', 'answer_start': -2}
# {'text': 'جيم كرو', 'answer_start': -2}
# {'text': 'نائب الرئيس جونسون', 'answer_start': -2}
# {'text': 'الآثار الجانبية غير المرغوب فيها', 'answer_start': -2}
# {'text': 'غروتر ضد الولايات المتحدة باند', 'answer_start': -2}
# {'text': '60 %', 'answer_start': -2}
# {'text': 'قد يزيد من التوتر العرقي', 'answer_start': -2}
# {'text': 'مراجعة ستانفورد للقانون', 'answer_start': -2}
# {'text': 'نصف جميع طلاب القانون السود يحتلون مرتبة قريبة من أسفل فصلهم بعد السنة الأولى من كلية الحقوق', 'answer_start': -2}
# {'text': 'لوس انجليس', 'answer_start': -2}
# {'text': 'حظر التمييز', 'answer_start': -2}
# {'text': 'بيل كلينتون', 'answer_start': -2}
# {'text': 'ليندون جونسون " الحرية ليست كافية "', 'answer_start': -2}
# {'text': 'لم تكن السياسة مصدر مشاكلهم', 'answer_start': -2}
# {'text': 'عصر إعادة الإعمار', 'answer_start': -2}
# {'text': 'عكس', 'answer_start': -2}
# {'text': 'الحصص بين الجنسين', 'answer_start': -2}
# {'text': '80 %', 'answer_start': -2}
# {'text': 'الدكتور بول بريست', 'answer_start': -2}
# {'text': 'القضاء على التمييز', 'answer_start': -2}
# {'text': 'يونيو 1963', 'answer_start': -2}
# {'text': 'الامتثال لسياسات الحكومة', 'answer_start': -2}
# {'text': '2000', 'answer_start': -2}
# {'text': 'الطلاب القوقازيون', 'answer_start': -2}
# {'text': 'يساعد الطلاب على الوصول إلى الأهداف الأساسية للتعليم الجامعي', 'answer_start': -2}
# {'text': 'سياسة أو ممارسة يتعرض فيها أعضاء الأغلبية للتمييز لصالح مجموعة أو أقلية محرومة تاريخيا', 'answer_start': -2}
# {'text': 'الرداءة وعدم الكفاءة', 'answer_start': -2}
# {'text': 'وارد كونرلي', 'answer_start': -2}
# {'text': 'موت', 'answer_start': -2}
# {'text': 'يتنازل عن بعض الحقوق والامتيازات', 'answer_start': -2}
# {'text': 'القوات المسلحة', 'answer_start': -2}
# {'text': 'غير متكافئ بطبيعته', 'answer_start': -2}
# {'text': 'التغلب على المعاملة الضارة من خلال الإدماج', 'answer_start': -2}
# {'text': 'بذل جهود خاصة من أجل الإدماج', 'answer_start': -2}
# {'text': 'الجهود المبذولة نحو الإدماج', 'answer_start': -2}
# {'text': 'فصل', 'answer_start': -2}
# {'text': 'السياسة الأمريكية الأفريقية', 'answer_start': -2}
# {'text': 'لمعالجة العقبات القائمة على العرق التي تسد طريق نجاح عدد لا يحصى من الأشخاص الملونين من جميع الطبقات', 'answer_start': -2}
# {'text': 'الأقليات غير الفقيرة لا تعاني من التمييز العنصري والجنساني', 'answer_start': -2}
# {'text': 'الطبقة الوسطى الأمريكية الأفريقية', 'answer_start': -2}
# {'text': 'أربع مرات', 'answer_start': -2}
# {'text': 'ارتفاع معدلات التسرب', 'answer_start': -2}
# {'text': 'ريتشارد ساندر', 'answer_start': -2}
# {'text': 'أدنى 20 في المئة', 'answer_start': -2}
# {'text': 'عدم المساواة الطبقية', 'answer_start': -2}
# {'text': 'الأمريكيون الأوروبيون من الطبقة الدنيا', 'answer_start': -2}
# {'text': 'العمل الإيجابي القائم على أساس طبقي', 'answer_start': -2}
# {'text': 'الناس من اللون', 'answer_start': -2}
# {'text': 'هسباني', 'answer_start': -2}
# {'text': 'المفاهيم المتنافسة لمهمة الكليات :', 'answer_start': -2}
# {'text': 'التنوع هو هدف الجامعة وتفضيلاتهم العرقية لا تميز ضد المتقدمين', 'answer_start': -2}
# {'text': 'كيف ستذهب فوائد العمل الإيجابي إلى أولئك الذين لا يحتاجون إليه ، ومعظمهم من الأقليات من الطبقة الوسطى .', 'answer_start': -2}
# {'text': 'من إنهاء العمل الإيجابي : قضية العدالة لعمى الألوان', 'answer_start': -2}
# {'text': 'معالجة التمييز في الماضي', 'answer_start': -2}
# {'text': 'لأن القيام بذلك غير ضروري', 'answer_start': -2}
# {'text': 'أكثر تمثيلا للسكان الذين يخدمونهم', 'answer_start': -2}
# {'text': 'الأقليات العرقية', 'answer_start': -2}
# {'text': 'تعليم', 'answer_start': -2}
# {'text': 'في عام 1985', 'answer_start': -2}
# {'text': 'ستوبار', 'answer_start': -2}
# {'text': 'تحمل مجموعة من الأسلحة الدفاعية وصواريخ P - 700 Granit الهجومية الكبيرة من طراز P - 700', 'answer_start': -2}
# {'text': 'تبيليسي', 'answer_start': -2}
# {'text': 'أنظمة P - 700', 'answer_start': -2}
# {'text': 'البحرية الفرنسية', 'answer_start': -2}
# {'text': 'كاتوبار', 'answer_start': -2}
# {'text': 'شارل ديغول', 'answer_start': -2}
# {'text': 'استر', 'answer_start': -2}
# {'text': 'غارة تونديرن في يوليو 1918', 'answer_start': -2}
# {'text': '1911', 'answer_start': -2}
# {'text': '1903', 'answer_start': -2}
# {'text': 'أول غارة جوية ناجحة في العالم تطلقها السفن', 'answer_start': -2}
# {'text': 'إتش إم إس أرجوس', 'answer_start': -2}
# {'text': 'بناء سفن قتالية سطحية ثقيلة جديدة', 'answer_start': -2}
# {'text': 'معاهدة واشنطن البحرية لعام 1922', 'answer_start': -2}
# {'text': 'ليكسينغتون - كلاس', 'answer_start': -2}
# {'text': 'السفن المسطحة', 'answer_start': -2}
# {'text': 'قادرة على VTOL أو طائرات الهليكوبتر', 'answer_start': -2}
# {'text': 'طائرات قادرة على الإقلاع والهبوط العمودي أو القصير', 'answer_start': -2}
# {'text': 'منطقة الإطلاق', 'answer_start': -2}
# {'text': 'حم', 'answer_start': -2}
# {'text': 'حاملات الطائرات', 'answer_start': -2}
# {'text': 'سطح الطائرة المسطح', 'answer_start': -2}
# {'text': 'تسريع بسرعة أكبر للحصول على رفع', 'answer_start': -2}
# {'text': 'سيكون بناء مدرج كامل الطول مكلفا وصيانته', 'answer_start': -2}
# {'text': 'سطح الطائرة', 'answer_start': -2}
# {'text': 'الهند', 'answer_start': -2}
# {'text': 'أربعة محركات توربينات غازية', 'answer_start': -2}
# {'text': 'أغسطس 2013', 'answer_start': -2}
# {'text': '8 , 000 ميل بحري', 'answer_start': -2}
# {'text': 'كوشين لبناء السفن', 'answer_start': -2}
# {'text': 'أرخص للعمل', 'answer_start': -2}
# {'text': 'نشر الطائرات الثقيلة مع عمليات تحميل كاملة', 'answer_start': -2}
# {'text': 'الطائرات الثقيلة', 'answer_start': -2}
# {'text': 'أنها تؤثر على وزن ونوع وتكوين الطائرة التي يمكن إطلاقها', 'answer_start': -2}
# {'text': 'البنية الفوقية للناقل', 'answer_start': -2}
# {'text': 'إدارة العادم من محطة توليد الكهرباء', 'answer_start': -2}
# {'text': 'الميمنه', 'answer_start': -2}
# {'text': 'الأبخرة القادمة عبر سطح السفينة', 'answer_start': -2}
# {'text': 'جزيرة', 'answer_start': -2}
# {'text': 'حتى 90', 'answer_start': -2}
# {'text': 'سبعة وثلاثون', 'answer_start': -2}
# {'text': 'البحرية الأمريكية', 'answer_start': -2}
# {'text': 'لنشر البالونات', 'answer_start': -2}
# {'text': 'الناقل الفائق', 'answer_start': -2}
# {'text': 'البارجة', 'answer_start': -2}
# {'text': 'شركات النقل العملاقة', 'answer_start': -2}
# {'text': 'المروحيات', 'answer_start': -2}
# {'text': 'السفن الهجومية البرمائية', 'answer_start': -2}
# {'text': 'الحرب العالمية الثانية', 'answer_start': -2}
# {'text': 'مجاديف ملونة', 'answer_start': -2}
# {'text': 'ضابط إشارة الهبوط', 'answer_start': -2}
# {'text': 'ضابط إشارة هبوط', 'answer_start': -2}
# {'text': 'نظام الهبوط البصري', 'answer_start': -2}
# {'text': 'الشروع في قوة شروع في نقلها ونشرها', 'answer_start': -2}
# {'text': 'طائرات هليكوبتر متعددة في وقت واحد', 'answer_start': -2}
# {'text': '1000 جندي ومركبات الدعم الخاصة بهم', 'answer_start': -2}
# {'text': 'البحرية الملكية الأسترالية', 'answer_start': -2}
# {'text': 'الأكبر في تاريخ البحرية الأسترالية', 'answer_start': -2}
# {'text': 'أكبر السفن الحربية التي بنيت على الإطلاق للبحرية الملكية', 'answer_start': -2}
# {'text': 'HMS الملكة إليزابيث و HMS أمير ويلز', 'answer_start': -2}
# {'text': '70 , 600', 'answer_start': -2}
# {'text': 'حاملتا طائرات STOVL جديدتان أكبر حجما ، فئة الملكة إليزابيث', 'answer_start': -2}
# {'text': 'البحرية الملكية', 'answer_start': -2}
# {'text': '70 , 600 طن', 'answer_start': -2}
# {'text': '2017', 'answer_start': -2}
# {'text': 'في حوالي عام 2020', 'answer_start': -2}
# {'text': 'الملكة إليزابيث', 'answer_start': -2}
# {'text': 'حمل وتسليح ونشر واستعادة الطائرات', 'answer_start': -2}
# {'text': 'مشروع القوة الجوية في جميع أنحاء العالم دون الاعتماد على القواعد المحلية', 'answer_start': -2}
# {'text': 'كامل الطول', 'answer_start': -2}
# {'text': 'حاملة طائرات', 'answer_start': -2}
# {'text': 'السفن الحربية التي تعمل بالطاقة النووية', 'answer_start': -2}
# {'text': 'البحرية الفرنسية', 'answer_start': -2}
# {'text': 'حريق كبير آخر', 'answer_start': -2}
# {'text': 'كليمنصو', 'answer_start': -2}
# {'text': 'تحديث واسع النطاق', 'answer_start': -2}
# {'text': 'البحرية البرازيلية', 'answer_start': -2}
# {'text': 'سفينة التدريب', 'answer_start': -2}
# {'text': 'هذه هي أول حاملة طائرات في حوزتهم', 'answer_start': -2}
# {'text': '100 , 000 طن', 'answer_start': -2}
# {'text': '45 , 000', 'answer_start': -2}
# {'text': 'نظام إطلاق الطائرات الكهرومغناطيسية ( EMALS )', 'answer_start': -2}
# {'text': '2016', 'answer_start': -2}
# {'text': 'حاملة الطائرات التقليدية تقبض على الكابلات وخطاف الذيل على طائراتها', 'answer_start': -2}
# {'text': 'منحدر للقفز على الجليد', 'answer_start': -2}
# {'text': 'عمودي', 'answer_start': -2}
# {'text': 'STOVL', 'answer_start': -2}
# {'text': 'باستخدام المنحدر وبدء التشغيل', 'answer_start': -2}
# {'text': 'استعادة طائراتهم', 'answer_start': -2}
# {'text': 'مسمار', 'answer_start': -2}
# {'text': 'لا يمكن أن تتباطأ من تلقاء نفسها', 'answer_start': -2}
# {'text': 'تمديد خطاف الذيل الذي يمسك بأسلاك المانع الممتدة عبر سطح السفينة', 'answer_start': -2}
# {'text': 'القضاء على واحد أو أكثر من مناطق هبوط طائرات الهليكوبتر', 'answer_start': -2}
# {'text': 'طائرات محملة بكثافة', 'answer_start': -2}
# {'text': 'العقوبة التي تفرضها على حجم الطائرة وحمولتها وحمولة الوقود', 'answer_start': -2}
# {'text': 'منجنيق أو صاروخ JATO', 'answer_start': -2}
# {'text': 'مع الحد الأدنى من التسلح وحمل الوقود', 'answer_start': -2}
# {'text': 'كان لديهم نطاق أعلى ودقة أعلى', 'answer_start': -2}
# {'text': 'نطاق فائق ومرونة وفعالية', 'answer_start': -2}
# {'text': 'غرق سفينة HMS Glorious بواسطة البوارج الألمانية', 'answer_start': -2}
# {'text': 'حاملة الطائرات', 'answer_start': -2}
# {'text': 'بداية ضربات الطائرات الفعالة والمتحركة للغاية', 'answer_start': -2}
# {'text': 'بطول 820 قدما ( 250 مترا )', 'answer_start': -2}
# {'text': '19 , 500 طن', 'answer_start': -2}
# {'text': 'خمسة', 'answer_start': -2}
# {'text': 'ضباط البحرية الهندية', 'answer_start': -2}
# {'text': 'علم الذرة العام', 'answer_start': -2}
# {'text': 'الرئيس السابق للبحرية الملكية', 'answer_start': -2}
# {'text': 'وفقا لنوع الطائرة التي يحملونها ومهامهم التشغيلية', 'answer_start': -2}
# {'text': 'لا يوجد تعريف واحد', 'answer_start': -2}
# {'text': 'الطائرات', 'answer_start': -2}
# {'text': '2023', 'answer_start': -2}
# {'text': 'مورمانسك', 'answer_start': -2}
# {'text': '2016', 'answer_start': -2}
# {'text': 'فلاديفوستوك', 'answer_start': -2}
# {'text': '10', 'answer_start': -2}
# {'text': 'F - 35Bs', 'answer_start': -2}
# {'text': 'سفن هجومية برمائية من الفئة الأمريكية', 'answer_start': -2}
# {'text': 'واحد كل أربع سنوات', 'answer_start': -2}
# {'text': 'ضرب الطائرات المتوقفة إلى الأمام', 'answer_start': -2}
# {'text': 'واحد أو اثنين', 'answer_start': -2}
# {'text': 'اثنان', 'answer_start': -2}
# {'text': 'سطح السفينة بزاوية', 'answer_start': -2}
# {'text': 'الحرب العالمية الثانية', 'answer_start': -2}
# {'text': 'ما يقرب من أربع مرات', 'answer_start': -2}
# {'text': 'تأثير سياسي واقتصادي وعسكري كبير في حالة فقدان حاملة الطائرات', 'answer_start': -2}
# {'text': 'لاستيعاب الزيادة المطردة في حجم الطائرة', 'answer_start': -2}
# {'text': 'حاملات الطائرات اليوم مكلفة للغاية', 'answer_start': -2}
# {'text': 'سرعة', 'answer_start': -2}
# {'text': 'ضوء', 'answer_start': -2}
# {'text': 'تقلع بأوزان أعلى بكثير', 'answer_start': -2}
# {'text': 'الطرف الأمامي من سطح الطائرة', 'answer_start': -2}
# {'text': 'بعض من حركة التدحرج إلى الأمام للطائرة إلى سرعة عمودية', 'answer_start': -2}
# {'text': 'طرادات الطيران الثقيلة', 'answer_start': -2}
# {'text': 'أسطول الناقل', 'answer_start': -2}
# {'text': 'توفير الدفاع عن قوافل السفن', 'answer_start': -2}
# {'text': 'الأدميرال المشرع وموظفيه', 'answer_start': -2}
# {'text': 'على جسر الملاحة', 'answer_start': -2}
# {'text': 'إطلاق الطائرات', 'answer_start': -2}
# {'text': 'حركة الطائرات قبل الإطلاق وبعد الاسترداد', 'answer_start': -2}
# {'text': 'يقبل القراء مغامرة الأسئلة التي ستفصلهم عن كل إجماع', 'answer_start': -2}
# {'text': 'النص الميتافيزيقي الوحيد الأكثر إثارة للإعجاب في القرن العشرين', 'answer_start': -2}
# {'text': 'العملية والواقع', 'answer_start': -2}
# {'text': 'مشاكل علمية وفلسفية في القرن 21', 'answer_start': -2}
# {'text': 'لا ينبغي أن يمنع الناس من إدراك أن " المواد المادية " أو " الجواهر " هي وصف معمم مناسب', 'answer_start': -2}
# {'text': 'من السهل والمريح التفكير في الأشخاص والأشياء على أنها تبقى في الأساس نفس الأشياء', 'answer_start': -2}
# {'text': 'قيود اللغة', 'answer_start': -2}
# {'text': 'ريتشارد رورتي', 'answer_start': -2}
# {'text': 'تشارلز ساندرز بيرس', 'answer_start': -2}
# {'text': 'البديهيات وقواعد الاستدلال المقترحة', 'answer_start': -2}
# {'text': 'مختلط', 'answer_start': -2}
# {'text': 'فيكتور لوي', 'answer_start': -2}
# {'text': 'لن يلمسه أي كاتب سيرة ذاتية محترف في عقله الصحيح', 'answer_start': -2}
# {'text': 'إن فكرة المادة كمادة أساسية تجعل الناس يفكرون في الأشياء على أنها منفصلة بشكل أساسي في الزمان والمكان ، وليس بالضرورة مرتبطة بأي شيء .', 'answer_start': -2}
# {'text': 'يحجب أهمية العلاقات', 'answer_start': -2}
# {'text': 'من وجهة نظر وايتهيد ، تلعب العلاقات دورا أساسيا', 'answer_start': -2}
# {'text': 'مبادئ الرياضيات', 'answer_start': -2}
# {'text': 'مقدمة في الرياضيات', 'answer_start': -2}
# {'text': 'برتراند راسل', 'answer_start': -2}
# {'text': 'تعتبر واحدة من أهم الأعمال في المنطق الرياضي في القرن 20th', 'answer_start': -2}
# {'text': 'أطروحة في الجبر العالمي', 'answer_start': -2}
# {'text': 'الدين هو ما يفعله الفرد بعزلته', 'answer_start': -2}
# {'text': 'في حين أن الدين غالبا ما يكون له تأثير جيد ، إلا أنه ليس بالضرورة جيدا', 'answer_start': -2}
# {'text': 'عقد 1910', 'answer_start': -2}
# {'text': 'فلسفة العلوم', 'answer_start': -2}
# {'text': 'العملية والواقع', 'answer_start': -2}
# {'text': 'يتم بناء الواقع بشكل أساسي من خلال أجزاء من المادة التي توجد بشكل مستقل عن بعضها البعض .', 'answer_start': -2}
# {'text': 'مفاهيم مهمة يمكن للطالب ربطها عضويا', 'answer_start': -2}
# {'text': 'يجب أن يكون التعليم عكس ذلك تماما للتخصصات المتعددة', 'answer_start': -2}
# {'text': 'دعا إلى تدريس عدد قليل نسبيا من المفاهيم المهمة التي يمكن للطالب ربطها عضويا بالعديد من مجالات المعرفة المختلفة', 'answer_start': -2}
# {'text': 'من خلال عمل طلابه ومعجبيه', 'answer_start': -2}
# {'text': 'كليرمونت وعدد مختار من برامج اللاهوت والفلسفة الليبرالية على مستوى الدراسات العليا', 'answer_start': -2}
# {'text': 'برتراند راسل ، كما قام بتدريس وأشرف على أطروحة ويلارد فان أورمان كوين', 'answer_start': -2}
# {'text': 'إنه يقف مؤقتا كآخر فيلسوف أنجلو أمريكي عظيم قبل أن ينشر تلاميذ فيتغنشتاين ارتباكهم الضبابي وكفايتهم وإرهابهم .', 'answer_start': -2}
# {'text': 'تعريف الجوهر " أو " الهوية الأساسية', 'answer_start': -2}
# {'text': 'مناسبات الخبرة', 'answer_start': -2}
# {'text': 'جوهر', 'answer_start': -2}
# {'text': '" مناسبات تجربة " منفصلة تتداخل مع بعضها البعض في الزمان والمكان', 'answer_start': -2}
# {'text': 'النوعية والثانوية لهويتهم الأساسية', 'answer_start': -2}
# {'text': 'تطوير فلسفة عملية وايتهيد إلى لاهوت عملية كامل', 'answer_start': -2}
# {'text': 'تشارلز هارتسهورن', 'answer_start': -2}
# {'text': 'اللاهوت التقدمي الأمريكي', 'answer_start': -2}
# {'text': 'الجليل الموجز', 'answer_start': -2}
# {'text': 'أعطت الكنيسة لله الصفات التي كانت تخص قيصر حصرا .', 'answer_start': -2}
# {'text': 'في المقام الأول ملك إلهي يفرض إرادته على العالم ، وأهم صفاته هي القوة', 'answer_start': -2}
# {'text': 'مدرسة اللاهوت بجامعة شيكاغو', 'answer_start': -2}
# {'text': 'هنري نيلسون ويمان', 'answer_start': -2}
# {'text': 'ويمان ، تشارلز هارتسهورن ، برنارد لومر ، برنارد ميلاند ، ودانيال داي وليامز', 'answer_start': -2}
# {'text': 'جون ب . كوب الابن', 'answer_start': -2}
# {'text': 'مبنية بشكل أساسي من أجزاء من المادة التي توجد بشكل مستقل تماما عن بعضها البعض', 'answer_start': -2}
# {'text': 'الأنطولوجيا القائمة على الأحداث أو " العملية " التي تكون فيها الأحداث أساسية ومترابطة بشكل أساسي وتعتمد على بعضها البعض', 'answer_start': -2}
# {'text': 'يقال إن العمليات غير الحية مثل تصادمات الإلكترونات تظهر درجة معينة من الخبرة', 'answer_start': -2}
# {'text': 'فلسفة الكائن الحي', 'answer_start': -2}
# {'text': 'طبيعة الله العلائقية', 'answer_start': -2}
# {'text': 'لن يمدح الناس حاكما بشريا لم يتأثر بأفراح أو أحزان أتباعه .', 'answer_start': -2}
# {'text': 'الزميل المتألم الذي يفهم', 'answer_start': -2}
# {'text': 'الأفكار التي هي قصاصات منفصلة من المعلومات', 'answer_start': -2}
# {'text': 'تم إلقاء المقال الذي اشتقت منه أهداف التعليم اسمها كعنوان في عام 1916', 'answer_start': -2}
# {'text': '1929', 'answer_start': -2}
# {'text': '1912 و 1927', 'answer_start': -2}
# {'text': 'انتقادات شديدة', 'answer_start': -2}
# {'text': 'أصبحت وجهة نظر وايتهيد الآن بالية ، مع اكتشاف موجات الجاذبية .', 'answer_start': -2}
# {'text': 'لاحظت فينونينا محليا أنها تنتهك إلى حد كبير هذا النوع من التسطيح المحلي للمساحة التي يفترضها وايتهيد', 'answer_start': -2}
# {'text': 'ينظر الشخص العادي إلى الأعلى ، ويرى شكلا ملونا ، ويستنتج على الفور أنه كرسي .', 'answer_start': -2}
# {'text': 'ربما لم يقفز إلى فكرة الكرسي', 'answer_start': -2}
# {'text': 'علم الأحياء والاقتصاد', 'answer_start': -2}
# {'text': 'علم الوراثه', 'answer_start': -2}
# {'text': 'عالم لاهوت عملية', 'answer_start': -2}
# {'text': 'نظرية ما بعد البنيوية وما بعد الاستعمار والنظرية النسوية', 'answer_start': -2}
# {'text': 'الشيء الحقيقي هو فقط ما يجبر بقية الكون على التوافق معه بطريقة أو بأخرى .', 'answer_start': -2}
# {'text': 'بعض الشعور لا أكثر ولا أقل', 'answer_start': -2}
# {'text': 'توسيع الهياكل الجبرية', 'answer_start': -2}
# {'text': 'وحدة التصميم', 'answer_start': -2}
# {'text': 'دراسة مقارنة لهياكلها المتعددة', 'answer_start': -2}
# {'text': 'جامعة لندن', 'answer_start': -2}
# {'text': 'بكالوريوس العلوم', 'answer_start': -2}
# {'text': 'هل فات الأوان ؟ لاهوت علم البيئة', 'answer_start': -2}
# {'text': 'الحفاظ على الصالح العام : منظور مسيحي للاقتصاد العالمي', 'answer_start': -2}
# {'text': 'جائزة غراوماير للأفكار التي تعمل على تحسين النظام العالمي', 'answer_start': -2}
# {'text': 'مارك ديبن', 'answer_start': -2}
# {'text': 'فكر العملية التطبيقية II', 'answer_start': -2}
# {'text': 'فلسفة إدارة الأعمال والنظرية التنظيمية', 'answer_start': -2}
# {'text': 'مطبعة جامعة كامبريدج', 'answer_start': -2}
# {'text': 'في السنة', 'answer_start': -2}
# {'text': 'لا توجد مكتبة أكاديمية كبرى في العالم لا تحتوي على نسخة', 'answer_start': -2}
# {'text': 'كان العمل المكون من ثلاثة مجلدات ضخما جدا', 'answer_start': -2}
# {'text': 'الممارسات التي توحد النضال السياسي والروحانية مع علوم التربية', 'answer_start': -2}
# {'text': 'أوروبا والصين', 'answer_start': -2}
# {'text': 'البيئة والفيزياء والبيولوجيا والتعليم والاقتصاد وعلم النفس', 'answer_start': -2}
# {'text': 'ويليام تيمبل', 'answer_start': -2}
# {'text': 'الأنطولوجيا التي " تفهم أن تصبح عملية علائقية . الفرق باعتباره مرتبطا ، ولكنه فريد من نوعه ؛ والغرض من أن تصبح فرقا متناغما', 'answer_start': -2}
# {'text': 'العملية التكاملية : التفكير الفوليت من الأنطولوجيا إلى الإدارة', 'answer_start': -2}
# {'text': 'إن مهمة الدين هي جعل الفلسفة قابلة للتطبيق على الحياة اليومية للناس العاديين .', 'answer_start': -2}
# {'text': 'يأخذ الدين العواطف العميقة ويضعها في سياقها ضمن نظام من الحقائق العامة حول العالم', 'answer_start': -2}
# {'text': 'جسر بين الفلسفة والعواطف', 'answer_start': -2}
# {'text': 'الرغبة القصوى في غرس الخصوصية الملحة للعاطفة تلك العمومية غير الزمنية التي تنتمي في المقام الأول إلى الفكر المفاهيمي وحده', 'answer_start': -2}
# {'text': 'لم يكن لديك أي تدريب رسمي في الفلسفة', 'answer_start': -2}
# {'text': 'سيصبح وايتهيد واحدا من أهم الميتافيزيقيين في القرن 20th', 'answer_start': -2}
# {'text': 'برتراند راسل', 'answer_start': -2}
# {'text': 'تعتبر التحقيقات الميتافيزيقية ضرورية لكل من العلم الجيد والفلسفة الجيدة', 'answer_start': -2}
# {'text': 'كل رجل علمي من أجل الحفاظ على سمعته يجب أن يقول إنه يكره الميتافيزيقيا . ما يعنيه هو أنه يكره انتقاد ميتافيزيقيته', 'answer_start': -2}
# {'text': 'قبول الله لنشاط العالم', 'answer_start': -2}
# {'text': 'الله يتغير حقا بما يحدث في العالم والكون الأوسع', 'answer_start': -2}
# {'text': 'الله يخلص ويعتز بجميع التجارب إلى الأبد', 'answer_start': -2}
# {'text': 'سلسلة متصلة من الأحداث المتداخلة', 'answer_start': -2}
# {'text': 'هذه المفاهيم " الكلاسيكية " تفشل في تفسير التغيير بشكل كاف', 'answer_start': -2}
# {'text': 'من خلال افتراض أن الأشياء الدائمة هي أكثر الأشياء الحقيقية والأساسية في الكون', 'answer_start': -2}
# {'text': '" الجودة " و " المادة " و " الشكل "', 'answer_start': -2}
# {'text': 'المجتمع " من الأحداث', 'answer_start': -2}
# {'text': 'العقل لديه فقط أفكار خاصة حول الكيانات الأخرى', 'answer_start': -2}
# ...
# {'text': '200 مليون دولار', 'answer_start': -2}
# {'text': 'لقد كان من الممكن اختيار ترخيص المشاع الإبداعي كافتراضي ، مما يسمح للمستخدمين الآخرين بإعادة استخدام المواد وإعادة مزجها إذا كانت خالية من حقوق الطبع والنشر .', 'answer_start': -2}
# {'text': 'خدمة تجريبية ، تسمح لبعض الشركاء بتقديم تنزيلات الفيديو مجانا أو مقابل رسوم مدفوعة من خلال Google Checkout', 'answer_start': -2}
# {'text': 'الرئيس باراك أوباما', 'answer_start': -2}
# {'text': 'غوتنبرغ', 'answer_start': -2}
# {'text': 'أكاديمية خان', 'answer_start': -2}
# {'text': 'السيناتور ليندسي غراهام', 'answer_start': -2}
# {'text': 'قدم أكثر من ثلث أعضاء مجلس الشيوخ الأمريكي قرارا يدين جوزيف كوني', 'answer_start': -2}
# {'text': 'تنظيم الاضطرابات السياسية ينطوي على استخدام " فيسبوك لجدولة الاحتجاجات ، وتويتر للتنسيق ، ويوتيوب لإخبار العالم " .', 'answer_start': -2}
# {'text': 'سي', 'answer_start': -2}
# {'text': 'أول تطبيق لجهاز iPhone', 'answer_start': -2}
# {'text': 'تفاح', 'answer_start': -2}
# {'text': 'معيار الفيديو المفضل', 'answer_start': -2}
# {'text': 'فياكوم', 'answer_start': -2}
# {'text': 'غوغل', 'answer_start': -2}
# {'text': '" جيل يوتيوب " .', 'answer_start': -2}
# {'text': 'الرئيس الأمريكي أوباما', 'answer_start': -2}
# {'text': 'سابع أكبر منتج لمؤسسة إخبارية', 'answer_start': -2}
# {'text': 'سان فرانسيسكو ، كاليفورنيا', 'answer_start': -2}
# {'text': 'مشاركة مقاطع الفيديو', 'answer_start': -2}
# {'text': 'سان فرانسيسكو ، كاليفورنيا', 'answer_start': -2}
# {'text': 'عائد', 'answer_start': -2}
# {'text': 'ما يقرب من الثلث', 'answer_start': -2}
# {'text': 'ملكية حقوق الطبع والنشر الخاصة بها', 'answer_start': -2}
# {'text': 'يجب أن تكون المراجعة الاستباقية للمحتوى ممارسة قياسية للمواقع التي تستضيف المحتوى الذي ينشئه المستخدمون', 'answer_start': -2}
# {'text': 'لجنة الثقافة والإعلام التابعة لمجلس العموم في المملكة المتحدة', 'answer_start': -2}
# {'text': 'محتوى مقاطع الفيديو غير مناسب', 'answer_start': -2}
# {'text': '12 ساعة', 'answer_start': -2}
# {'text': 'الحد الأقصى لمدة عشر دقائق', 'answer_start': -2}
# {'text': 'جميع مستخدمي يوتيوب', 'answer_start': -2}
# {'text': 'تم زيادة الحد الأقصى البالغ 10 دقائق إلى 15 دقيقة', 'answer_start': -2}
# {'text': 'آذار - مارس 2006', 'answer_start': -2}
# {'text': '20 جيجابايت', 'answer_start': -2}
# {'text': 'تضمينه في أي صفحة على الويب', 'answer_start': -2}
# {'text': 'أنه سيزيل ردود الفيديو لكونها ميزة غير مستخدمة بشكل كاف', 'answer_start': -2}
# {'text': 'تضمين مقاطع فيديو YouTube في صفحات الشبكات الاجتماعية والمدونات', 'answer_start': -2}
# {'text': 'التضمين والتقييم والتعليق ونشر الاستجابة', 'answer_start': -2}
# {'text': 'بيتشبليند', 'answer_start': -2}
# {'text': 'ماري كوري', 'answer_start': -2}
# {'text': 'أقراص الساعة والطائرات', 'answer_start': -2}
# {'text': 'توهج في الظلام', 'answer_start': -2}
# {'text': 'كربونات اليورانيل', 'answer_start': -2}
# {'text': 'أخضر', 'answer_start': -2}
# {'text': 'خلات اليورانيل', 'answer_start': -2}
# {'text': 'ثاني أكسيد اليورانيوم', 'answer_start': -2}
# {'text': 'ثلاثي اليورانيوم ثماني أكسيد', 'answer_start': -2}
# {'text': '1 – 2 %', 'answer_start': -2}
# {'text': 'الخليج العربي', 'answer_start': -2}
# {'text': 'متلازمة حرب الخليج', 'answer_start': -2}
# {'text': 'اليورانيوم - 233', 'answer_start': -2}
# {'text': 'اليورانيوم - 233', 'answer_start': -2}
# {'text': 'اليورانيوم - 238', 'answer_start': -2}
# {'text': 'اليورانيوم المنضب', 'answer_start': -2}
# {'text': 'كحل', 'answer_start': -2}
# {'text': 'الموليبدينوم', 'answer_start': -2}
# {'text': 'اليورانينيت', 'answer_start': -2}
# {'text': 'الفوسفات', 'answer_start': -2}
# {'text': 'الليغنيت', 'answer_start': -2}
# {'text': '6', 'answer_start': -2}
# {'text': 'أبيض فضي', 'answer_start': -2}
# {'text': 'U', 'answer_start': -2}
# {'text': 'أكتينيد', 'answer_start': -2}
# {'text': '51', 'answer_start': -2}
# {'text': 'ثوريوم', 'answer_start': -2}
# {'text': 'في المستعرات العظمى', 'answer_start': -2}
# {'text': 'سائل', 'answer_start': -2}
# {'text': '49 %', 'answer_start': -2}
# {'text': 'الخمس', 'answer_start': -2}
# {'text': 'اليورانيوم - 238', 'answer_start': -2}
# {'text': '4 . 468 109 سنة ( سنوات )', 'answer_start': -2}
# {'text': 'المجمعات الأنيونية', 'answer_start': -2}
# {'text': 'المجمعات الأنيونية', 'answer_start': -2}
# {'text': 'محلول يحتوي على كربونات', 'answer_start': -2}
# {'text': 'يورانيوم', 'answer_start': -2}
# {'text': 'محلول يحتوي على كربونات', 'answer_start': -2}
# {'text': 'الجسيمات ذات أوقات الإقامة القصيرة في المكلس', 'answer_start': -2}
# {'text': 'كعكة اليورانيوم الأصفر المكلس', 'answer_start': -2}
# {'text': 'الجسيمات ذات أوقات الإقامة القصيرة في المكلس', 'answer_start': -2}
# {'text': 'الجسيمات ذات أوقات الإقامة القصيرة في المكلس', 'answer_start': -2}
# {'text': 'درجة الأسلحة', 'answer_start': -2}
# {'text': '550 مليون دولار أمريكي', 'answer_start': -2}
# {'text': '16', 'answer_start': -2}
# {'text': '40 , 000', 'answer_start': -2}
# {'text': 'الرجل السمين', 'answer_start': -2}
# {'text': '6 اغسطس 1945', 'answer_start': -2}
# {'text': '12 , 500', 'answer_start': -2}
# {'text': 'هيروشيما', 'answer_start': -2}
# {'text': 'أجهزة الطرد المركزي الغازية', 'answer_start': -2}
# {'text': 'سادس فلوريد اليورانيوم', 'answer_start': -2}
# {'text': 'أثقل', 'answer_start': -2}
# {'text': 'الانتشار الغازي', 'answer_start': -2}
# {'text': 'شيكاغو بايل - 1', 'answer_start': -2}
# {'text': 'مشروع مانهاتن', 'answer_start': -2}
# {'text': 'سفينجوموناس sp .', 'answer_start': -2}
# {'text': 'كربونات', 'answer_start': -2}
# {'text': 'كربونات', 'answer_start': -2}
# {'text': 'سفينجوموناس sp .', 'answer_start': -2}
# {'text': '99 . 2742 %', 'answer_start': -2}
# {'text': 'اليورانيوم - 238', 'answer_start': -2}
# {'text': 'الماء الثقيل المضغوط', 'answer_start': -2}
# {'text': '0 . 7204 %', 'answer_start': -2}
# {'text': 'الكتلة الحرجة', 'answer_start': -2}
# {'text': '1 . 7 مليار سنة', 'answer_start': -2}
# {'text': 'جبل يوكا', 'answer_start': -2}
# {'text': 'غابون', 'answer_start': -2}
# {'text': '3 %', 'answer_start': -2}
# {'text': 'النيوترونات الحرة', 'answer_start': -2}
# {'text': '235', 'answer_start': -2}
# {'text': 'كومة كلينتون', 'answer_start': -2}
# {'text': '20 ديسمبر 1951', 'answer_start': -2}
# {'text': 'تينيسي', 'answer_start': -2}
# {'text': 'إنريكو فيرمي شيكاغو بايل', 'answer_start': -2}
# {'text': '1800 درجة مئوية', 'answer_start': -2}
# {'text': 'ثنائي كربيد اليورانيوم الثلاثي', 'answer_start': -2}
# {'text': 'نترات', 'answer_start': -2}
# {'text': 'مرحلة', 'answer_start': -2}
# {'text': 'حرير', 'answer_start': -2}
# {'text': 'صوف .', 'answer_start': -2}
# {'text': '1934', 'answer_start': -2}
# {'text': 'عميد كلية روما ,', 'answer_start': -2}
# {'text': 'ليز مايتنر', 'answer_start': -2}
# {'text': 'إنريكو فيرمي', 'answer_start': -2}
# {'text': 'هيسبيريوم', 'answer_start': -2}
# {'text': '40', 'answer_start': -2}
# {'text': '1013', 'answer_start': -2}
# {'text': 'الأسمدة الفوسفاتية', 'answer_start': -2}
# {'text': '3 أجزاء في المليار', 'answer_start': -2}
# {'text': '10 ر . س .', 'answer_start': -2}
# {'text': '200 مليون دولار أمريكي', 'answer_start': -2}
# {'text': '35', 'answer_start': -2}
# {'text': 'الحرب العالمية الثانية', 'answer_start': -2}
# {'text': '( غير مخصب', 'answer_start': -2}
# {'text': 'اليورانيوم - 238', 'answer_start': -2}
# {'text': 'الديوتريوم', 'answer_start': -2}
# {'text': 'سبعة عشر', 'answer_start': -2}
# {'text': '9 , 430', 'answer_start': -2}
# {'text': 'أوزبكستان', 'answer_start': -2}
# {'text': '2 . 1 %', 'answer_start': -2}
# {'text': '0 . 3 %', 'answer_start': -2}
# {'text': '5 دولارات', 'answer_start': -2}
# {'text': 'بين 3 ٪ و 5 ٪', 'answer_start': -2}
# {'text': '130 ر . س .', 'answer_start': -2}
# {'text': 'المنضب', 'answer_start': -2}
# {'text': 'كثافة عالية', 'answer_start': -2}
# {'text': 'راديوم', 'answer_start': -2}
# {'text': 'حصب', 'answer_start': -2}
# {'text': 'ضعيف', 'answer_start': -2}
# {'text': '4 . 6 مليار', 'answer_start': -2}
# {'text': 'هايكاب', 'answer_start': -2}
# {'text': '2012', 'answer_start': -2}
# {'text': 'هيدروجين', 'answer_start': -2}
# {'text': '250 درجة مئوية', 'answer_start': -2}
# {'text': '482 إلى 572 درجة فهرنهايت', 'answer_start': -2}
# {'text': 'نتريد', 'answer_start': -2}
# {'text': 'اثنان', 'answer_start': -2}
# {'text': 'أكسيد اليورانيوم', 'answer_start': -2}
# {'text': 'الماء البارد', 'answer_start': -2}
# {'text': 'اليورانيوم - 239', 'answer_start': -2}
# {'text': '0 . 71 %', 'answer_start': -2}
# {'text': 'اليورانيوم - 233', 'answer_start': -2}
# {'text': 'اليورانيوم - 234', 'answer_start': -2}
# {'text': 'تفرز', 'answer_start': -2}
# {'text': '5 %', 'answer_start': -2}
# {'text': '0 . 5 %', 'answer_start': -2}
# {'text': 'الأنسجة العظمية', 'answer_start': -2}
# {'text': 'الفوسفات', 'answer_start': -2}
# {'text': '23 %', 'answer_start': -2}
# {'text': '0 . 01 إلى 0 . 25 ٪', 'answer_start': -2}
# {'text': 'كندا', 'answer_start': -2}
# {'text': 'بئر', 'answer_start': -2}
# {'text': 'هنري بيكريل', 'answer_start': -2}
# {'text': 'ليتل بوي', 'answer_start': -2}
# {'text': 'مارتن هاينريش كلابروث', 'answer_start': -2}
# {'text': 'برتقالي - أحمر', 'answer_start': -2}
# {'text': 'يوجين ملكيور بيليغوت', 'answer_start': -2}
# {'text': 'إيطاليا', 'answer_start': -2}
# {'text': '79 م', 'answer_start': -2}
# {'text': '1912', 'answer_start': -2}
# {'text': 'أصفر', 'answer_start': -2}
# {'text': 'مارتن هاينريش كلابروث', 'answer_start': -2}
# {'text': '1789', 'answer_start': -2}
# {'text': 'ويليام هيرشل .', 'answer_start': -2}
# {'text': 'دييورنات الصوديوم', 'answer_start': -2}
# {'text': 'درجة حرارة الغرفة', 'answer_start': -2}
# {'text': 'كلية', 'answer_start': -2}
# {'text': 'إشعاع ألفا', 'answer_start': -2}
# {'text': 'إدارة السلامة والصحة المهنية', 'answer_start': -2}
# {'text': '0 . 2 ملغم - م 3', 'answer_start': -2}
# {'text': 'حد التعرض الموصى به', 'answer_start': -2}
# {'text': '0 . 25 ملغم - م 3', 'answer_start': -2}
# {'text': '10 ملغم - م 3', 'answer_start': -2}
# {'text': 'Trapelia involuta', 'answer_start': -2}
# {'text': 'الغلوموس داخل الجذور', 'answer_start': -2}
# {'text': 'فوسفات الجلسرين', 'answer_start': -2}
# {'text': 'جيوباكتر', 'answer_start': -2}
# {'text': 'سيتروباكتر', 'answer_start': -2}
# {'text': 'العربية', 'answer_start': -2}
# {'text': 'معيار يونيكود', 'answer_start': -2}
# {'text': '120 , 000', 'answer_start': -2}
# {'text': 'جامعة كاليفورنيا في سان فرانسيسكو', 'answer_start': -2}
# {'text': 'يو تي إف - 16', 'answer_start': -2}
# {'text': 'بناء أنظمة جديدة لمعالجة المعلومات', 'answer_start': -2}
# {'text': 'UCS - 2', 'answer_start': -2}
# {'text': 'محرك الخط العربي', 'answer_start': -2}
# {'text': 'العربية والديفاناغارية', 'answer_start': -2}
# {'text': 'عقد 1980', 'answer_start': -2}
# {'text': 'تفاح', 'answer_start': -2}
# {'text': 'أدوبي ومايكروسوفت', 'answer_start': -2}
# {'text': 'مستخدم', 'answer_start': -2}
# {'text': 'مايكل إيفرسون وريك ماكجوان وكين ويسلر', 'answer_start': -2}
# {'text': 'لجنة خارطة طريق يونيكود', 'answer_start': -2}
# {'text': 'ذخيرة الشخصيات', 'answer_start': -2}
# {'text': 'سي جي كيه', 'answer_start': -2}
# {'text': 'عناصر أبسط', 'answer_start': -2}
# {'text': 'الأيديولوجيات', 'answer_start': -2}
# {'text': 'يونيكود الإصدار 2 . 0', 'answer_start': -2}
# {'text': 'U + A015 YI SYLLABLE WU', 'answer_start': -2}
# {'text': 'اسم الشخصية الرسمي', 'answer_start': -2}
# {'text': 'استقرار الاسم', 'answer_start': -2}
# {'text': 'عام', 'answer_start': -2}
# {'text': 'استخدمت الترميزات القديمة خصائص متعددة لكل نقطة رمز واحدة', 'answer_start': -2}
# {'text': 'اخر , التحكم', 'answer_start': -2}
# {'text': 'الفئة العامة', 'answer_start': -2}
# {'text': 'إرسال البريد الإلكتروني', 'answer_start': -2}
# {'text': 'معايير MIME', 'answer_start': -2}
# {'text': 'علامة ترتيب بايت Unicode', 'answer_start': -2}
# {'text': 'الطابع القانوني', 'answer_start': -2}
# {'text': 'U + FEFF', 'answer_start': -2}
# {'text': 'زوج بديل', 'answer_start': -2}
# {'text': 'بديل زائد', 'answer_start': -2}
# {'text': 'القيمة العددية', 'answer_start': -2}
# {'text': '1 , 048 , 576', 'answer_start': -2}
# {'text': 'الرموز', 'answer_start': -2}
# {'text': 'اللغات نفسها', 'answer_start': -2}
# {'text': 'ترون', 'answer_start': -2}
# {'text': 'لوحات المفاتيح', 'answer_start': -2}
# {'text': 'المعيار الصناعي التايلاندي 620', 'answer_start': -2}
# {'text': 'حروف العلة , , , ,', 'answer_start': -2}
# {'text': 'دعم الأبجدية التايلاندية', 'answer_start': -2}
# {'text': 'قابلية التشغيل البيني', 'answer_start': -2}
# {'text': 'المنظمة الدولية للتوحيد القياسي', 'answer_start': -2}
# {'text': 'يونيكود و ISO - IEC 10646', 'answer_start': -2}
# {'text': 'المستفيدون', 'answer_start': -2}
# {'text': 'يونيكود', 'answer_start': -2}
# {'text': 'ISO - IEC 10646', 'answer_start': -2}
# {'text': 'غربي', 'answer_start': -2}
# {'text': 'للحفاظ على الفروق المستخدمة من قبل الترميزات القديمة', 'answer_start': -2}
# {'text': 'نماذج كاملة العرض', 'answer_start': -2}
# {'text': 'سي جي كيه', 'answer_start': -2}
# {'text': 'أول 256 نقطة رمز', 'answer_start': -2}
# {'text': 'عموم يونيكود', 'answer_start': -2}
# {'text': 'استبدال الخط', 'answer_start': -2}
# {'text': 'ASCII الأساسية وبرامج نصية معينة أو مجموعات من الأحرف أو الرموز', 'answer_start': -2}
# {'text': 'التطبيقات والوثائق', 'answer_start': -2}
# {'text': 'نص عادي', 'answer_start': -2}
# {'text': 'الجداول المطبعية المتقدمة', 'answer_start': -2}
# {'text': 'تقنية الخط الحديثة', 'answer_start': -2}
# {'text': 'يونيكود الاحتياطي', 'answer_start': -2}
# {'text': 'تفاح', 'answer_start': -2}
# {'text': 'U + FFD', 'answer_start': -2}
# {'text': '', 'answer_start': -2}
# {'text': 'مترجمو دول مجلس التعاون الخليجي', 'answer_start': -2}
# {'text': '2 . 2', 'answer_start': -2}
# {'text': 'بذرة 7', 'answer_start': -2}
# {'text': 'النهايات', 'answer_start': -2}
# {'text': 'كانجي', 'answer_start': -2}
# {'text': 'نصوص تاريخية ( مثل الهيروغليفية المصرية ) وآلاف الأحرف التي نادرا ما تستخدم أو عفا عليها الزمن', 'answer_start': -2}
# {'text': 'آلية شخصية بديلة', 'answer_start': -2}
# {'text': 'الأسماء الشخصية وأسماء الأماكن', 'answer_start': -2}
# {'text': 'شخصيات مجردة', 'answer_start': -2}
# {'text': 'ogonek ، نقطة أعلاه ، ولهجة حادة', 'answer_start': -2}
# {'text': 'أوغونيك', 'answer_start': -2}
# {'text': 'تقليدي', 'answer_start': -2}
# {'text': 'استخدام واسع النطاق في مختلف بلدان العالم ولكن لا تزال غير متوافقة إلى حد كبير مع بعضها البعض', 'answer_start': -2}
# {'text': 'معيار ISO 8859', 'answer_start': -2}
# {'text': 'كل حرف جديد ممكن', 'answer_start': -2}
# {'text': 'إنها عملية داخلية فقط للتقديم', 'answer_start': -2}
# {'text': 'W3C XML', 'answer_start': -2}
# {'text': '692', 'answer_start': -2}
# {'text': 'مخططات التعليمات البرمجية أو المرفقات القياسية', 'answer_start': -2}
# {'text': 'يونيو', 'answer_start': -2}
# {'text': '1991', 'answer_start': -2}
# {'text': 'آلية التكافؤ القانوني', 'answer_start': -2}
# {'text': 'علامات التشكيل', 'answer_start': -2}
# {'text': 'نفس الشخصية', 'answer_start': -2}
# {'text': 'يو + 0065', 'answer_start': -2}
# {'text': 'الجمع بين الشخصيات', 'answer_start': -2}
# {'text': 'ترتيب مرئي', 'answer_start': -2}
# {'text': '128 رمز', 'answer_start': -2}
# {'text': 'العلماء المحليون', 'answer_start': -2}
# {'text': 'المعيار الوطني الصيني', 'answer_start': -2}
# {'text': 'حقيقي', 'answer_start': -2}
# {'text': 'صفر', 'answer_start': -2}
# {'text': 'أحادي المسافة', 'answer_start': -2}
# {'text': 'الحرف الرسومي الأساسي', 'answer_start': -2}
# {'text': 'الخطوط', 'answer_start': -2}
# {'text': 'MES - 1 و WGL - 4', 'answer_start': -2}
# {'text': '1062', 'answer_start': -2}
# {'text': 'مايكروسوفت ويندوز', 'answer_start': -2}
# {'text': '335', 'answer_start': -2}
# {'text': 'Shift - JIS أو EUC - JP', 'answer_start': -2}
# {'text': 'U + FF5E', 'answer_start': -2}
# {'text': 'الخرائط عن طريق الحقن', 'answer_start': -2}
# {'text': 'عدم تطابق تحويل تنسيق الرحلة ذهابا وإيابا', 'answer_start': -2}
# {'text': 'نطاق نقاط رمز Unicode', 'answer_start': -2}
# {'text': 'اثنان', 'answer_start': -2}
# {'text': 'UCS - 2', 'answer_start': -2}
# {'text': 'نطاق نقاط رمز Unicode', 'answer_start': -2}
# {'text': 'يو تي إف - 16', 'answer_start': -2}
# {'text': 'الأنماط المحتملة في UTF - 8', 'answer_start': -2}
# {'text': 'المعيار RFC 3629', 'answer_start': -2}
# {'text': 'حيث تكون مجموعة الأحرف غير معلمة', 'answer_start': -2}
# {'text': 'قائمة مكونات الصنف', 'answer_start': -2}
# {'text': 'تشاريس سيل', 'answer_start': -2}
# {'text': 'الحروف اللاتينيه', 'answer_start': -2}
# {'text': 'واحد', 'answer_start': -2}
# {'text': 'الأحرف ذات علامات التشكيل', 'answer_start': -2}
# {'text': 'واحد', 'answer_start': -2}
# {'text': 'يونيكود', 'answer_start': -2}
# {'text': 'UTF - 8 , UTF - 16', 'answer_start': -2}
# {'text': 'يو تي إف - 16', 'answer_start': -2}
# {'text': 'يو تي إف - 8', 'answer_start': -2}

# %%
index_to_token_position(span_train_encodings, span_train_answers)
index_to_token_position(val_encodings, aqad_val_answers)
index_to_token_position(test_encodings, aqad_test_answers)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-13-c012105c99fa> in <module>
# ----> 1 index_to_token_position(span_train_encodings, span_train_answers)
#       2 index_to_token_position(val_encodings, aqad_val_answers)
#       3 index_to_token_position(test_encodings, aqad_test_answers)
#
# <ipython-input-12-990c0be21e24> in index_to_token_position(encodings, answers)
#       3   end_positions = list()
#       4   for i in range(len(answers)):
# ----> 5     start_positions.append(encodings.char_to_token(i, answers[i]['answer_start'], 1))
#       6     end_positions.append(encodings.char_to_token(i, answers[i]['answer_end'], 1))
#       7     #if context truncated
#
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/transformers/tokenization_utils_base.py in char_to_token(self, batch_or_char_index, char_index, sequence_index)
#     550             batch_index = 0
#     551             char_index = batch_or_char_index
# --> 552         return self._encodings[batch_index].char_to_token(char_index, sequence_index)
#     553
#     554     def word_to_chars(
#
# OverflowError: can't convert negative int to unsigned

# %%
def add_weights_labels_tensors(encodings, plausible):
  plausible = torch.tensor(plausible)
  weights = torch.zeros(plausible.shape)
  no_ans = torch.ones(plausible.shape)
  weights[plausible==False]=1.0
  no_ans[plausible==False]=0.0
  weights = weights.view(-1,1)
  no_ans = no_ans.view(-1,1)
  encodings.update({'weights':weights, 'no_ans':no_ans})

# %%
add_weights_labels_tensors(train_encodings, aqad_train_plausible)
add_weights_labels_tensors(val_encodings, aqad_val_plausible)
add_weights_labels_tensors(test_encodings, aqad_test_plausible)

# %%
val_encodings['IDs'] = aqad_val_ids
test_encodings['IDs'] = aqad_test_ids

# %%
print(train_encodings.keys())
print(val_encodings.keys())
print(test_encodings.keys())
print(span_train_encodings.keys())

# %% [markdown]
# ## Dataset and DataLoader

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from tqdm import tqdm

# %%
class AqadDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings
    def __getitem__(self, idx):
        return {key: val[idx] for key, val in self.encodings.items()}

    def __len__(self):
        return len(self.encodings.input_ids)

cls_train_dataset = AqadDataset(train_encodings)
span_train_dataset = AqadDataset(span_train_encodings)
val_dataset = AqadDataset(val_encodings)
test_dataset = AqadDataset(test_encodings)

# %%
data_collator = DataCollatorWithPadding(araelectra_tokenizer)

# %%
cls_train_loader = DataLoader(cls_train_dataset, batch_size=8, shuffle= True, collate_fn= data_collator)
span_train_loader = DataLoader(span_train_dataset, batch_size=8, shuffle= True, collate_fn = data_collator)
val_loader = DataLoader(val_dataset, batch_size = 8, shuffle = True, collate_fn = data_collator)
test_loader = DataLoader(test_dataset, batch_size = 8, shuffle = True, collate_fn = data_collator)

# %% [markdown]
# ## Checkpoints

# %%
def save_ckp(state, is_best, checkpoint_path, best_model_path):
    """
    state: checkpoint to save
    is_best: is this the best checkpoint; min validation loss
    checkpoint_path: path to save checkpoint
    best_model_path: path to save best checkpoint
    """
    f_path = checkpoint_path
    # save checkpoint data to the path given, checkpoint_path
    torch.save(state, f_path)
    # if it is a best model, min validation loss
    if is_best:
        best_fpath = best_model_path
        # copy that checkpoint file to best path given, best_model_path
        shutil.copyfile(f_path, best_fpath)

# %%
def load_ckp(checkpoint_fpath, model, optimizer):
    """
    checkpoint_path: path to saved checkpoint
    model: model to load checkpoint parameters into       
    optimizer: optimizer defined in previous training
    """
    # load check point
    checkpoint = torch.load(checkpoint_fpath)
    # initialize state_dict from checkpoint to model
    model.load_state_dict(checkpoint['state_dict'])
    # initialize optimizer from checkpoint to optimizer
    optimizer.load_state_dict(checkpoint['optimizer'])
    # initialize valid_loss_min from checkpoint to valid_loss_min
    results = checkpoint['result_dict']
    # return model, optimizer, epoch value, min validation loss 
    return model, optimizer, checkpoint['epoch'], results

# %%
def order_exp(base_path, exp_name):
  exp_path = os.path.join(base_path, exp_name)
  if not os.path.exists(exp_path):
    os.mkdir(exp_path)
  curr_ckp_path = os.path.join(exp_path,'curr.pt')
  best_ckp_path = os.path.join(exp_path, 'best.pt')
  return curr_ckp_path, best_ckp_path, exp_path

# %% [markdown]
# ## Classification train and evaluation

# %%
def cls_eval(model, data_loader, exp_path, train_loss):
    model.eval()
    total_acc = 0
    for batch in data_loader:
      tokens = batch['input_ids'].to(device)
      masks = batch['attention_mask'].to(device)
      tokens_type = batch['token_type_ids'].to(device)
      gt_no_ans = batch['no_ans'].to(device)
      output = model(tokens, masks, tokens_type)
      pred = output.logits.view(masks.shape[0],2,)
      pred = torch.argmax(pred, dim=1)
      target = batch['no_ans'].to(device).view(masks.shape[0],)
      total_acc += torch.sum(target==pred)
    total_acc = total_acc/ val_dataset.__len__()
    res_dict = {'acc':total_acc.item()*100, 'train_loss':train_loss}
    if exp_path:
        log_path = os.path.join(exp_path,'res.csv')
        if not os.path.exists(log_path):
            with open(log_path,'w') as f:
                writer = csv.DictWriter(f, fieldnames=res_dict.keys())
                writer.writeheader()
        with open(log_path, 'a') as f:
            writer = csv.DictWriter(f, fieldnames=res_dict.keys())
            #writer.writeheader()
            writer.writerow(res_dict)
    return res_dict

# %%
def cls_train(model,start_epoch, num_epochs, optimizer,max_acc, train_loader, val_loader, log, exp_name):
  curr_ckp_path, best_ckp_path, exp_path = order_exp('Runs/AraElectraDecoupledAsquadv2/train/cls', exp_name)
  model.train()
  for epoch in range(start_epoch,num_epochs):
    total_loss = 0.0
    loop = tqdm(train_loader, leave=True)
    for batch_idx, batch in enumerate(loop):
      tokens = batch['input_ids'].to(device)
      masks = batch['attention_mask'].to(device)
      tokens_type = batch['token_type_ids'].to(device)
      output = model(tokens, masks, tokens_type)
      pred = output.logits.view(masks.shape[0],2,)
      target = batch['no_ans'].type(torch.LongTensor)
      target = target.to(device)
      loss = cls_criterion(pred, target.view(masks.shape[0],))
      loss.backward()
      optimizer.step()
      optimizer.zero_grad()
      total_loss = total_loss + ((1 / (batch_idx + 1)) * (loss.item() - total_loss)) 
      loop.set_description(f'Epoch {epoch}')
      loop.set_postfix(loss=loss.item())

    result_dict = cls_eval(model, val_loader,exp_path,total_loss )
    checkpoint = {
            'epoch': epoch + 1,
            'result_dict':result_dict,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict(),
        }
    curr_acc = result_dict['acc']
    if curr_acc>=max_acc:
      max_acc = curr_acc
      save_ckp(checkpoint, True, curr_ckp_path, best_ckp_path)
    else:
      save_ckp(checkpoint, False, curr_ckp_path, best_ckp_path)
    print(result_dict)
  return model

# %% [markdown]
# ## Modeling

# %%
Cls_AraElectra = ElectraForSequenceClassification.from_pretrained(model_name, num_labels=2)
QA_AraElectra = ElectraForQuestionAnswering.from_pretrained(model_name)

# %%
def freeze(Electra, count=None):
    if count is not None:
	      # We freeze here the embeddings of the model
        for param in Electra.embeddings.parameters():
            param.requires_grad = False

        if count != -1:
	          # if freeze_layer_count == -1, we only freeze the embedding layer
	          # otherwise we freeze the first `freeze_layer_count` encoder layers
            for layer in Electra.encoder.layer[:count]:
                for param in layer.parameters():
                    param.requires_grad = False
    print(sum(p.numel() for p in Electra.parameters()), sum(p.numel() for p in Electra.parameters() if p.requires_grad))

# %%
freeze(Cls_AraElectra.electra,4)
freeze(QA_AraElectra.electra, 4)

# %% [markdown]
# ## Classification Training

# %%
num_epochs = 2
learning_rate = 3e-5
optimizer = torch.optim.Adam(Cls_AraElectra.parameters(), lr=learning_rate)
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
#criterion_span = nn.CrossEntropyLoss(reduction='none')
cls_criterion = nn.CrossEntropyLoss()
Cls_AraElectra.to(device)

# %%
cls_trained_model = cls_train(Cls_AraElectra, 0, 2, optimizer, 0, cls_train_loader, val_loader , True, 'first')

# %% [markdown]
# ## Load Cls Model if needed

# %%
cls_model = ElectraForSequenceClassification.from_pretrained(model_name)

# %%
learning_rate = 3e-5
optimizer = torch.optim.AdamW(cls_model.parameters(), lr=learning_rate)
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
#criterion_span = nn.CrossEntropyLoss(reduction='none')
#cls_criterion = nn.CrossEntropyLoss()
cls_model.to(device)

# %%
cls_model, optimizer, start_epoch, result_dict = load_ckp('Runs/AraElectraDecoupledAsquadv2/train/cls/first/best.pt', cls_model, optimizer)

# %% [markdown]
# ## Span Training

# %%
def get_raw_preds(data_loader, model, cls_model): 
  model.eval()
  with torch.no_grad():
    #F1 = EM = Total = 0
    total_loss = 0.0
    total_predictions = dict()
    no_probs_pred = dict()
    soft = torch.nn.Softmax(dim=1)
    #loop = tqdm(data_loader)
    #loop = tqdm(data_loader, leave=True)
    for batch_idx, batch in enumerate(data_loader):
      #moving tensors to gpu    
      tokens = batch['input_ids'].to(device)
      masks = batch['attention_mask'].to(device)
      tokens_type = batch['token_type_ids'].to(device)
      gt_start = batch['start_positions'].to(device)
      gt_end = batch['end_positions'].to(device)
      weights = batch['weights'].view(-1,1).to(device)
      gt_no_ans = batch['no_ans'].to(device)
      IDs = batch['IDs'].to(device)
      outputs = model(tokens, masks, tokens_type, start_positions=gt_start, end_positions=gt_end)
      no_probs = cls_model(tokens, masks, tokens_type)
      no_probs = soft(no_probs.logits)
      #calculating loss
      loss = outputs.loss
      #update average total loss 
      total_loss = total_loss + ((1 / (batch_idx + 1)) * (loss.item() - total_loss)) 
      #calculating f1 score and EM
      curr_batch_size = tokens.shape[0]
      #print(curr_batch_size)
      #print(outputs.start_logits.shape)
      #print(no_probs.logits.shape)
      for i in range(curr_batch_size):
        #print(f"this is tensor index {i}")
        start_pred, end_pred= torch.argmax(outputs.start_logits[i],dim=0), torch.argmax(outputs.end_logits[i],dim =0)
        #print(start_pred.shape, end_pred.shape)
        #print(start_pred)
        #print(start_pred, end_pred)
        total_predictions[str(IDs[i].item())] = araelectra_tokenizer.decode(tokens[i][start_pred.item():end_pred.item()], skip_special_tokens=True, clean_up_tokenization_spaces=True)
        no_probs_pred[str(IDs[i].item())] = no_probs[i][1].item()
    #saving evaluation results
    #evaluation

    model.train()
    return total_predictions, no_probs_pred

# %%
def get_preds(total_preds, no_probs_preds,data_path, log_path):
    preds_path = os.path.join(log_path, 'preds')
    if not os.path.exists(preds_path):
        os.mkdir(preds_path)
    no_probs_path = os.path.join(preds_path, 'na_probs.json')
    text_preds_path = os.path.join(preds_path, 'preds.json')
    jsonString = json.dumps(total_preds)
    jsonFile = open(text_preds_path, "w")
    jsonFile.write(jsonString)
    jsonFile.close()
    jsonString = json.dumps(no_probs_preds)
    jsonFile = open(no_probs_path, "w")
    jsonFile.write(jsonString)
    jsonFile.close()
    #!python evaluatev2.py data_path text_preds_path electra --na-prob-file no_probs_path --na-prob-thresh 0.4 --out-file log_path
    #os.system(f"python evaluatev2.py {data_path} {text_preds_path} electra --na-prob-file {no_probs_path} --na-prob-thresh 0.5 --out-file {log_path}")
    # !/anaconda/envs/azureml_py38/bin/python3 evaluatev2.py Data/AAQAD-dev.json Runs/AraElectraDecoupledAsquadv2/train/span/first/preds/preds.json electra --na-prob-file Runs/AraElectraDecoupledAsquadv2/train/span/first/preds/na_probs.json --na-prob-thresh 0.5 --out-file Runs/AraElectraDecoupled/train/span/first 
    with open(os.path.join(log_path, 'res.csv')) as f:
        DictReader_obj = csv.DictReader(f)
        lastrow = None
        for item in DictReader_obj:
            lastrow = dict(item)
    #print(lastrow)
    return lastrow

# %%
def span_train(model,start_epoch, num_epochs, optimizer,max_compined_metric, train_loader, val_loader, log, exp_name):
  curr_ckp_path, best_ckp_path, exp_path = order_exp('Runs/AraElectraDecoupledAsquadv2/train/span', exp_name)
  model.train()
  for epoch in range(start_epoch,num_epochs):
    total_loss = 0.0
    loop = tqdm(train_loader, leave=True)
    for batch_idx, batch in enumerate(loop):
      tokens = batch['input_ids'].to(device)
      masks = batch['attention_mask'].to(device)
      tokens_type = batch['token_type_ids'].to(device)
      gt_start = batch['start_positions'].to(device)
      gt_end = batch['end_positions'].to(device)
      outputs = model(tokens, masks, tokens_type, start_positions=gt_start, end_positions=gt_end)
      loss = outputs.loss
      loss.backward()
      optimizer.step()
      optimizer.zero_grad()
      total_loss = total_loss + ((1 / (batch_idx + 1)) * (loss.item() - total_loss)) 
      loop.set_description(f'Epoch {epoch}')
      loop.set_postfix(loss=loss.item())

    total_preds, no_probs_preds = get_raw_preds(val_loader, model, cls_model)
    result_dict = get_preds(total_preds, no_probs_preds,'Data/asquadv2-val.json',exp_path )
    checkpoint = {
            'epoch': epoch + 1,
            'result_dict':result_dict,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict(),
        }
    curr_compined_metric = float(result_dict['exact'])+1.5*float(result_dict['f1'])
    if curr_compined_metric>=max_compined_metric:
      max_compined_metric = curr_compined_metric
      save_ckp(checkpoint, True, curr_ckp_path, best_ckp_path)
    else:
      save_ckp(checkpoint, False, curr_ckp_path, best_ckp_path)
    print(result_dict)
  return model

# %%
span_num_epochs = 2
span_learning_rate = 3e-5
span_optimizer = torch.optim.AdamW(QA_AraElectra.parameters(), lr=span_learning_rate)
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
#criterion_span = nn.CrossEntropyLoss(reduction='none')
#cls_criterion = nn.CrossEntropyLoss()
QA_AraElectra.to(device)

# %%
span_trained_model = span_train(QA_AraElectra,0, num_epochs, optimizer,0.0, span_train_loader, val_loader, True, 'first')
