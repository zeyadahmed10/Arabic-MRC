# %%
import os
import shutil
from collections import Counter
import numpy as np
import json
import torch
import torch.nn as nn
import torch.nn.functional as F
from transformers import AutoTokenizer, ElectraForQuestionAnswering, DataCollatorWithPadding
from Preprocess.arabertpreprocess import ArabertPreprocessor
import matplotlib.pyplot as plt
import seaborn as sns
import csv
torch.manual_seed(3407)

# %% [markdown]
# ## Read Data and Preprocessing

# %%
def add_end_index(answer, context):
  ## 1 if span mathc the context 0 otherwise
  text = answer['text']
  start_idx = answer['answer_start']
  end_idx = start_idx + len(text)
  if text == context[start_idx:end_idx]:
    answer['answer_end'] = end_idx
    return False
  for i in range(1,3):
    if text == context[start_idx-i:end_idx-i]:
      answer['answer_end']= end_idx-1
      answer['answer_start'] = start_idx-1
      return False
  return True

# %%
def arabert_preprocess(context,question, answer, arabert_prep):
    answer['text'] = arabert_prep.preprocess(answer['text'])
    context = arabert_prep.preprocess(context)
    question = arabert_prep.preprocess(question)
    res = context.find(answer['text'])
    answer['answer_start'] = res
    return context, question, answer, res

# %%
def Read_AAQAD(path,arabert_prep):
  contexts =[]
  answers =[]
  questions =[]
  IDs= []
  cnt = 0
  with open(path) as f:
    aaqad_dict = json.load(f)
    for article in aaqad_dict['data']:
      for passage in article['paragraphs']:
        context = passage['context']
        for qa in passage['qas']:
          question = qa['question']
          if 'plausible_answers' in qa.keys():# there is two cases if the question have no answer then use plausible answer
            access = 'plausible_answers'
            #plausible.append(False)
          else:
            access = 'answers'
            #plausible.append(True)
          for answer in qa[access]:
            context,question, answer, res =  arabert_preprocess(context,question, answer, arabert_prep)
            if res==-1:
              cnt+=1
              continue
            flag = add_end_index(answer, context) #if false dont add the 
            cnt =cnt + flag
            if not flag:
              contexts.append(context)
              answers.append(answer)
              questions.append(question)
              IDs.append(qa['id'])
  return contexts,questions,answers,IDs

# %%
model_name = "araelectra-base-discriminator"
arabert_prep = ArabertPreprocessor(model_name=model_name)
train_contexts, train_questions, train_answers, train_ids = Read_AAQAD('Data/ASQUAD1.json', arabert_prep)
aqad_train_contexts, aqad_train_questions, aqad_train_answers, aqad_train_ids = Read_AAQAD('Data/AAQAD-train.json', arabert_prep)
arcd_train_contexts, arcd_train_questions, arcd_train_answers, arcd_train_ids = Read_AAQAD('Data/arcd-train.json', arabert_prep)
aqad_val_contexts, aqad_val_questions, aqad_val_answers, aqad_val_ids = Read_AAQAD('Data/AAQAD-dev.json', arabert_prep)
arcd_test_contexts, arcd_test_questions, arcd_test_answers, arcd_test_ids = Read_AAQAD('Data/arcd-test.json', arabert_prep)
aqad_test_contexts, aqad_test_questions, aqad_test_answers, aqad_test_ids = Read_AAQAD('Data/AAQAD-test.json', arabert_prep)

# %%
train_contexts = train_contexts +aqad_train_contexts +arcd_train_contexts
train_questions = train_questions+ aqad_train_questions +arcd_train_questions
train_answers = train_answers+ aqad_train_answers+ arcd_train_answers
train_ids = train_ids + aqad_train_ids + arcd_train_ids
print(len(train_contexts), len(train_questions), len(train_answers))
# Out:
# 61666 61666 61666

# %%
del aqad_train_contexts, aqad_train_questions, aqad_train_answers, aqad_train_ids
del arcd_train_contexts, arcd_train_questions, arcd_train_answers, arcd_train_ids
print(len(train_contexts), len(train_questions), len(train_answers))
# Out:
# 61666 61666 61666

# %%
print(train_contexts[0])
print(train_questions[0])
print(train_answers[0])
# Out:
# يعتمد ASCII أساس ا على الأبجدية الإنجليزية ، ويقوم بترميز 128 حرف ا محدد ا في أعداد صحيحة من سبعة أجزاء كما هو موضح في مخطط ASCII على اليمين . الأحرف المشفرة هي الأرقام من 0 إلى 9 ، والأحرف الصغيرة ا إلى ز ، والأحرف الكبيرة A إلى Z ، ورموز الترقيم الأساسية ، ورموز التحكم التي نشأت مع أجهزة تيليتيبي ، ومساحة . على سبيل المثال ، سيصبح الحرف الصغير ج 1101010 والعشري 106 . تتضمن ASCII تعريفات ل 128 حرف ا 33 حرف ا تحكم ا غير الطباعة العديد منها الآن قديمة تؤثر على كيفية معالجة النص والمساحة و 95 حرف ا قابلا للطباعة ، بما في ذلك المساحة التي ي عتبر رسم ا غير مرئي 223 .
# ما هو ASCII على أساس ؟
# {'text': 'الأبجدية الإنجليزية', 'answer_start': 23, 'answer_end': 42}

# %% [markdown]
# ## Tokenization

# %%
#Creating the tokenizer
model_name = model_name = "aubmindlab/araelectra-base-discriminator"

araelectra_tokenizer = AutoTokenizer.from_pretrained(model_name,do_lower_case=False)
train_encodings = araelectra_tokenizer(train_questions, train_contexts, truncation=True)
aqad_val_encodings = araelectra_tokenizer(aqad_val_questions, aqad_val_contexts, truncation=True)
aqad_test_encodings = araelectra_tokenizer(aqad_test_questions, aqad_test_contexts,truncation= True)
arcd_test_encodings = araelectra_tokenizer(arcd_test_questions, arcd_test_contexts,truncation=True)

# %%
def index_to_token_position(encodings , answers):
  start_positions = list()
  end_positions = list()
  for i in range(len(answers)):
    start_positions.append(encodings.char_to_token(i, answers[i]['answer_start'], 1))
    end_positions.append(encodings.char_to_token(i, answers[i]['answer_end'], 1))
    #if context truncated
    if start_positions[-1] is None: 
      start_positions[-1] = araelectra_tokenizer.model_max_length
    #if end index is space
    itt = 1
    while end_positions[-1] is None: 
      end_positions[-1] = encodings.char_to_token(i, answers[i]['answer_end']-itt, 1)
      itt = itt + 1 
  encodings.update({'start_positions': torch.tensor(start_positions), 'end_positions': torch.tensor(end_positions)})
  encodings['start_positions'] = encodings['start_positions'].view(len(answers), 1)
  encodings['end_positions'] = encodings['end_positions'].view(len(answers), 1)

# %%
index_to_token_position(train_encodings, train_answers)
index_to_token_position(aqad_val_encodings, aqad_val_answers)
index_to_token_position(aqad_test_encodings, aqad_test_answers)
index_to_token_position(arcd_test_encodings, arcd_test_answers)

# %%
train_encodings.keys()
# Out:
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask', 'start_positions', 'end_positions'])

# %%
def fix_ids(ids):
    return [int(x) for x in ids]

# %%
arcd_test_ids = fix_ids(arcd_test_ids)

# %%
print(type(arcd_test_ids[0]))
print(type(aqad_test_ids[0]))
# Out:
# <class 'int'>
# <class 'int'>

# %%
#train_encodings.update({'IDs':torch.tensor(train_ids)})
aqad_val_encodings.update({'IDs':torch.tensor(aqad_val_ids)})
aqad_test_encodings.update({'IDs':torch.tensor(aqad_test_ids)})
arcd_test_encodings.update({'IDs':torch.tensor(arcd_test_ids)})

#train_encodings['IDs'] = train_encodings['IDs'].view(len(train_contexts), 1)
aqad_val_encodings['IDs'] = aqad_val_encodings['IDs'].view(len(aqad_val_contexts), 1)
aqad_test_encodings['IDs'] = aqad_test_encodings['IDs'].view(len(aqad_test_contexts), 1)
arcd_test_encodings['IDs'] = arcd_test_encodings['IDs'].view(len(arcd_test_contexts), 1)

# %% [markdown]
# ## Dataset and Dataloader

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from tqdm import tqdm

# %%
class AqadDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings
    def __getitem__(self, idx):
        return {key: val[idx] for key, val in self.encodings.items()}

    def __len__(self):
        return len(self.encodings.input_ids)

train_dataset = AqadDataset(train_encodings)
aqad_val_dataset = AqadDataset(aqad_val_encodings)
aqad_test_dataset = AqadDataset(aqad_test_encodings)
arcd_test_dataset = AqadDataset(arcd_test_encodings)

# %%
data_collator = DataCollatorWithPadding(araelectra_tokenizer)

# %%
train_loader = DataLoader(train_dataset, batch_size=8, shuffle= True, collate_fn= data_collator)
aqad_val_loader = DataLoader(aqad_val_dataset, batch_size = 8, shuffle = True, collate_fn = data_collator)
aqad_test_loader = DataLoader(aqad_test_dataset, batch_size = 8, shuffle = True, collate_fn = data_collator)
arcd_test_loader = DataLoader(arcd_test_dataset, batch_size = 8, shuffle = True, collate_fn = data_collator)

# %%
for step, batch in enumerate(train_loader):
    print(batch['input_ids'].shape)
    print(batch.keys())
    if step>1:
        break
# Out:
# torch.Size([8, 402])
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask', 'start_positions', 'end_positions'])
# torch.Size([8, 184])
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask', 'start_positions', 'end_positions'])
# torch.Size([8, 411])
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask', 'start_positions', 'end_positions'])

# %% [markdown]
# ## Checkpoint Saving and Loading

# %%
def save_ckp(state, is_best, checkpoint_path, best_model_path):
    """
    state: checkpoint to save
    is_best: is this the best checkpoint; min validation loss
    checkpoint_path: path to save checkpoint
    best_model_path: path to save best checkpoint
    """
    f_path = checkpoint_path
    # save checkpoint data to the path given, checkpoint_path
    torch.save(state, f_path)
    # if it is a best model, min validation loss
    if is_best:
        best_fpath = best_model_path
        # copy that checkpoint file to best path given, best_model_path
        shutil.copyfile(f_path, best_fpath)

# %%
def load_ckp(checkpoint_fpath, model, optimizer):
    """
    checkpoint_path: path to saved checkpoint
    model: model to load checkpoint parameters into       
    optimizer: optimizer defined in previous training
    """
    # load check point
    checkpoint = torch.load(checkpoint_fpath)
    # initialize state_dict from checkpoint to model
    model.load_state_dict(checkpoint['state_dict'])
    # initialize optimizer from checkpoint to optimizer
    optimizer.load_state_dict(checkpoint['optimizer'])
    # initialize valid_loss_min from checkpoint to valid_loss_min
    results = checkpoint['result_dict']
    # return model, optimizer, epoch value, min validation loss 
    return model, optimizer, checkpoint['epoch'], results

# %%
def order_exp(base_path, exp_name):
  exp_path = os.path.join(base_path, exp_name)
  if not os.path.exists(exp_path):
    os.mkdir(exp_path)
  curr_ckp_path = os.path.join(exp_path,'curr.pt')
  best_ckp_path = os.path.join(exp_path, 'best.pt')
  return curr_ckp_path, best_ckp_path, exp_path

# %% [markdown]
# ## Evaluate SQuAD

# %%
from __future__ import print_function
from collections import Counter
import string
import re
import argparse
import json
import sys
import nltk
import random
nltk.download('punkt')
def normalize_answer(s):
    """Lower text and remove punctuation, articles and extra whitespace."""
    def remove_articles(text):
        return re.sub(r'\b(a|an|the)\b', ' ', text)

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return ''.join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))


def f1_score(prediction, ground_truth):
    prediction_tokens = normalize_answer(prediction).split()
    ground_truth_tokens = normalize_answer(ground_truth).split()
    common = Counter(prediction_tokens) & Counter(ground_truth_tokens)
    num_same = sum(common.values())
    if num_same == 0:
        return 0
    precision = 1.0 * num_same / len(prediction_tokens)
    recall = 1.0 * num_same / len(ground_truth_tokens)
    f1 = (2 * precision * recall) / (precision + recall)
    return f1


def exact_match_score(prediction, ground_truth):
    return (normalize_answer(prediction) == normalize_answer(ground_truth))


def metric_max_over_ground_truths(metric_fn, prediction, ground_truths):
    scores_for_ground_truths = []
    for ground_truth in ground_truths:
        score = metric_fn(prediction, ground_truth)
        scores_for_ground_truths.append(score)
    return max(scores_for_ground_truths)

def evaluate_squad(dataset, predictions):
    f1 = exact_match = total = exact_sentence = inclusion = random = 0
    f1_ans = exact_match_ans = total_ans = exact_sentence_ans  = 0
    f1_noans = exact_match_noans = total_noans = exact_sentence_noans = 0
    for article in dataset:
        for paragraph in article['paragraphs']:
            for qa in paragraph['qas']:
                flag = False
                total += 1
                if int(qa['id']) not in predictions:
                    message = 'Unanswered question ' + str(qa['id']) + \
                              ' will receive score 0.'
                    print(message, file=sys.stderr)
                    continue
                ground_truths = list(map(lambda x: arabert_prep.preprocess(x['text']), qa['answers']))
                #print(type(ground_truths))
                if len(ground_truths)==0:
                    flag = True
                    total_noans +=1
                else:
                    total_ans+=1
                if flag:
                    ground_truths = list(map(lambda x: arabert_prep.preprocess(x['text']), qa['plausible_answers']))
                prediction = predictions[qa['id']]
                sents = nltk.sent_tokenize(arabert_prep.preprocess(paragraph['context']))
                indx_g = -1
                indx_p = -1
                i = 0
                for sent in sents:
                    if sent.find(ground_truths[0]) != -1:
                        indx_g = i
                    if sent.find(prediction) != -1:
                        indx_p = i
                    i += 1
                if prediction.find(ground_truths[0]) != -1 or ground_truths[0].find(prediction):
                    inclusion += 1
                if indx_g == indx_p and indx_p != -1:
                    exact_sentence += 1
                    if flag:
                        exact_sentence_noans+=1
                    else:
                        exact_sentence_ans+=1

                curr_exact_match= metric_max_over_ground_truths(
                    exact_match_score, prediction, ground_truths)
                curr_f1 = metric_max_over_ground_truths(
                    f1_score, prediction, ground_truths)
                if flag:
                    f1_noans+=curr_f1
                    exact_match_noans+=curr_exact_match
                else:
                    f1_ans+=curr_f1
                    exact_match_ans+=curr_exact_match
                f1+=curr_f1
                exact_match+=curr_exact_match
    print(f"total examples {total}, total have answers {total_ans} total have no answers {total_noans}")
    exact_sentence = 100 * exact_sentence / total
    exact_match = 100.0 * exact_match / total
    f1 = 100.0 * f1 / total
    if total_ans!=0:
        exact_sentence_ans = 100 * exact_sentence_ans / total_ans
        exact_match_ans = 100.0 * exact_match_ans / total_ans
        f1_ans = 100.0 * f1_ans / total_ans
    if total_noans !=0:
        exact_sentence_noans = 100 * exact_sentence_noans / total_noans
        exact_match_noans = 100.0 * exact_match_noans / total_noans
        f1_noans = 100.0 * f1_noans / total_noans



    return {'exact_match': exact_match, 'f1': f1, 'exact_sentence': exact_sentence,
    'exact_match_ans': exact_match_ans, 'f1_ans': f1_ans, 'exact_sentence_ans': exact_match_ans,
    'exact_match_noans': exact_match_noans, 'f1_noans':f1_noans, 'exact_sentence_noans':exact_sentence_noans}


#evaluation
'''
predict_file_path = 'Data/AAQAD-test.json'
predictions_file_path = 'Predictions.json'
with open(predict_file_path) as dataset_file:
  dataset_json = json.load(dataset_file)
  dataset = dataset_json['data']
with open(predictions_file_path) as prediction_file:
  predictions = json.load(prediction_file)
print(json.dumps(evaluate(dataset, predictions)))'''
# Out:
# [nltk_data] Downloading package punkt to /home/azureuser/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# "\npredict_file_path = 'Data/AAQAD-test.json'\npredictions_file_path = 'Predictions.json'\nwith open(predict_file_path) as dataset_file:\n  dataset_json = json.load(dataset_file)\n  dataset = dataset_json['data']\nwith open(predictions_file_path) as prediction_file:\n  predictions = json.load(prediction_file)\nprint(json.dumps(evaluate(dataset, predictions)))"

# %%
def evaluate_squadv1(dataset, predictions):
    f1 = exact_match = total = exact_sentence = inclusion = random = 0
    for article in dataset:
        for paragraph in article['paragraphs']:
            for qa in paragraph['qas']:
                total += 1
                if int(qa['id']) not in predictions:
                    message = 'Unanswered question ' + str(qa['id']) + \
                              ' will receive score 0.'
                    print(message, file=sys.stderr)
                    continue
                ground_truths = list(map(lambda x: x['text'], qa['answers']))
                if len(ground_truths)==0:
                    total -=1
                    continue
                prediction = predictions[qa['id']]
                sents = nltk.sent_tokenize(paragraph['context'])
                indx_g = -1
                indx_p = -1
                i = 0
                for sent in sents:
                    if sent.find(ground_truths[0]) != -1:
                        indx_g = i
                    if sent.find(prediction) != -1:
                        indx_p = i
                    i += 1
                if prediction.find(ground_truths[0]) != -1 or ground_truths[0].find(prediction):
                    inclusion += 1
                if indx_g == indx_p and indx_p != -1:
                    exact_sentence += 1
                exact_match += metric_max_over_ground_truths(
                    exact_match_score, prediction, ground_truths)
                f1 += metric_max_over_ground_truths(
                    f1_score, prediction, ground_truths)
    exact_sentence = 100 * exact_sentence / total
    exact_match = 100.0 * exact_match / total
    f1 = 100.0 * f1 / total
    print('Exact Match {exact_match}, f1 Score {f1}, Same Sentence {exact_sentence} total {total}')
    return {'exact_match': exact_match, 'f1': f1, 'exact_sentence': exact_sentence}

# %%
print('yes')
# !pwd
torch.randn(3)
# Out:
# yes
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/youssefgpu/code/Users/Ziyad2018170918/GP/Arabic-MRC
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-28f61207737a> in <module>
#       1 print('yes')
#       2 get_ipython().system('pwd')
# ----> 3 torch.randn(3)
#
# NameError: name 'torch' is not defined

# %% [markdown]
# ## Evaluate and Train functions

# %%
def evaluate(data_loader, model, log, log_path=None, train_loss=None): 
  model.eval()
  with torch.no_grad():
    #F1 = EM = Total = 0
    total_loss = 0.0
    total_predictions = dict()
    #loop = tqdm(data_loader)
    #loop = tqdm(data_loader, leave=True)
    for batch_idx, batch in enumerate(data_loader):
      #moving tensors to gpu    
      tokens = batch['input_ids'].to(device)
      masks = batch['attention_mask'].to(device)
      tokens_type = batch['token_type_ids'].to(device)
      gt_start = batch['start_positions'].to(device)
      gt_end = batch['end_positions'].to(device)
      IDs = batch['IDs'].to(device)
      outputs = model(tokens, masks, tokens_type, start_positions=gt_start, end_positions=gt_end)
      #calculating loss
      loss = outputs.loss
      #update average total loss 
      total_loss = total_loss + ((1 / (batch_idx + 1)) * (loss - total_loss)) 
      #calculating f1 score and EM
      curr_batch_size = gt_start.shape[0]
      #print(curr_batch_size)
      for i in range(curr_batch_size):
        #print(f"this is tensor index {i}")
        start_gt, end_gt = batch['start_positions'][i], batch['end_positions'][i]
        start_pred, end_pred = torch.argmax(outputs.start_logits[i],dim=0), torch.argmax(outputs.end_logits[i],dim =0)
        total_predictions[IDs[i].item()] = araelectra_tokenizer.decode(tokens[i][start_pred.item():end_pred.item()], skip_special_tokens=True, clean_up_tokenization_spaces=True)
    #saving evaluation results
    #evaluation
    #print(total_predictions[5539])
    with open('Data/AAQAD-dev.json') as dataset_file:
        dataset_json = json.load(dataset_file)
        dataset = dataset_json['data']
    result_dict = evaluate_squad(dataset, total_predictions)
    result_dictv1 = evaluate_squadv1(dataset, total_predictions)
    try:
        result_dict['train_loss'] = train_loss.item()
        result_dict['val_loss'] = total_loss.item()
    except:
        pass
    print(type(result_dict))
    print(result_dict)
    #print(json.dumps(result_dict))
    if(log):
      log_path = os.path.join(log_path,'res.csv')
      if not os.path.exists(log_path):
          with open(log_path,'w') as f:
            writer = csv.DictWriter(f, fieldnames=result_dict.keys())
            writer.writeheader()
      with open(log_path, 'a') as f:
        writer = csv.DictWriter(f, fieldnames=result_dict.keys())
        #writer.writeheader()
        writer.writerow(result_dict)
    model.train()
    return result_dict, result_dictv1

# %%
def train(model,start_epoch, num_epochs, optimizer,max_compined_metric, train_loader, val_loader, log, exp_name):
  curr_ckp_path, best_ckp_path, exp_path = order_exp('Runs/AraElectra_CombinedData/train', exp_name)
  model.train()
  for epoch in range(start_epoch,num_epochs):
    total_loss = 0.0
    loop = tqdm(train_loader, leave=True)
    for batch_idx, batch in enumerate(loop):
      tokens = batch['input_ids'].to(device)
      masks = batch['attention_mask'].to(device)
      tokens_type = batch['token_type_ids'].to(device)
      gt_start = batch['start_positions'].to(device)
      gt_end = batch['end_positions'].to(device)
      outputs = model(tokens, masks, tokens_type, start_positions=gt_start, end_positions=gt_end)
      loss = outputs.loss
      loss.backward()
      optimizer.step()
      optimizer.zero_grad()
      total_loss = total_loss + ((1 / (batch_idx + 1)) * (loss - total_loss)) 
      loop.set_description(f'Epoch {epoch}')
      loop.set_postfix(loss=loss.item())

    result_dict = evaluate(val_loader, model , log, exp_path, total_loss)
    checkpoint = {
            'epoch': epoch + 1,
            'result_dict':result_dict,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict(),
        }
    curr_compined_metric = result_dict['exact_match']+1.5*result_dict['f1']+0.7*result_dict['exact_sentence']
    if curr_compined_metric>=max_compined_metric:
      max_compined_metric = curr_compined_metric
      save_ckp(checkpoint, True, curr_ckp_path, best_ckp_path)
    else:
      save_ckp(checkpoint, False, curr_ckp_path, best_ckp_path)
  return model

# %% [markdown]
# ## Modeling

# %%
def freeze(Electra, count=None):
    if count is not None:
	      # We freeze here the embeddings of the model
        for param in Electra.electra.embeddings.parameters():
            param.requires_grad = False

        if count != -1:
	          # if freeze_layer_count == -1, we only freeze the embedding layer
	          # otherwise we freeze the first `freeze_layer_count` encoder layers
            for layer in Electra.electra.encoder.layer[:count]:
                for param in layer.parameters():
                    param.requires_grad = False
    print(sum(p.numel() for p in Electra.parameters()), sum(p.numel() for p in Electra.parameters() if p.requires_grad))

# %%
QA_AraElectra = ElectraForQuestionAnswering.from_pretrained(model_name)
freeze(QA_AraElectra, 4)
# Out:
# Some weights of the model checkpoint at aubmindlab/araelectra-base-discriminator were not used when initializing ElectraForQuestionAnswering: ['discriminator_predictions.dense.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense_prediction.bias']
# - This IS expected if you are initializing ElectraForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForQuestionAnswering were not initialized from the model checkpoint at aubmindlab/araelectra-base-discriminator and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 134604290 56704514

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
QA_AraElectra.to(device)
# Out:
# ElectraForQuestionAnswering(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(64000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (qa_outputs): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
device
# Out:
# device(type='cuda')

# %%
num_epochs = 2
learning_rate = 3e-5
optimizer = torch.optim.AdamW(QA_AraElectra.parameters(), lr=learning_rate)
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
QA_AraElectra.to(device)
# Out:
# ElectraForQuestionAnswering(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(64000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (qa_outputs): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
trained_model = train(QA_AraElectra, 0, num_epochs, optimizer, 0, train_loader, aqad_val_loader,True, 'firstFreeze4AdamW')
# Out:
# Epoch 0: 100%|██████████| 7709/7709 [1:23:25<00:00,  1.54it/s, loss=2.72]
# Epoch 1: 100%|██████████| 7709/7709 [1:23:35<00:00,  1.54it/s, loss=0.806]
# 179
# total examples 1926, total have answers 1193 total have no answers 733
# 416
# <class 'dict'>
# {'exact_match': 3.790238836967809, 'f1': 22.611938207877447, 'exact_sentence': 57.11318795430945, 'exact_match_ans': 4.694048616932104, 'f1_ans': 25.984081185595617, 'exact_sentence_ans': 4.694048616932104, 'exact_match_noans': 2.319236016371078, 'f1_noans': 17.123579991754934, 'exact_sentence_noans': 56.75306957708049, 'train_loss': 2.4689888954162598, 'val_loss': 2.9085168838500977}
# 179
# total examples 1926, total have answers 1193 total have no answers 733
# 443
# <class 'dict'>
# {'exact_match': 3.6863966770508827, 'f1': 24.435995525849044, 'exact_sentence': 59.345794392523366, 'exact_match_ans': 4.861693210393965, 'f1_ans': 27.79402539149263, 'exact_sentence_ans': 4.861693210393965, 'exact_match_noans': 1.7735334242837653, 'f1_noans': 18.970607217918772, 'exact_sentence_noans': 60.43656207366985, 'train_loss': 1.9735907316207886, 'val_loss': 2.9121501445770264}

# %% [markdown]
# ## Validate using SQuADv1

# %%
loadedModel, loadedOptime, a, b = load_ckp('Runs/AraElectra_CombinedData/train/firstFreeze4AdamW/best.pt', QA_AraElectra, optimizer)

# %%
resv2, resv1 = evaluate(aqad_val_loader,loadedModel,False,None,None )
# Out:
# 179
# total examples 1926, total have answers 1193 total have no answers 733
# 443
# Exact Match {exact_match}, f1 Score {f1}, Same Sentence {exact_sentence} total {total}
# <class 'dict'>
# {'exact_match': 3.6863966770508827, 'f1': 24.435995525849044, 'exact_sentence': 59.345794392523366, 'exact_match_ans': 4.861693210393965, 'f1_ans': 27.79402539149263, 'exact_sentence_ans': 4.861693210393965, 'exact_match_noans': 1.7735334242837653, 'f1_noans': 18.970607217918772, 'exact_sentence_noans': 60.43656207366985}

# %%
resv1
# Out:
# {'exact_match': 4.442581726739313,
#  'f1': 24.117430584141715,
#  'exact_sentence': 48.44928751047779}

# %%
resv2, resv1 = evaluate(arcd_test_loader,loadedModel,False,None,None )
# Out:
# Unanswered question 16780 will receive score 0.
# Unanswered question 16781 will receive score 0.
# Unanswered question 16782 will receive score 0.
# Unanswered question 16783 will receive score 0.
# Unanswered question 16784 will receive score 0.
# Unanswered question 16785 will receive score 0.
# Unanswered question 16786 will receive score 0.
# Unanswered question 16787 will receive score 0.
# Unanswered question 16788 will receive score 0.
# Unanswered question 16789 will receive score 0.
# Unanswered question 16790 will receive score 0.
# Unanswered question 16791 will receive score 0.
# Unanswered question 16792 will receive score 0.
# Unanswered question 16793 will receive score 0.
# Unanswered question 16794 will receive score 0.
# Unanswered question 16795 will receive score 0.
# Unanswered question 16796 will receive score 0.
# Unanswered question 16797 will receive score 0.
# Unanswered question 16798 will receive score 0.
# Unanswered question 16799 will receive score 0.
# Unanswered question 16800 will receive score 0.
# Unanswered question 16801 will receive score 0.
# Unanswered question 16802 will receive score 0.
# Unanswered question 16803 will receive score 0.
# Unanswered question 16804 will receive score 0.
# Unanswered question 16805 will receive score 0.
# Unanswered question 16806 will receive score 0.
# Unanswered question 16807 will receive score 0.
# Unanswered question 16808 will receive score 0.
# Unanswered question 16809 will receive score 0.
# Unanswered question 16810 will receive score 0.
# Unanswered question 16811 will receive score 0.
# Unanswered question 16812 will receive score 0.
# Unanswered question 16813 will receive score 0.
# Unanswered question 16814 will receive score 0.
# Unanswered question 16815 will receive score 0.
# Unanswered question 16816 will receive score 0.
# Unanswered question 16817 will receive score 0.
# Unanswered question 16818 will receive score 0.
# Unanswered question 16819 will receive score 0.
# Unanswered question 16820 will receive score 0.
# Unanswered question 16821 will receive score 0.
# Unanswered question 16822 will receive score 0.
# Unanswered question 16823 will receive score 0.
# Unanswered question 16824 will receive score 0.
# Unanswered question 16825 will receive score 0.
# Unanswered question 16826 will receive score 0.
# Unanswered question 16827 will receive score 0.
# Unanswered question 16828 will receive score 0.
# Unanswered question 16829 will receive score 0.
# Unanswered question 16830 will receive score 0.
# Unanswered question 16831 will receive score 0.
# Unanswered question 16832 will receive score 0.
# Unanswered question 16833 will receive score 0.
# Unanswered question 16834 will receive score 0.
# Unanswered question 16835 will receive score 0.
# Unanswered question 16836 will receive score 0.
# Unanswered question 16837 will receive score 0.
# Unanswered question 16838 will receive score 0.
# Unanswered question 16839 will receive score 0.
# Unanswered question 16840 will receive score 0.
# Unanswered question 16841 will receive score 0.
# Unanswered question 16842 will receive score 0.
# Unanswered question 16843 will receive score 0.
# Unanswered question 16844 will receive score 0.
# Unanswered question 16845 will receive score 0.
# Unanswered question 16846 will receive score 0.
# Unanswered question 16847 will receive score 0.
# Unanswered question 16848 will receive score 0.
# Unanswered question 16849 will receive score 0.
# Unanswered question 16850 will receive score 0.
# Unanswered question 16851 will receive score 0.
# Unanswered question 16852 will receive score 0.
# Unanswered question 16853 will receive score 0.
# Unanswered question 16854 will receive score 0.
# Unanswered question 16855 will receive score 0.
# Unanswered question 16856 will receive score 0.
# Unanswered question 16857 will receive score 0.
# Unanswered question 16858 will receive score 0.
# Unanswered question 16859 will receive score 0.
# Unanswered question 16860 will receive score 0.
# Unanswered question 16861 will receive score 0.
# Unanswered question 16862 will receive score 0.
# Unanswered question 16863 will receive score 0.
# Unanswered question 16864 will receive score 0.
# Unanswered question 16865 will receive score 0.
# Unanswered question 16866 will receive score 0.
# Unanswered question 16867 will receive score 0.
# Unanswered question 16868 will receive score 0.
# Unanswered question 16869 will receive score 0.
# Unanswered question 16870 will receive score 0.
# Unanswered question 16871 will receive score 0.
# Unanswered question 16872 will receive score 0.
# Unanswered question 16873 will receive score 0.
# Unanswered question 16874 will receive score 0.
# Unanswered question 16875 will receive score 0.
# Unanswered question 16876 will receive score 0.
# Unanswered question 16877 will receive score 0.
# Unanswered question 16878 will receive score 0.
# Unanswered question 16879 will receive score 0.
# Unanswered question 16880 will receive score 0.
# Unanswered question 16881 will receive score 0.
# Unanswered question 16882 will receive score 0.
# Unanswered question 16883 will receive score 0.
# Unanswered question 16884 will receive score 0.
# Unanswered question 16885 will receive score 0.
# Unanswered question 16886 will receive score 0.
# Unanswered question 16887 will receive score 0.
# Unanswered question 16888 will receive score 0.
# Unanswered question 16889 will receive score 0.
# Unanswered question 16890 will receive score 0.
# Unanswered question 16891 will receive score 0.
# Unanswered question 16892 will receive score 0.
# Unanswered question 16893 will receive score 0.
# Unanswered question 16894 will receive score 0.
# Unanswered question 16895 will receive score 0.
# Unanswered question 16896 will receive score 0.
# Unanswered question 16897 will receive score 0.
# Unanswered question 16898 will receive score 0.
# Unanswered question 16899 will receive score 0.
# Unanswered question 16900 will receive score 0.
# Unanswered question 16901 will receive score 0.
# Unanswered question 16902 will receive score 0.
# Unanswered question 16903 will receive score 0.
# Unanswered question 16904 will receive score 0.
# Unanswered question 16905 will receive score 0.
# Unanswered question 16906 will receive score 0.
# Unanswered question 16907 will receive score 0.
# Unanswered question 16908 will receive score 0.
# Unanswered question 16909 will receive score 0.
# Unanswered question 16910 will receive score 0.
# Unanswered question 16911 will receive score 0.
# Unanswered question 16912 will receive score 0.
# Unanswered question 16913 will receive score 0.
# Unanswered question 16914 will receive score 0.
# Unanswered question 16915 will receive score 0.
# Unanswered question 16916 will receive score 0.
# Unanswered question 16917 will receive score 0.
# Unanswered question 16918 will receive score 0.
# Unanswered question 16919 will receive score 0.
# Unanswered question 16920 will receive score 0.
# Unanswered question 16921 will receive score 0.
# Unanswered question 16922 will receive score 0.
# Unanswered question 16923 will receive score 0.
# Unanswered question 16924 will receive score 0.
# Unanswered question 16925 will receive score 0.
# Unanswered question 16926 will receive score 0.
# Unanswered question 16927 will receive score 0.
# Unanswered question 16928 will receive score 0.
# Unanswered question 16929 will receive score 0.
# Unanswered question 16930 will receive score 0.
# Unanswered question 16931 will receive score 0.
# Unanswered question 16932 will receive score 0.
# Unanswered question 16933 will receive score 0.
# Unanswered question 16934 will receive score 0.
# Unanswered question 16935 will receive score 0.
# Unanswered question 16936 will receive score 0.
# Unanswered question 16937 will receive score 0.
# Unanswered question 16938 will receive score 0.
# Unanswered question 16939 will receive score 0.
# Unanswered question 16940 will receive score 0.
# Unanswered question 16941 will receive score 0.
# Unanswered question 16942 will receive score 0.
# Unanswered question 16943 will receive score 0.
# Unanswered question 16944 will receive score 0.
# Unanswered question 16945 will receive score 0.
# Unanswered question 16946 will receive score 0.
# Unanswered question 16947 will receive score 0.
# Unanswered question 16948 will receive score 0.
# Unanswered question 16949 will receive score 0.
# Unanswered question 16950 will receive score 0.
# Unanswered question 16951 will receive score 0.
# Unanswered question 16952 will receive score 0.
# Unanswered question 16953 will receive score 0.
# Unanswered question 16954 will receive score 0.
# Unanswered question 16955 will receive score 0.
# Unanswered question 16956 will receive score 0.
# Unanswered question 16957 will receive score 0.
# Unanswered question 16958 will receive score 0.
# Unanswered question 16959 will receive score 0.
# Unanswered question 16960 will receive score 0.
# Unanswered question 16961 will receive score 0.
# Unanswered question 16962 will receive score 0.
# Unanswered question 16963 will receive score 0.
# Unanswered question 16964 will receive score 0.
# Unanswered question 16965 will receive score 0.
# Unanswered question 16966 will receive score 0.
# Unanswered question 16967 will receive score 0.
# Unanswered question 16968 will receive score 0.
# Unanswered question 16969 will receive score 0.
# Unanswered question 16970 will receive score 0.
# Unanswered question 16971 will receive score 0.
# Unanswered question 16972 will receive score 0.
# Unanswered question 16973 will receive score 0.
# Unanswered question 16974 will receive score 0.
# Unanswered question 16975 will receive score 0.
# Unanswered question 16976 will receive score 0.
# Unanswered question 16977 will receive score 0.
# Unanswered question 16978 will receive score 0.
# Unanswered question 16979 will receive score 0.
# Unanswered question 16980 will receive score 0.
# Unanswered question 16981 will receive score 0.
# Unanswered question 16982 will receive score 0.
# Unanswered question 16983 will receive score 0.
# Unanswered question 16984 will receive score 0.
# Unanswered question 16985 will receive score 0.
# Unanswered question 16986 will receive score 0.
# Unanswered question 16987 will receive score 0.
# Unanswered question 16988 will receive score 0.
# Unanswered question 14695 will receive score 0.
# Unanswered question 14696 will receive score 0.
# Unanswered question 14697 will receive score 0.
# Unanswered question 14698 will receive score 0.
# Unanswered question 14699 will receive score 0.
# Unanswered question 14700 will receive score 0.
# Unanswered question 14701 will receive score 0.
# Unanswered question 14702 will receive score 0.
# Unanswered question 14703 will receive score 0.
# Unanswered question 14704 will receive score 0.
# Unanswered question 14705 will receive score 0.
# Unanswered question 14706 will receive score 0.
# Unanswered question 14707 will receive score 0.
# Unanswered question 14708 will receive score 0.
# Unanswered question 14709 will receive score 0.
# Unanswered question 14710 will receive score 0.
# Unanswered question 14711 will receive score 0.
# Unanswered question 14712 will receive score 0.
# Unanswered question 14713 will receive score 0.
# Unanswered question 14714 will receive score 0.
# Unanswered question 14715 will receive score 0.
# Unanswered question 14716 will receive score 0.
# Unanswered question 14717 will receive score 0.
# Unanswered question 14718 will receive score 0.
# Unanswered question 14719 will receive score 0.
# Unanswered question 14720 will receive score 0.
# Unanswered question 14721 will receive score 0.
# Unanswered question 14722 will receive score 0.
# Unanswered question 14723 will receive score 0.
# Unanswered question 14724 will receive score 0.
# Unanswered question 14725 will receive score 0.
# Unanswered question 14726 will receive score 0.
# Unanswered question 14727 will receive score 0.
# Unanswered question 14728 will receive score 0.
# Unanswered question 14729 will receive score 0.
# Unanswered question 14730 will receive score 0.
# Unanswered question 14731 will receive score 0.
# Unanswered question 14732 will receive score 0.
# Unanswered question 14733 will receive score 0.
# Unanswered question 14734 will receive score 0.
# Unanswered question 14735 will receive score 0.
# Unanswered question 14736 will receive score 0.
# Unanswered question 14737 will receive score 0.
# Unanswered question 14738 will receive score 0.
# Unanswered question 14739 will receive score 0.
# Unanswered question 14740 will receive score 0.
# Unanswered question 14741 will receive score 0.
# Unanswered question 14742 will receive score 0.
# Unanswered question 14743 will receive score 0.
# Unanswered question 14744 will receive score 0.
# Unanswered question 14745 will receive score 0.
# Unanswered question 14746 will receive score 0.
# Unanswered question 14747 will receive score 0.
# Unanswered question 14748 will receive score 0.
# Unanswered question 14749 will receive score 0.
# Unanswered question 14750 will receive score 0.
# Unanswered question 14751 will receive score 0.
# Unanswered question 14752 will receive score 0.
# Unanswered question 14753 will receive score 0.
# Unanswered question 14754 will receive score 0.
# Unanswered question 14755 will receive score 0.
# Unanswered question 14756 will receive score 0.
# Unanswered question 14757 will receive score 0.
# Unanswered question 14758 will receive score 0.
# Unanswered question 14759 will receive score 0.
# Unanswered question 14760 will receive score 0.
# Unanswered question 14761 will receive score 0.
# Unanswered question 14762 will receive score 0.
# Unanswered question 14763 will receive score 0.
# Unanswered question 14764 will receive score 0.
# Unanswered question 14765 will receive score 0.
# Unanswered question 14766 will receive score 0.
# Unanswered question 14767 will receive score 0.
# Unanswered question 14768 will receive score 0.
# Unanswered question 14769 will receive score 0.
# Unanswered question 14770 will receive score 0.
# Unanswered question 14771 will receive score 0.
# Unanswered question 14772 will receive score 0.
# Unanswered question 14773 will receive score 0.
# Unanswered question 14774 will receive score 0.
# Unanswered question 14775 will receive score 0.
# Unanswered question 14776 will receive score 0.
# Unanswered question 14777 will receive score 0.
# Unanswered question 14778 will receive score 0.
# Unanswered question 14779 will receive score 0.
# Unanswered question 14780 will receive score 0.
# Unanswered question 14781 will receive score 0.
# Unanswered question 14782 will receive score 0.
# Unanswered question 14783 will receive score 0.
# Unanswered question 14784 will receive score 0.
# Unanswered question 14785 will receive score 0.
# Unanswered question 14786 will receive score 0.
# Unanswered question 14787 will receive score 0.
# Unanswered question 14788 will receive score 0.
# Unanswered question 14789 will receive score 0.
# Unanswered question 14790 will receive score 0.
# Unanswered question 14791 will receive score 0.
# Unanswered question 14792 will receive score 0.
# Unanswered question 14793 will receive score 0.
# Unanswered question 14794 will receive score 0.
# Unanswered question 14795 will receive score 0.
# Unanswered question 14796 will receive score 0.
# Unanswered question 14797 will receive score 0.
# Unanswered question 14798 will receive score 0.
# Unanswered question 14799 will receive score 0.
# Unanswered question 14800 will receive score 0.
# Unanswered question 14801 will receive score 0.
# Unanswered question 14802 will receive score 0.
# Unanswered question 14803 will receive score 0.
# Unanswered question 14804 will receive score 0.
# Unanswered question 14805 will receive score 0.
# Unanswered question 14806 will receive score 0.
# Unanswered question 14807 will receive score 0.
# Unanswered question 14808 will receive score 0.
# Unanswered question 14809 will receive score 0.
# Unanswered question 14810 will receive score 0.
# Unanswered question 14811 will receive score 0.
# Unanswered question 14812 will receive score 0.
# Unanswered question 14813 will receive score 0.
# Unanswered question 14814 will receive score 0.
# Unanswered question 14815 will receive score 0.
# Unanswered question 14816 will receive score 0.
# Unanswered question 14817 will receive score 0.
# Unanswered question 14818 will receive score 0.
# Unanswered question 14819 will receive score 0.
# Unanswered question 14820 will receive score 0.
# Unanswered question 14821 will receive score 0.
# Unanswered question 14822 will receive score 0.
# Unanswered question 14823 will receive score 0.
# Unanswered question 14824 will receive score 0.
# Unanswered question 14825 will receive score 0.
# Unanswered question 14826 will receive score 0.
# Unanswered question 14827 will receive score 0.
# Unanswered question 14828 will receive score 0.
# Unanswered question 14829 will receive score 0.
# Unanswered question 14830 will receive score 0.
# Unanswered question 14831 will receive score 0.
# Unanswered question 14832 will receive score 0.
# Unanswered question 14833 will receive score 0.
# Unanswered question 14834 will receive score 0.
# Unanswered question 14835 will receive score 0.
# Unanswered question 14836 will receive score 0.
# Unanswered question 14837 will receive score 0.
# Unanswered question 14838 will receive score 0.
# Unanswered question 14839 will receive score 0.
# Unanswered question 14840 will receive score 0.
# Unanswered question 14841 will receive score 0.
# Unanswered question 14842 will receive score 0.
# Unanswered question 14843 will receive score 0.
# Unanswered question 14844 will receive score 0.
# Unanswered question 14845 will receive score 0.
# Unanswered question 14846 will receive score 0.
# Unanswered question 14847 will receive score 0.
# Unanswered question 14848 will receive score 0.
# Unanswered question 14849 will receive score 0.
# Unanswered question 14850 will receive score 0.
# Unanswered question 14851 will receive score 0.
# Unanswered question 14852 will receive score 0.
# Unanswered question 14853 will receive score 0.
# Unanswered question 14854 will receive score 0.
# Unanswered question 14855 will receive score 0.
# Unanswered question 14856 will receive score 0.
# Unanswered question 14857 will receive score 0.
# Unanswered question 14858 will receive score 0.
# Unanswered question 14859 will receive score 0.
# Unanswered question 14860 will receive score 0.
# Unanswered question 14861 will receive score 0.
# Unanswered question 14862 will receive score 0.
# Unanswered question 14863 will receive score 0.
# Unanswered question 14864 will receive score 0.
# Unanswered question 14865 will receive score 0.
# Unanswered question 14866 will receive score 0.
# Unanswered question 14867 will receive score 0.
# Unanswered question 14868 will receive score 0.
# Unanswered question 14869 will receive score 0.
# Unanswered question 14870 will receive score 0.
# Unanswered question 14871 will receive score 0.
# Unanswered question 14872 will receive score 0.
# Unanswered question 14873 will receive score 0.
# Unanswered question 14874 will receive score 0.
# Unanswered question 14875 will receive score 0.
# Unanswered question 14876 will receive score 0.
# Unanswered question 14877 will receive score 0.
# Unanswered question 14878 will receive score 0.
# Unanswered question 14879 will receive score 0.
# Unanswered question 14880 will receive score 0.
# Unanswered question 14881 will receive score 0.
# Unanswered question 14882 will receive score 0.
# Unanswered question 14883 will receive score 0.
# Unanswered question 14884 will receive score 0.
# Unanswered question 14885 will receive score 0.
# Unanswered question 14886 will receive score 0.
# Unanswered question 14887 will receive score 0.
# Unanswered question 14888 will receive score 0.
# Unanswered question 14889 will receive score 0.
# Unanswered question 14890 will receive score 0.
# Unanswered question 14891 will receive score 0.
# Unanswered question 14892 will receive score 0.
# Unanswered question 14893 will receive score 0.
# Unanswered question 14894 will receive score 0.
# Unanswered question 14895 will receive score 0.
# Unanswered question 14896 will receive score 0.
# Unanswered question 14897 will receive score 0.
# Unanswered question 14898 will receive score 0.
# Unanswered question 14899 will receive score 0.
# Unanswered question 14900 will receive score 0.
# Unanswered question 14901 will receive score 0.
# Unanswered question 14902 will receive score 0.
# Unanswered question 14903 will receive score 0.
# Unanswered question 14904 will receive score 0.
# Unanswered question 14905 will receive score 0.
# Unanswered question 14906 will receive score 0.
# Unanswered question 14907 will receive score 0.
# Unanswered question 14908 will receive score 0.
# Unanswered question 14909 will receive score 0.
# Unanswered question 14910 will receive score 0.
# Unanswered question 14911 will receive score 0.
# Unanswered question 14912 will receive score 0.
# Unanswered question 14913 will receive score 0.
# Unanswered question 14914 will receive score 0.
# Unanswered question 14915 will receive score 0.
# Unanswered question 14916 will receive score 0.
# Unanswered question 14917 will receive score 0.
# Unanswered question 14918 will receive score 0.
# Unanswered question 14919 will receive score 0.
# Unanswered question 14920 will receive score 0.
# Unanswered question 14921 will receive score 0.
# Unanswered question 14922 will receive score 0.
# Unanswered question 14923 will receive score 0.
# Unanswered question 14924 will receive score 0.
# Unanswered question 14925 will receive score 0.
# Unanswered question 14926 will receive score 0.
# Unanswered question 14927 will receive score 0.
# Unanswered question 14928 will receive score 0.
# Unanswered question 14929 will receive score 0.
# Unanswered question 14930 will receive score 0.
# Unanswered question 14931 will receive score 0.
# Unanswered question 14932 will receive score 0.
# Unanswered question 14933 will receive score 0.
# Unanswered question 14934 will receive score 0.
# Unanswered question 14935 will receive score 0.
# Unanswered question 14936 will receive score 0.
# Unanswered question 14937 will receive score 0.
# Unanswered question 14938 will receive score 0.
# Unanswered question 14939 will receive score 0.
# Unanswered question 14940 will receive score 0.
# Unanswered question 14941 will receive score 0.
# Unanswered question 5496 will receive score 0.
# Unanswered question 5497 will receive score 0.
# Unanswered question 5498 will receive score 0.
# Unanswered question 5499 will receive score 0.
# Unanswered question 5500 will receive score 0.
# Unanswered question 5501 will receive score 0.
# Unanswered question 5502 will receive score 0.
# Unanswered question 5503 will receive score 0.
# Unanswered question 5504 will receive score 0.
# Unanswered question 5505 will receive score 0.
# Unanswered question 5506 will receive score 0.
# Unanswered question 5507 will receive score 0.
# Unanswered question 5508 will receive score 0.
# Unanswered question 5509 will receive score 0.
# Unanswered question 5510 will receive score 0.
# Unanswered question 5511 will receive score 0.
# Unanswered question 5512 will receive score 0.
# Unanswered question 5513 will receive score 0.
# Unanswered question 5514 will receive score 0.
# Unanswered question 5515 will receive score 0.
# Unanswered question 5516 will receive score 0.
# Unanswered question 5517 will receive score 0.
# Unanswered question 5518 will receive score 0.
# Unanswered question 5519 will receive score 0.
# Unanswered question 5520 will receive score 0.
# Unanswered question 5521 will receive score 0.
# Unanswered question 5522 will receive score 0.
# Unanswered question 5523 will receive score 0.
# Unanswered question 5524 will receive score 0.
# Unanswered question 5525 will receive score 0.
# Unanswered question 5526 will receive score 0.
# Unanswered question 5527 will receive score 0.
# Unanswered question 5528 will receive score 0.
# Unanswered question 5529 will receive score 0.
# Unanswered question 5530 will receive score 0.
# Unanswered question 5531 will receive score 0.
# Unanswered question 5532 will receive score 0.
# Unanswered question 5533 will receive score 0.
# Unanswered question 5534 will receive score 0.
# Unanswered question 5535 will receive score 0.
# Unanswered question 5536 will receive score 0.
# Unanswered question 5537 will receive score 0.
# Unanswered question 5538 will receive score 0.
# Unanswered question 5539 will receive score 0.
# Unanswered question 5540 will receive score 0.
# Unanswered question 5541 will receive score 0.
# Unanswered question 5542 will receive score 0.
# Unanswered question 5543 will receive score 0.
# Unanswered question 5544 will receive score 0.
# Unanswered question 5545 will receive score 0.
# Unanswered question 5546 will receive score 0.
# Unanswered question 5547 will receive score 0.
# Unanswered question 5548 will receive score 0.
# Unanswered question 5549 will receive score 0.
# Unanswered question 5550 will receive score 0.
# Unanswered question 5551 will receive score 0.
# Unanswered question 5552 will receive score 0.
# Unanswered question 5553 will receive score 0.
# Unanswered question 5554 will receive score 0.
# Unanswered question 5555 will receive score 0.
# Unanswered question 5556 will receive score 0.
# Unanswered question 5557 will receive score 0.
# Unanswered question 5558 will receive score 0.
# Unanswered question 5559 will receive score 0.
# Unanswered question 5560 will receive score 0.
# Unanswered question 5561 will receive score 0.
# Unanswered question 5562 will receive score 0.
# Unanswered question 5563 will receive score 0.
# Unanswered question 5564 will receive score 0.
# Unanswered question 5565 will receive score 0.
# Unanswered question 5566 will receive score 0.
# Unanswered question 5567 will receive score 0.
# Unanswered question 5568 will receive score 0.
# Unanswered question 5569 will receive score 0.
# Unanswered question 5570 will receive score 0.
# Unanswered question 5571 will receive score 0.
# Unanswered question 5572 will receive score 0.
# Unanswered question 5573 will receive score 0.
# Unanswered question 5574 will receive score 0.
# Unanswered question 5575 will receive score 0.
# Unanswered question 5576 will receive score 0.
# Unanswered question 5577 will receive score 0.
# Unanswered question 5578 will receive score 0.
# Unanswered question 5579 will receive score 0.
# Unanswered question 5580 will receive score 0.
# Unanswered question 5581 will receive score 0.
# Unanswered question 5582 will receive score 0.
# Unanswered question 5583 will receive score 0.
# Unanswered question 5584 will receive score 0.
# Unanswered question 5585 will receive score 0.
# Unanswered question 5586 will receive score 0.
# Unanswered question 5587 will receive score 0.
# Unanswered question 5588 will receive score 0.
# Unanswered question 5589 will receive score 0.
# Unanswered question 5590 will receive score 0.
# Unanswered question 5591 will receive score 0.
# Unanswered question 5592 will receive score 0.
# Unanswered question 5593 will receive score 0.
# Unanswered question 5594 will receive score 0.
# Unanswered question 5595 will receive score 0.
# Unanswered question 5596 will receive score 0.
# Unanswered question 5597 will receive score 0.
# Unanswered question 5598 will receive score 0.
# Unanswered question 5599 will receive score 0.
# Unanswered question 5600 will receive score 0.
# Unanswered question 5601 will receive score 0.
# Unanswered question 5602 will receive score 0.
# Unanswered question 5603 will receive score 0.
# Unanswered question 5604 will receive score 0.
# Unanswered question 5605 will receive score 0.
# Unanswered question 5606 will receive score 0.
# Unanswered question 5607 will receive score 0.
# Unanswered question 5608 will receive score 0.
# Unanswered question 5609 will receive score 0.
# Unanswered question 5610 will receive score 0.
# Unanswered question 5611 will receive score 0.
# Unanswered question 5612 will receive score 0.
# Unanswered question 5613 will receive score 0.
# Unanswered question 5614 will receive score 0.
# Unanswered question 5615 will receive score 0.
# Unanswered question 5616 will receive score 0.
# Unanswered question 5617 will receive score 0.
# Unanswered question 5618 will receive score 0.
# Unanswered question 5619 will receive score 0.
# Unanswered question 5620 will receive score 0.
# Unanswered question 5621 will receive score 0.
# Unanswered question 5622 will receive score 0.
# Unanswered question 5623 will receive score 0.
# Unanswered question 5624 will receive score 0.
# Unanswered question 5625 will receive score 0.
# Unanswered question 5626 will receive score 0.
# Unanswered question 5627 will receive score 0.
# Unanswered question 5628 will receive score 0.
# Unanswered question 5629 will receive score 0.
# Unanswered question 5630 will receive score 0.
# Unanswered question 5631 will receive score 0.
# Unanswered question 5632 will receive score 0.
# Unanswered question 5633 will receive score 0.
# Unanswered question 5634 will receive score 0.
# Unanswered question 5635 will receive score 0.
# Unanswered question 5636 will receive score 0.
# Unanswered question 5637 will receive score 0.
# Unanswered question 5638 will receive score 0.
# Unanswered question 5639 will receive score 0.
# Unanswered question 5640 will receive score 0.
# Unanswered question 5641 will receive score 0.
# Unanswered question 5642 will receive score 0.
# Unanswered question 5643 will receive score 0.
# Unanswered question 5644 will receive score 0.
# Unanswered question 5645 will receive score 0.
# Unanswered question 5646 will receive score 0.
# Unanswered question 5647 will receive score 0.
# Unanswered question 5648 will receive score 0.
# Unanswered question 5649 will receive score 0.
# Unanswered question 5650 will receive score 0.
# Unanswered question 5651 will receive score 0.
# Unanswered question 5652 will receive score 0.
# Unanswered question 5653 will receive score 0.
# Unanswered question 5654 will receive score 0.
# Unanswered question 5655 will receive score 0.
# Unanswered question 5656 will receive score 0.
# Unanswered question 5657 will receive score 0.
# Unanswered question 5658 will receive score 0.
# Unanswered question 5659 will receive score 0.
# Unanswered question 5660 will receive score 0.
# Unanswered question 5661 will receive score 0.
# Unanswered question 5662 will receive score 0.
# Unanswered question 5663 will receive score 0.
# Unanswered question 5664 will receive score 0.
# Unanswered question 5665 will receive score 0.
# Unanswered question 5666 will receive score 0.
# Unanswered question 5667 will receive score 0.
# Unanswered question 5668 will receive score 0.
# Unanswered question 5669 will receive score 0.
# Unanswered question 5670 will receive score 0.
# Unanswered question 5671 will receive score 0.
# Unanswered question 5672 will receive score 0.
# Unanswered question 5673 will receive score 0.
# Unanswered question 5674 will receive score 0.
# Unanswered question 5675 will receive score 0.
# Unanswered question 5676 will receive score 0.
# Unanswered question 5677 will receive score 0.
# Unanswered question 5678 will receive score 0.
# Unanswered question 5679 will receive score 0.
# Unanswered question 5680 will receive score 0.
# Unanswered question 5681 will receive score 0.
# Unanswered question 5682 will receive score 0.
# Unanswered question 5683 will receive score 0.
# Unanswered question 5684 will receive score 0.
# Unanswered question 5685 will receive score 0.
# Unanswered question 5686 will receive score 0.
# Unanswered question 5687 will receive score 0.
# Unanswered question 5688 will receive score 0.
# Unanswered question 5689 will receive score 0.
# Unanswered question 5690 will receive score 0.
# Unanswered question 5691 will receive score 0.
# Unanswered question 5692 will receive score 0.
# Unanswered question 5693 will receive score 0.
# Unanswered question 5694 will receive score 0.
# Unanswered question 5695 will receive score 0.
# Unanswered question 5696 will receive score 0.
# Unanswered question 17395 will receive score 0.
# Unanswered question 17396 will receive score 0.
# Unanswered question 17397 will receive score 0.
# Unanswered question 17398 will receive score 0.
# Unanswered question 17399 will receive score 0.
# Unanswered question 17400 will receive score 0.
# Unanswered question 17401 will receive score 0.
# Unanswered question 17402 will receive score 0.
# Unanswered question 17403 will receive score 0.
# Unanswered question 17404 will receive score 0.
# Unanswered question 17405 will receive score 0.
# Unanswered question 17406 will receive score 0.
# Unanswered question 17407 will receive score 0.
# Unanswered question 17408 will receive score 0.
# Unanswered question 17409 will receive score 0.
# Unanswered question 17410 will receive score 0.
# Unanswered question 17411 will receive score 0.
# Unanswered question 17412 will receive score 0.
# Unanswered question 17413 will receive score 0.
# Unanswered question 17414 will receive score 0.
# Unanswered question 17415 will receive score 0.
# Unanswered question 17416 will receive score 0.
# Unanswered question 17417 will receive score 0.
# Unanswered question 17418 will receive score 0.
# Unanswered question 17419 will receive score 0.
# Unanswered question 17420 will receive score 0.
# Unanswered question 17421 will receive score 0.
# Unanswered question 17422 will receive score 0.
# Unanswered question 17423 will receive score 0.
# Unanswered question 17424 will receive score 0.
# Unanswered question 17425 will receive score 0.
# Unanswered question 17426 will receive score 0.
# Unanswered question 17427 will receive score 0.
# Unanswered question 17428 will receive score 0.
# Unanswered question 17429 will receive score 0.
# Unanswered question 17430 will receive score 0.
# Unanswered question 17431 will receive score 0.
# Unanswered question 17432 will receive score 0.
# Unanswered question 17433 will receive score 0.
# Unanswered question 17434 will receive score 0.
# Unanswered question 17435 will receive score 0.
# Unanswered question 17436 will receive score 0.
# Unanswered question 17437 will receive score 0.
# Unanswered question 17438 will receive score 0.
# Unanswered question 17439 will receive score 0.
# Unanswered question 17440 will receive score 0.
# Unanswered question 17441 will receive score 0.
# Unanswered question 17442 will receive score 0.
# Unanswered question 17443 will receive score 0.
# Unanswered question 17444 will receive score 0.
# Unanswered question 17445 will receive score 0.
# Unanswered question 17446 will receive score 0.
# Unanswered question 17447 will receive score 0.
# Unanswered question 17448 will receive score 0.
# Unanswered question 17449 will receive score 0.
# Unanswered question 17450 will receive score 0.
# Unanswered question 17451 will receive score 0.
# Unanswered question 17452 will receive score 0.
# Unanswered question 17453 will receive score 0.
# Unanswered question 17454 will receive score 0.
# Unanswered question 17455 will receive score 0.
# Unanswered question 17456 will receive score 0.
# Unanswered question 17457 will receive score 0.
# Unanswered question 17458 will receive score 0.
# Unanswered question 17459 will receive score 0.
# Unanswered question 17460 will receive score 0.
# Unanswered question 17461 will receive score 0.
# Unanswered question 17462 will receive score 0.
# Unanswered question 17463 will receive score 0.
# Unanswered question 17464 will receive score 0.
# Unanswered question 17465 will receive score 0.
# Unanswered question 17466 will receive score 0.
# Unanswered question 17467 will receive score 0.
# Unanswered question 17468 will receive score 0.
# Unanswered question 17469 will receive score 0.
# Unanswered question 17470 will receive score 0.
# Unanswered question 17471 will receive score 0.
# Unanswered question 17472 will receive score 0.
# Unanswered question 17473 will receive score 0.
# Unanswered question 17474 will receive score 0.
# Unanswered question 17475 will receive score 0.
# Unanswered question 17476 will receive score 0.
# Unanswered question 17477 will receive score 0.
# Unanswered question 17478 will receive score 0.
# Unanswered question 17479 will receive score 0.
# Unanswered question 17480 will receive score 0.
# Unanswered question 17481 will receive score 0.
# Unanswered question 17482 will receive score 0.
# Unanswered question 17483 will receive score 0.
# Unanswered question 17484 will receive score 0.
# Unanswered question 17485 will receive score 0.
# Unanswered question 17486 will receive score 0.
# Unanswered question 17487 will receive score 0.
# Unanswered question 17488 will receive score 0.
# Unanswered question 17489 will receive score 0.
# Unanswered question 17490 will receive score 0.
# Unanswered question 17491 will receive score 0.
# Unanswered question 17492 will receive score 0.
# Unanswered question 17493 will receive score 0.
# Unanswered question 17494 will receive score 0.
# Unanswered question 17495 will receive score 0.
# Unanswered question 17496 will receive score 0.
# Unanswered question 17497 will receive score 0.
# Unanswered question 17498 will receive score 0.
# Unanswered question 17499 will receive score 0.
# Unanswered question 17500 will receive score 0.
# Unanswered question 17501 will receive score 0.
# Unanswered question 17502 will receive score 0.
# Unanswered question 17503 will receive score 0.
# Unanswered question 17504 will receive score 0.
# Unanswered question 17505 will receive score 0.
# Unanswered question 17506 will receive score 0.
# Unanswered question 17507 will receive score 0.
# Unanswered question 17508 will receive score 0.
# Unanswered question 17509 will receive score 0.
# Unanswered question 17510 will receive score 0.
# Unanswered question 17511 will receive score 0.
# Unanswered question 17512 will receive score 0.
# Unanswered question 17513 will receive score 0.
# Unanswered question 17514 will receive score 0.
# Unanswered question 17515 will receive score 0.
# Unanswered question 17516 will receive score 0.
# Unanswered question 17517 will receive score 0.
# Unanswered question 17518 will receive score 0.
# Unanswered question 17519 will receive score 0.
# Unanswered question 17520 will receive score 0.
# Unanswered question 17521 will receive score 0.
# Unanswered question 17522 will receive score 0.
# Unanswered question 17523 will receive score 0.
# Unanswered question 17524 will receive score 0.
# Unanswered question 17525 will receive score 0.
# Unanswered question 17526 will receive score 0.
# Unanswered question 17527 will receive score 0.
# Unanswered question 17528 will receive score 0.
# Unanswered question 17529 will receive score 0.
# Unanswered question 17530 will receive score 0.
# Unanswered question 17531 will receive score 0.
# Unanswered question 17532 will receive score 0.
# Unanswered question 17533 will receive score 0.
# Unanswered question 17534 will receive score 0.
# Unanswered question 17535 will receive score 0.
# Unanswered question 17536 will receive score 0.
# Unanswered question 17537 will receive score 0.
# Unanswered question 17538 will receive score 0.
# Unanswered question 17539 will receive score 0.
# Unanswered question 17540 will receive score 0.
# Unanswered question 17541 will receive score 0.
# Unanswered question 17542 will receive score 0.
# Unanswered question 17543 will receive score 0.
# Unanswered question 17544 will receive score 0.
# Unanswered question 17545 will receive score 0.
# Unanswered question 17546 will receive score 0.
# Unanswered question 17547 will receive score 0.
# Unanswered question 17548 will receive score 0.
# Unanswered question 17549 will receive score 0.
# Unanswered question 17550 will receive score 0.
# Unanswered question 17551 will receive score 0.
# Unanswered question 17552 will receive score 0.
# Unanswered question 17553 will receive score 0.
# Unanswered question 17554 will receive score 0.
# Unanswered question 17555 will receive score 0.
# Unanswered question 17556 will receive score 0.
# Unanswered question 17557 will receive score 0.
# Unanswered question 17558 will receive score 0.
# Unanswered question 17559 will receive score 0.
# Unanswered question 17560 will receive score 0.
# Unanswered question 17561 will receive score 0.
# Unanswered question 17562 will receive score 0.
# Unanswered question 17563 will receive score 0.
# Unanswered question 17564 will receive score 0.
# Unanswered question 17565 will receive score 0.
# Unanswered question 17566 will receive score 0.
# Unanswered question 17567 will receive score 0.
# Unanswered question 17568 will receive score 0.
# Unanswered question 17569 will receive score 0.
# Unanswered question 17570 will receive score 0.
# Unanswered question 17571 will receive score 0.
# Unanswered question 17572 will receive score 0.
# Unanswered question 17573 will receive score 0.
# Unanswered question 17574 will receive score 0.
# Unanswered question 17575 will receive score 0.
# Unanswered question 17576 will receive score 0.
# Unanswered question 17577 will receive score 0.
# Unanswered question 11079 will receive score 0.
# Unanswered question 11080 will receive score 0.
# Unanswered question 11081 will receive score 0.
# Unanswered question 11082 will receive score 0.
# Unanswered question 11083 will receive score 0.
# Unanswered question 11084 will receive score 0.
# Unanswered question 11085 will receive score 0.
# Unanswered question 11086 will receive score 0.
# Unanswered question 11087 will receive score 0.
# Unanswered question 11088 will receive score 0.
# Unanswered question 11089 will receive score 0.
# Unanswered question 11090 will receive score 0.
# Unanswered question 11091 will receive score 0.
# Unanswered question 11092 will receive score 0.
# Unanswered question 11093 will receive score 0.
# Unanswered question 11094 will receive score 0.
# Unanswered question 11095 will receive score 0.
# Unanswered question 11096 will receive score 0.
# Unanswered question 11097 will receive score 0.
# Unanswered question 11098 will receive score 0.
# Unanswered question 11099 will receive score 0.
# Unanswered question 11100 will receive score 0.
# Unanswered question 11101 will receive score 0.
# Unanswered question 11102 will receive score 0.
# Unanswered question 11103 will receive score 0.
# Unanswered question 11104 will receive score 0.
# Unanswered question 11105 will receive score 0.
# Unanswered question 11106 will receive score 0.
# Unanswered question 11107 will receive score 0.
# Unanswered question 11108 will receive score 0.
# Unanswered question 11109 will receive score 0.
# Unanswered question 11110 will receive score 0.
# Unanswered question 11111 will receive score 0.
# Unanswered question 11112 will receive score 0.
# Unanswered question 11113 will receive score 0.
# Unanswered question 11114 will receive score 0.
# Unanswered question 11115 will receive score 0.
# Unanswered question 11116 will receive score 0.
# Unanswered question 11117 will receive score 0.
# Unanswered question 11118 will receive score 0.
# Unanswered question 11119 will receive score 0.
# Unanswered question 11120 will receive score 0.
# Unanswered question 11121 will receive score 0.
# Unanswered question 11122 will receive score 0.
# Unanswered question 11123 will receive score 0.
# Unanswered question 11124 will receive score 0.
# Unanswered question 11125 will receive score 0.
# Unanswered question 11126 will receive score 0.
# Unanswered question 11127 will receive score 0.
# Unanswered question 11128 will receive score 0.
# Unanswered question 11129 will receive score 0.
# Unanswered question 11130 will receive score 0.
# Unanswered question 11131 will receive score 0.
# Unanswered question 11132 will receive score 0.
# Unanswered question 11133 will receive score 0.
# Unanswered question 11134 will receive score 0.
# Unanswered question 11135 will receive score 0.
# Unanswered question 11136 will receive score 0.
# Unanswered question 11137 will receive score 0.
# Unanswered question 11138 will receive score 0.
# Unanswered question 11139 will receive score 0.
# Unanswered question 11140 will receive score 0.
# Unanswered question 11141 will receive score 0.
# Unanswered question 11142 will receive score 0.
# Unanswered question 11143 will receive score 0.
# Unanswered question 11144 will receive score 0.
# Unanswered question 11145 will receive score 0.
# Unanswered question 11146 will receive score 0.
# Unanswered question 11147 will receive score 0.
# Unanswered question 11148 will receive score 0.
# Unanswered question 11149 will receive score 0.
# Unanswered question 11150 will receive score 0.
# Unanswered question 11151 will receive score 0.
# Unanswered question 11152 will receive score 0.
# Unanswered question 11153 will receive score 0.
# Unanswered question 2027 will receive score 0.
# Unanswered question 2028 will receive score 0.
# Unanswered question 2029 will receive score 0.
# Unanswered question 5704 will receive score 0.
# Unanswered question 5705 will receive score 0.
# Unanswered question 5706 will receive score 0.
# Unanswered question 5707 will receive score 0.
# Unanswered question 5708 will receive score 0.
# Unanswered question 5709 will receive score 0.
# Unanswered question 5710 will receive score 0.
# Unanswered question 5711 will receive score 0.
# Unanswered question 5712 will receive score 0.
# Unanswered question 5713 will receive score 0.
# Unanswered question 5714 will receive score 0.
# Unanswered question 5715 will receive score 0.
# Unanswered question 5716 will receive score 0.
# Unanswered question 5717 will receive score 0.
# Unanswered question 5718 will receive score 0.
# Unanswered question 5719 will receive score 0.
# Unanswered question 5720 will receive score 0.
# Unanswered question 5721 will receive score 0.
# Unanswered question 5722 will receive score 0.
# Unanswered question 5723 will receive score 0.
# Unanswered question 5724 will receive score 0.
# Unanswered question 5725 will receive score 0.
# Unanswered question 11549 will receive score 0.
# Unanswered question 11550 will receive score 0.
# Unanswered question 11551 will receive score 0.
# Unanswered question 11552 will receive score 0.
# Unanswered question 11553 will receive score 0.
# Unanswered question 11554 will receive score 0.
# Unanswered question 11555 will receive score 0.
# Unanswered question 11556 will receive score 0.
# Unanswered question 11557 will receive score 0.
# Unanswered question 11558 will receive score 0.
# Unanswered question 11559 will receive score 0.
# Unanswered question 11560 will receive score 0.
# Unanswered question 483 will receive score 0.
# Unanswered question 484 will receive score 0.
# Unanswered question 485 will receive score 0.
# Unanswered question 486 will receive score 0.
# Unanswered question 487 will receive score 0.
# Unanswered question 488 will receive score 0.
# Unanswered question 489 will receive score 0.
# Unanswered question 490 will receive score 0.
# Unanswered question 491 will receive score 0.
# Unanswered question 492 will receive score 0.
# Unanswered question 493 will receive score 0.
# Unanswered question 494 will receive score 0.
# Unanswered question 495 will receive score 0.
# Unanswered question 496 will receive score 0.
# Unanswered question 497 will receive score 0.
# Unanswered question 3413 will receive score 0.
# Unanswered question 3414 will receive score 0.
# Unanswered question 3415 will receive score 0.
# Unanswered question 3416 will receive score 0.
# Unanswered question 3417 will receive score 0.
# Unanswered question 3418 will receive score 0.
# Unanswered question 3419 will receive score 0.
# Unanswered question 3420 will receive score 0.
# Unanswered question 3421 will receive score 0.
# Unanswered question 3422 will receive score 0.
# Unanswered question 3423 will receive score 0.
# Unanswered question 3424 will receive score 0.
# Unanswered question 3425 will receive score 0.
# Unanswered question 3426 will receive score 0.
# Unanswered question 3427 will receive score 0.
# Unanswered question 3428 will receive score 0.
# Unanswered question 9183 will receive score 0.
# Unanswered question 9184 will receive score 0.
# Unanswered question 9185 will receive score 0.
# Unanswered question 9186 will receive score 0.
# Unanswered question 9187 will receive score 0.
# Unanswered question 9188 will receive score 0.
# Unanswered question 9189 will receive score 0.
# Unanswered question 9190 will receive score 0.
# Unanswered question 9191 will receive score 0.
# Unanswered question 9192 will receive score 0.
# Unanswered question 9193 will receive score 0.
# Unanswered question 9194 will receive score 0.
# Unanswered question 9195 will receive score 0.
# Unanswered question 9196 will receive score 0.
# Unanswered question 9197 will receive score 0.
# Unanswered question 9198 will receive score 0.
# Unanswered question 9199 will receive score 0.
# Unanswered question 9200 will receive score 0.
# Unanswered question 9201 will receive score 0.
# Unanswered question 9202 will receive score 0.
# Unanswered question 9203 will receive score 0.
# Unanswered question 9204 will receive score 0.
# Unanswered question 9205 will receive score 0.
# ...
# Unanswered question 15701 will receive score 0.
# Unanswered question 15702 will receive score 0.
# Unanswered question 15703 will receive score 0.
# Unanswered question 15704 will receive score 0.
# Unanswered question 15705 will receive score 0.
# Unanswered question 15706 will receive score 0.
# Unanswered question 15707 will receive score 0.
# Unanswered question 15708 will receive score 0.
# Unanswered question 15709 will receive score 0.
# Unanswered question 15710 will receive score 0.
# Unanswered question 15711 will receive score 0.
# Unanswered question 15712 will receive score 0.
# Unanswered question 15713 will receive score 0.
# Unanswered question 15714 will receive score 0.
# Unanswered question 15715 will receive score 0.
# Unanswered question 15716 will receive score 0.
# Unanswered question 15717 will receive score 0.
# Unanswered question 15718 will receive score 0.
# Unanswered question 15719 will receive score 0.
# Unanswered question 15720 will receive score 0.
# Unanswered question 15721 will receive score 0.
# Unanswered question 15722 will receive score 0.
# Unanswered question 15723 will receive score 0.
# Unanswered question 15724 will receive score 0.
# Unanswered question 15725 will receive score 0.
# Unanswered question 15726 will receive score 0.
# Unanswered question 15727 will receive score 0.
# Unanswered question 15728 will receive score 0.
# Unanswered question 15729 will receive score 0.
# Unanswered question 15730 will receive score 0.
# Unanswered question 15731 will receive score 0.
# Unanswered question 15732 will receive score 0.
# Unanswered question 15733 will receive score 0.
# Unanswered question 15734 will receive score 0.
# Unanswered question 15735 will receive score 0.
# Unanswered question 15736 will receive score 0.
# Unanswered question 15737 will receive score 0.
# Unanswered question 15738 will receive score 0.
# Unanswered question 15739 will receive score 0.
# Unanswered question 15740 will receive score 0.
# Unanswered question 15741 will receive score 0.
# Unanswered question 15742 will receive score 0.
# Unanswered question 15743 will receive score 0.
# Unanswered question 15744 will receive score 0.
# Unanswered question 15745 will receive score 0.
# Unanswered question 15746 will receive score 0.
# Unanswered question 15747 will receive score 0.
# Unanswered question 15748 will receive score 0.
# Unanswered question 15749 will receive score 0.
# Unanswered question 15750 will receive score 0.
# Unanswered question 15751 will receive score 0.
# Unanswered question 15752 will receive score 0.
# Unanswered question 15753 will receive score 0.
# Unanswered question 15754 will receive score 0.
# Unanswered question 15755 will receive score 0.
# Unanswered question 15756 will receive score 0.
# Unanswered question 15757 will receive score 0.
# Unanswered question 15758 will receive score 0.
# Unanswered question 15759 will receive score 0.
# Unanswered question 15760 will receive score 0.
# Unanswered question 15761 will receive score 0.
# Unanswered question 15762 will receive score 0.
# Unanswered question 15763 will receive score 0.
# Unanswered question 15764 will receive score 0.
# Unanswered question 15765 will receive score 0.
# Unanswered question 15766 will receive score 0.
# Unanswered question 15767 will receive score 0.
# Unanswered question 15768 will receive score 0.
# Unanswered question 15769 will receive score 0.
# Unanswered question 15770 will receive score 0.
# Unanswered question 15771 will receive score 0.
# Unanswered question 15772 will receive score 0.
# Unanswered question 15773 will receive score 0.
# Unanswered question 15774 will receive score 0.
# Unanswered question 15775 will receive score 0.
# Unanswered question 15776 will receive score 0.
# Unanswered question 15777 will receive score 0.
# Unanswered question 15778 will receive score 0.
# Unanswered question 15779 will receive score 0.
# Unanswered question 15780 will receive score 0.
# Unanswered question 15781 will receive score 0.
# Unanswered question 15782 will receive score 0.
# Unanswered question 15783 will receive score 0.
# Unanswered question 15784 will receive score 0.
# Unanswered question 15785 will receive score 0.
# Unanswered question 15786 will receive score 0.
# Unanswered question 15787 will receive score 0.
# Unanswered question 11210 will receive score 0.
# Unanswered question 11211 will receive score 0.
# Unanswered question 11212 will receive score 0.
# Unanswered question 11213 will receive score 0.
# Unanswered question 11214 will receive score 0.
# Unanswered question 11215 will receive score 0.
# Unanswered question 11216 will receive score 0.
# Unanswered question 11217 will receive score 0.
# Unanswered question 11218 will receive score 0.
# Unanswered question 11219 will receive score 0.
# Unanswered question 11220 will receive score 0.
# Unanswered question 11221 will receive score 0.
# Unanswered question 11222 will receive score 0.
# Unanswered question 11223 will receive score 0.
# Unanswered question 11224 will receive score 0.
# Unanswered question 11225 will receive score 0.
# Unanswered question 11226 will receive score 0.
# Unanswered question 11227 will receive score 0.
# Unanswered question 11228 will receive score 0.
# Unanswered question 11229 will receive score 0.
# Unanswered question 11230 will receive score 0.
# Unanswered question 11231 will receive score 0.
# Unanswered question 11232 will receive score 0.
# Unanswered question 11233 will receive score 0.
# Unanswered question 11234 will receive score 0.
# Unanswered question 11235 will receive score 0.
# Unanswered question 11236 will receive score 0.
# Unanswered question 11237 will receive score 0.
# Unanswered question 11238 will receive score 0.
# Unanswered question 11239 will receive score 0.
# Unanswered question 11240 will receive score 0.
# Unanswered question 11241 will receive score 0.
# Unanswered question 11242 will receive score 0.
# Unanswered question 11243 will receive score 0.
# Unanswered question 11244 will receive score 0.
# Unanswered question 11245 will receive score 0.
# Unanswered question 11246 will receive score 0.
# Unanswered question 11247 will receive score 0.
# Unanswered question 11248 will receive score 0.
# Unanswered question 11249 will receive score 0.
# Unanswered question 11250 will receive score 0.
# Unanswered question 11251 will receive score 0.
# Unanswered question 11252 will receive score 0.
# Unanswered question 11253 will receive score 0.
# Unanswered question 11254 will receive score 0.
# Unanswered question 11255 will receive score 0.
# Unanswered question 11256 will receive score 0.
# Unanswered question 11257 will receive score 0.
# Unanswered question 11258 will receive score 0.
# Unanswered question 11259 will receive score 0.
# Unanswered question 11260 will receive score 0.
# Unanswered question 11261 will receive score 0.
# Unanswered question 11262 will receive score 0.
# Unanswered question 11263 will receive score 0.
# Unanswered question 11264 will receive score 0.
# Unanswered question 11265 will receive score 0.
# Unanswered question 11266 will receive score 0.
# Unanswered question 11267 will receive score 0.
# Unanswered question 11268 will receive score 0.
# Unanswered question 11269 will receive score 0.
# Unanswered question 11270 will receive score 0.
# Unanswered question 11271 will receive score 0.
# Unanswered question 11272 will receive score 0.
# Unanswered question 11273 will receive score 0.
# Unanswered question 11274 will receive score 0.
# Unanswered question 11275 will receive score 0.
# Unanswered question 11276 will receive score 0.
# Unanswered question 11277 will receive score 0.
# Unanswered question 11278 will receive score 0.
# Unanswered question 11279 will receive score 0.
# Unanswered question 11280 will receive score 0.
# Unanswered question 11281 will receive score 0.
# Unanswered question 11282 will receive score 0.
# Unanswered question 11283 will receive score 0.
# Unanswered question 11284 will receive score 0.
# Unanswered question 11285 will receive score 0.
# Unanswered question 11286 will receive score 0.
# Unanswered question 11287 will receive score 0.
# Unanswered question 11288 will receive score 0.
# Unanswered question 11289 will receive score 0.
# Unanswered question 11290 will receive score 0.
# Unanswered question 11291 will receive score 0.
# Unanswered question 11292 will receive score 0.
# Unanswered question 11293 will receive score 0.
# Unanswered question 11294 will receive score 0.
# Unanswered question 11295 will receive score 0.
# Unanswered question 11296 will receive score 0.
# Unanswered question 11297 will receive score 0.
# Unanswered question 11298 will receive score 0.
# Unanswered question 11299 will receive score 0.
# Unanswered question 11300 will receive score 0.
# Unanswered question 11301 will receive score 0.
# Unanswered question 11302 will receive score 0.
# Unanswered question 11303 will receive score 0.
# Unanswered question 11304 will receive score 0.
# Unanswered question 11305 will receive score 0.
# Unanswered question 11306 will receive score 0.
# Unanswered question 11307 will receive score 0.
# Unanswered question 11308 will receive score 0.
# Unanswered question 11309 will receive score 0.
# Unanswered question 11310 will receive score 0.
# Unanswered question 11311 will receive score 0.
# Unanswered question 11312 will receive score 0.
# Unanswered question 11313 will receive score 0.
# Unanswered question 11314 will receive score 0.
# Unanswered question 11315 will receive score 0.
# Unanswered question 11316 will receive score 0.
# Unanswered question 11317 will receive score 0.
# Unanswered question 11318 will receive score 0.
# Unanswered question 11319 will receive score 0.
# Unanswered question 11320 will receive score 0.
# Unanswered question 11321 will receive score 0.
# Unanswered question 11322 will receive score 0.
# Unanswered question 11323 will receive score 0.
# Unanswered question 11324 will receive score 0.
# Unanswered question 11325 will receive score 0.
# Unanswered question 11326 will receive score 0.
# Unanswered question 11327 will receive score 0.
# Unanswered question 11328 will receive score 0.
# Unanswered question 11329 will receive score 0.
# Unanswered question 11330 will receive score 0.
# Unanswered question 11331 will receive score 0.
# Unanswered question 11332 will receive score 0.
# Unanswered question 11333 will receive score 0.
# Unanswered question 11334 will receive score 0.
# Unanswered question 11335 will receive score 0.
# Unanswered question 11336 will receive score 0.
# Unanswered question 11337 will receive score 0.
# Unanswered question 11338 will receive score 0.
# Unanswered question 11339 will receive score 0.
# Unanswered question 11340 will receive score 0.
# Unanswered question 11341 will receive score 0.
# Unanswered question 11342 will receive score 0.
# Unanswered question 11343 will receive score 0.
# Unanswered question 11344 will receive score 0.
# Unanswered question 11345 will receive score 0.
# Unanswered question 11346 will receive score 0.
# Unanswered question 11347 will receive score 0.
# Unanswered question 11348 will receive score 0.
# Unanswered question 11349 will receive score 0.
# Unanswered question 11350 will receive score 0.
# Unanswered question 11351 will receive score 0.
# Unanswered question 11352 will receive score 0.
# Unanswered question 11353 will receive score 0.
# Unanswered question 11354 will receive score 0.
# Unanswered question 11355 will receive score 0.
# Unanswered question 11356 will receive score 0.
# Unanswered question 11357 will receive score 0.
# Unanswered question 11358 will receive score 0.
# Unanswered question 11359 will receive score 0.
# Unanswered question 11360 will receive score 0.
# Unanswered question 11361 will receive score 0.
# Unanswered question 11362 will receive score 0.
# Unanswered question 11363 will receive score 0.
# Unanswered question 11364 will receive score 0.
# Unanswered question 11365 will receive score 0.
# Unanswered question 11366 will receive score 0.
# Unanswered question 11367 will receive score 0.
# Unanswered question 11368 will receive score 0.
# Unanswered question 11369 will receive score 0.
# Unanswered question 11370 will receive score 0.
# Unanswered question 11371 will receive score 0.
# Unanswered question 11372 will receive score 0.
# Unanswered question 11373 will receive score 0.
# Unanswered question 11374 will receive score 0.
# Unanswered question 11375 will receive score 0.
# Unanswered question 1539 will receive score 0.
# Unanswered question 1540 will receive score 0.
# Unanswered question 1541 will receive score 0.
# Unanswered question 1542 will receive score 0.
# Unanswered question 1543 will receive score 0.
# Unanswered question 1544 will receive score 0.
# Unanswered question 1545 will receive score 0.
# Unanswered question 1546 will receive score 0.
# Unanswered question 1547 will receive score 0.
# Unanswered question 1548 will receive score 0.
# Unanswered question 1549 will receive score 0.
# Unanswered question 14473 will receive score 0.
# Unanswered question 14474 will receive score 0.
# Unanswered question 14475 will receive score 0.
# Unanswered question 14476 will receive score 0.
# Unanswered question 14477 will receive score 0.
# Unanswered question 14478 will receive score 0.
# Unanswered question 14479 will receive score 0.
# Unanswered question 14480 will receive score 0.
# Unanswered question 14481 will receive score 0.
# Unanswered question 14482 will receive score 0.
# Unanswered question 4942 will receive score 0.
# Unanswered question 4943 will receive score 0.
# Unanswered question 4944 will receive score 0.
# Unanswered question 4945 will receive score 0.
# Unanswered question 4946 will receive score 0.
# Unanswered question 4947 will receive score 0.
# Unanswered question 3864 will receive score 0.
# Unanswered question 3865 will receive score 0.
# Unanswered question 3866 will receive score 0.
# Unanswered question 3867 will receive score 0.
# Unanswered question 3868 will receive score 0.
# Unanswered question 3869 will receive score 0.
# Unanswered question 3870 will receive score 0.
# Unanswered question 3871 will receive score 0.
# Unanswered question 3872 will receive score 0.
# Unanswered question 3873 will receive score 0.
# Unanswered question 3874 will receive score 0.
# Unanswered question 3875 will receive score 0.
# Unanswered question 3876 will receive score 0.
# Unanswered question 3877 will receive score 0.
# Unanswered question 3878 will receive score 0.
# Unanswered question 3879 will receive score 0.
# Unanswered question 3880 will receive score 0.
# Unanswered question 3881 will receive score 0.
# Unanswered question 3882 will receive score 0.
# Unanswered question 3883 will receive score 0.
# Unanswered question 3884 will receive score 0.
# Unanswered question 3885 will receive score 0.
# Unanswered question 3886 will receive score 0.
# Unanswered question 3887 will receive score 0.
# Unanswered question 696 will receive score 0.
# Unanswered question 697 will receive score 0.
# Unanswered question 698 will receive score 0.
# Unanswered question 699 will receive score 0.
# Unanswered question 700 will receive score 0.
# Unanswered question 701 will receive score 0.
# Unanswered question 702 will receive score 0.
# Unanswered question 703 will receive score 0.
# Unanswered question 704 will receive score 0.
# Unanswered question 705 will receive score 0.
# Unanswered question 706 will receive score 0.
# Unanswered question 707 will receive score 0.
# Unanswered question 708 will receive score 0.
# Unanswered question 709 will receive score 0.
# Unanswered question 710 will receive score 0.
# Unanswered question 711 will receive score 0.
# Unanswered question 712 will receive score 0.
# Unanswered question 713 will receive score 0.
# Unanswered question 714 will receive score 0.
# Unanswered question 715 will receive score 0.
# Unanswered question 716 will receive score 0.
# Unanswered question 717 will receive score 0.
# Unanswered question 718 will receive score 0.
# total examples 1926, total have answers 0 total have no answers 0
# Exact Match {exact_match}, f1 Score {f1}, Same Sentence {exact_sentence} total {total}
# <class 'dict'>
# {'exact_match': 0.0, 'f1': 0.0, 'exact_sentence': 0.0, 'exact_match_ans': 0, 'f1_ans': 0, 'exact_sentence_ans': 0, 'exact_match_noans': 0, 'f1_noans': 0, 'exact_sentence_noans': 0}

# %%
print(resv1)
# Out:
# {'exact_match': 0.0, 'f1': 0.0, 'exact_sentence': 0.0}

# %%
resv2, resv1 = evaluate(aqad_test_loader,loadedModel,False,None,None )
# Out:
# Unanswered question 16780 will receive score 0.
# Unanswered question 16781 will receive score 0.
# Unanswered question 16782 will receive score 0.
# Unanswered question 16783 will receive score 0.
# Unanswered question 16784 will receive score 0.
# Unanswered question 16785 will receive score 0.
# Unanswered question 16786 will receive score 0.
# Unanswered question 16787 will receive score 0.
# Unanswered question 16788 will receive score 0.
# Unanswered question 16789 will receive score 0.
# Unanswered question 16790 will receive score 0.
# Unanswered question 16791 will receive score 0.
# Unanswered question 16792 will receive score 0.
# Unanswered question 16793 will receive score 0.
# Unanswered question 16794 will receive score 0.
# Unanswered question 16795 will receive score 0.
# Unanswered question 16796 will receive score 0.
# Unanswered question 16797 will receive score 0.
# Unanswered question 16798 will receive score 0.
# Unanswered question 16799 will receive score 0.
# Unanswered question 16800 will receive score 0.
# Unanswered question 16801 will receive score 0.
# Unanswered question 16802 will receive score 0.
# Unanswered question 16803 will receive score 0.
# Unanswered question 16804 will receive score 0.
# Unanswered question 16805 will receive score 0.
# Unanswered question 16806 will receive score 0.
# Unanswered question 16807 will receive score 0.
# Unanswered question 16808 will receive score 0.
# Unanswered question 16809 will receive score 0.
# Unanswered question 16810 will receive score 0.
# Unanswered question 16811 will receive score 0.
# Unanswered question 16812 will receive score 0.
# Unanswered question 16813 will receive score 0.
# Unanswered question 16814 will receive score 0.
# Unanswered question 16815 will receive score 0.
# Unanswered question 16816 will receive score 0.
# Unanswered question 16817 will receive score 0.
# Unanswered question 16818 will receive score 0.
# Unanswered question 16819 will receive score 0.
# Unanswered question 16820 will receive score 0.
# Unanswered question 16821 will receive score 0.
# Unanswered question 16822 will receive score 0.
# Unanswered question 16823 will receive score 0.
# Unanswered question 16824 will receive score 0.
# Unanswered question 16825 will receive score 0.
# Unanswered question 16826 will receive score 0.
# Unanswered question 16827 will receive score 0.
# Unanswered question 16828 will receive score 0.
# Unanswered question 16829 will receive score 0.
# Unanswered question 16830 will receive score 0.
# Unanswered question 16831 will receive score 0.
# Unanswered question 16832 will receive score 0.
# Unanswered question 16833 will receive score 0.
# Unanswered question 16834 will receive score 0.
# Unanswered question 16835 will receive score 0.
# Unanswered question 16836 will receive score 0.
# Unanswered question 16837 will receive score 0.
# Unanswered question 16838 will receive score 0.
# Unanswered question 16839 will receive score 0.
# Unanswered question 16840 will receive score 0.
# Unanswered question 16841 will receive score 0.
# Unanswered question 16842 will receive score 0.
# Unanswered question 16843 will receive score 0.
# Unanswered question 16844 will receive score 0.
# Unanswered question 16845 will receive score 0.
# Unanswered question 16846 will receive score 0.
# Unanswered question 16847 will receive score 0.
# Unanswered question 16848 will receive score 0.
# Unanswered question 16849 will receive score 0.
# Unanswered question 16850 will receive score 0.
# Unanswered question 16851 will receive score 0.
# Unanswered question 16852 will receive score 0.
# Unanswered question 16853 will receive score 0.
# Unanswered question 16854 will receive score 0.
# Unanswered question 16855 will receive score 0.
# Unanswered question 16856 will receive score 0.
# Unanswered question 16857 will receive score 0.
# Unanswered question 16858 will receive score 0.
# Unanswered question 16859 will receive score 0.
# Unanswered question 16860 will receive score 0.
# Unanswered question 16861 will receive score 0.
# Unanswered question 16862 will receive score 0.
# Unanswered question 16863 will receive score 0.
# Unanswered question 16864 will receive score 0.
# Unanswered question 16865 will receive score 0.
# Unanswered question 16866 will receive score 0.
# Unanswered question 16867 will receive score 0.
# Unanswered question 16868 will receive score 0.
# Unanswered question 16869 will receive score 0.
# Unanswered question 16870 will receive score 0.
# Unanswered question 16871 will receive score 0.
# Unanswered question 16872 will receive score 0.
# Unanswered question 16873 will receive score 0.
# Unanswered question 16874 will receive score 0.
# Unanswered question 16875 will receive score 0.
# Unanswered question 16876 will receive score 0.
# Unanswered question 16877 will receive score 0.
# Unanswered question 16878 will receive score 0.
# Unanswered question 16879 will receive score 0.
# Unanswered question 16880 will receive score 0.
# Unanswered question 16881 will receive score 0.
# Unanswered question 16882 will receive score 0.
# Unanswered question 16883 will receive score 0.
# Unanswered question 16884 will receive score 0.
# Unanswered question 16885 will receive score 0.
# Unanswered question 16886 will receive score 0.
# Unanswered question 16887 will receive score 0.
# Unanswered question 16888 will receive score 0.
# Unanswered question 16889 will receive score 0.
# Unanswered question 16890 will receive score 0.
# Unanswered question 16891 will receive score 0.
# Unanswered question 16892 will receive score 0.
# Unanswered question 16893 will receive score 0.
# Unanswered question 16894 will receive score 0.
# Unanswered question 16895 will receive score 0.
# Unanswered question 16896 will receive score 0.
# Unanswered question 16897 will receive score 0.
# Unanswered question 16898 will receive score 0.
# Unanswered question 16899 will receive score 0.
# Unanswered question 16900 will receive score 0.
# Unanswered question 16901 will receive score 0.
# Unanswered question 16902 will receive score 0.
# Unanswered question 16903 will receive score 0.
# Unanswered question 16904 will receive score 0.
# Unanswered question 16905 will receive score 0.
# Unanswered question 16906 will receive score 0.
# Unanswered question 16907 will receive score 0.
# Unanswered question 16908 will receive score 0.
# Unanswered question 16909 will receive score 0.
# Unanswered question 16910 will receive score 0.
# Unanswered question 16911 will receive score 0.
# Unanswered question 16912 will receive score 0.
# Unanswered question 16913 will receive score 0.
# Unanswered question 16914 will receive score 0.
# Unanswered question 16915 will receive score 0.
# Unanswered question 16916 will receive score 0.
# Unanswered question 16917 will receive score 0.
# Unanswered question 16918 will receive score 0.
# Unanswered question 16919 will receive score 0.
# Unanswered question 16920 will receive score 0.
# Unanswered question 16921 will receive score 0.
# Unanswered question 16922 will receive score 0.
# Unanswered question 16923 will receive score 0.
# Unanswered question 16924 will receive score 0.
# Unanswered question 16925 will receive score 0.
# Unanswered question 16926 will receive score 0.
# Unanswered question 16927 will receive score 0.
# Unanswered question 16928 will receive score 0.
# Unanswered question 16929 will receive score 0.
# Unanswered question 16930 will receive score 0.
# Unanswered question 16931 will receive score 0.
# Unanswered question 16932 will receive score 0.
# Unanswered question 16933 will receive score 0.
# Unanswered question 16934 will receive score 0.
# Unanswered question 16935 will receive score 0.
# Unanswered question 16936 will receive score 0.
# Unanswered question 16937 will receive score 0.
# Unanswered question 16938 will receive score 0.
# Unanswered question 16939 will receive score 0.
# Unanswered question 16940 will receive score 0.
# Unanswered question 16941 will receive score 0.
# Unanswered question 16942 will receive score 0.
# Unanswered question 16943 will receive score 0.
# Unanswered question 16944 will receive score 0.
# Unanswered question 16945 will receive score 0.
# Unanswered question 16946 will receive score 0.
# Unanswered question 16947 will receive score 0.
# Unanswered question 16948 will receive score 0.
# Unanswered question 16949 will receive score 0.
# Unanswered question 16950 will receive score 0.
# Unanswered question 16951 will receive score 0.
# Unanswered question 16952 will receive score 0.
# Unanswered question 16953 will receive score 0.
# Unanswered question 16954 will receive score 0.
# Unanswered question 16955 will receive score 0.
# Unanswered question 16956 will receive score 0.
# Unanswered question 16957 will receive score 0.
# Unanswered question 16958 will receive score 0.
# Unanswered question 16959 will receive score 0.
# Unanswered question 16960 will receive score 0.
# Unanswered question 16961 will receive score 0.
# Unanswered question 16962 will receive score 0.
# Unanswered question 16963 will receive score 0.
# Unanswered question 16964 will receive score 0.
# Unanswered question 16965 will receive score 0.
# Unanswered question 16966 will receive score 0.
# Unanswered question 16967 will receive score 0.
# Unanswered question 16968 will receive score 0.
# Unanswered question 16969 will receive score 0.
# Unanswered question 16970 will receive score 0.
# Unanswered question 16971 will receive score 0.
# Unanswered question 16972 will receive score 0.
# Unanswered question 16973 will receive score 0.
# Unanswered question 16974 will receive score 0.
# Unanswered question 16975 will receive score 0.
# Unanswered question 16976 will receive score 0.
# Unanswered question 16977 will receive score 0.
# Unanswered question 16978 will receive score 0.
# Unanswered question 16979 will receive score 0.
# Unanswered question 16980 will receive score 0.
# Unanswered question 16981 will receive score 0.
# Unanswered question 16982 will receive score 0.
# Unanswered question 16983 will receive score 0.
# Unanswered question 16984 will receive score 0.
# Unanswered question 16985 will receive score 0.
# Unanswered question 16986 will receive score 0.
# Unanswered question 16987 will receive score 0.
# Unanswered question 16988 will receive score 0.
# Unanswered question 14695 will receive score 0.
# Unanswered question 14696 will receive score 0.
# Unanswered question 14697 will receive score 0.
# Unanswered question 14698 will receive score 0.
# Unanswered question 14699 will receive score 0.
# Unanswered question 14700 will receive score 0.
# Unanswered question 14701 will receive score 0.
# Unanswered question 14702 will receive score 0.
# Unanswered question 14703 will receive score 0.
# Unanswered question 14704 will receive score 0.
# Unanswered question 14705 will receive score 0.
# Unanswered question 14706 will receive score 0.
# Unanswered question 14707 will receive score 0.
# Unanswered question 14708 will receive score 0.
# Unanswered question 14709 will receive score 0.
# Unanswered question 14710 will receive score 0.
# Unanswered question 14711 will receive score 0.
# Unanswered question 14712 will receive score 0.
# Unanswered question 14713 will receive score 0.
# Unanswered question 14714 will receive score 0.
# Unanswered question 14715 will receive score 0.
# Unanswered question 14716 will receive score 0.
# Unanswered question 14717 will receive score 0.
# Unanswered question 14718 will receive score 0.
# Unanswered question 14719 will receive score 0.
# Unanswered question 14720 will receive score 0.
# Unanswered question 14721 will receive score 0.
# Unanswered question 14722 will receive score 0.
# Unanswered question 14723 will receive score 0.
# Unanswered question 14724 will receive score 0.
# Unanswered question 14725 will receive score 0.
# Unanswered question 14726 will receive score 0.
# Unanswered question 14727 will receive score 0.
# Unanswered question 14728 will receive score 0.
# Unanswered question 14729 will receive score 0.
# Unanswered question 14730 will receive score 0.
# Unanswered question 14731 will receive score 0.
# Unanswered question 14732 will receive score 0.
# Unanswered question 14733 will receive score 0.
# Unanswered question 14734 will receive score 0.
# Unanswered question 14735 will receive score 0.
# Unanswered question 14736 will receive score 0.
# Unanswered question 14737 will receive score 0.
# Unanswered question 14738 will receive score 0.
# Unanswered question 14739 will receive score 0.
# Unanswered question 14740 will receive score 0.
# Unanswered question 14741 will receive score 0.
# Unanswered question 14742 will receive score 0.
# Unanswered question 14743 will receive score 0.
# Unanswered question 14744 will receive score 0.
# Unanswered question 14745 will receive score 0.
# Unanswered question 14746 will receive score 0.
# Unanswered question 14747 will receive score 0.
# Unanswered question 14748 will receive score 0.
# Unanswered question 14749 will receive score 0.
# Unanswered question 14750 will receive score 0.
# Unanswered question 14751 will receive score 0.
# Unanswered question 14752 will receive score 0.
# Unanswered question 14753 will receive score 0.
# Unanswered question 14754 will receive score 0.
# Unanswered question 14755 will receive score 0.
# Unanswered question 14756 will receive score 0.
# Unanswered question 14757 will receive score 0.
# Unanswered question 14758 will receive score 0.
# Unanswered question 14759 will receive score 0.
# Unanswered question 14760 will receive score 0.
# Unanswered question 14761 will receive score 0.
# Unanswered question 14762 will receive score 0.
# Unanswered question 14763 will receive score 0.
# Unanswered question 14764 will receive score 0.
# Unanswered question 14765 will receive score 0.
# Unanswered question 14766 will receive score 0.
# Unanswered question 14767 will receive score 0.
# Unanswered question 14768 will receive score 0.
# Unanswered question 14769 will receive score 0.
# Unanswered question 14770 will receive score 0.
# Unanswered question 14771 will receive score 0.
# Unanswered question 14772 will receive score 0.
# Unanswered question 14773 will receive score 0.
# Unanswered question 14774 will receive score 0.
# Unanswered question 14775 will receive score 0.
# Unanswered question 14776 will receive score 0.
# Unanswered question 14777 will receive score 0.
# Unanswered question 14778 will receive score 0.
# Unanswered question 14779 will receive score 0.
# Unanswered question 14780 will receive score 0.
# Unanswered question 14781 will receive score 0.
# Unanswered question 14782 will receive score 0.
# Unanswered question 14783 will receive score 0.
# Unanswered question 14784 will receive score 0.
# Unanswered question 14785 will receive score 0.
# Unanswered question 14786 will receive score 0.
# Unanswered question 14787 will receive score 0.
# Unanswered question 14788 will receive score 0.
# Unanswered question 14789 will receive score 0.
# Unanswered question 14790 will receive score 0.
# Unanswered question 14791 will receive score 0.
# Unanswered question 14792 will receive score 0.
# Unanswered question 14793 will receive score 0.
# Unanswered question 14794 will receive score 0.
# Unanswered question 14795 will receive score 0.
# Unanswered question 14796 will receive score 0.
# Unanswered question 14797 will receive score 0.
# Unanswered question 14798 will receive score 0.
# Unanswered question 14799 will receive score 0.
# Unanswered question 14800 will receive score 0.
# Unanswered question 14801 will receive score 0.
# Unanswered question 14802 will receive score 0.
# Unanswered question 14803 will receive score 0.
# Unanswered question 14804 will receive score 0.
# Unanswered question 14805 will receive score 0.
# Unanswered question 14806 will receive score 0.
# Unanswered question 14807 will receive score 0.
# Unanswered question 14808 will receive score 0.
# Unanswered question 14809 will receive score 0.
# Unanswered question 14810 will receive score 0.
# Unanswered question 14811 will receive score 0.
# Unanswered question 14812 will receive score 0.
# Unanswered question 14813 will receive score 0.
# Unanswered question 14814 will receive score 0.
# Unanswered question 14815 will receive score 0.
# Unanswered question 14816 will receive score 0.
# Unanswered question 14817 will receive score 0.
# Unanswered question 14818 will receive score 0.
# Unanswered question 14819 will receive score 0.
# Unanswered question 14820 will receive score 0.
# Unanswered question 14821 will receive score 0.
# Unanswered question 14822 will receive score 0.
# Unanswered question 14823 will receive score 0.
# Unanswered question 14824 will receive score 0.
# Unanswered question 14825 will receive score 0.
# Unanswered question 14826 will receive score 0.
# Unanswered question 14827 will receive score 0.
# Unanswered question 14828 will receive score 0.
# Unanswered question 14829 will receive score 0.
# Unanswered question 14830 will receive score 0.
# Unanswered question 14831 will receive score 0.
# Unanswered question 14832 will receive score 0.
# Unanswered question 14833 will receive score 0.
# Unanswered question 14834 will receive score 0.
# Unanswered question 14835 will receive score 0.
# Unanswered question 14836 will receive score 0.
# Unanswered question 14837 will receive score 0.
# Unanswered question 14838 will receive score 0.
# Unanswered question 14839 will receive score 0.
# Unanswered question 14840 will receive score 0.
# Unanswered question 14841 will receive score 0.
# Unanswered question 14842 will receive score 0.
# Unanswered question 14843 will receive score 0.
# Unanswered question 14844 will receive score 0.
# Unanswered question 14845 will receive score 0.
# Unanswered question 14846 will receive score 0.
# Unanswered question 14847 will receive score 0.
# Unanswered question 14848 will receive score 0.
# Unanswered question 14849 will receive score 0.
# Unanswered question 14850 will receive score 0.
# Unanswered question 14851 will receive score 0.
# Unanswered question 14852 will receive score 0.
# Unanswered question 14853 will receive score 0.
# Unanswered question 14854 will receive score 0.
# Unanswered question 14855 will receive score 0.
# Unanswered question 14856 will receive score 0.
# Unanswered question 14857 will receive score 0.
# Unanswered question 14858 will receive score 0.
# Unanswered question 14859 will receive score 0.
# Unanswered question 14860 will receive score 0.
# Unanswered question 14861 will receive score 0.
# Unanswered question 14862 will receive score 0.
# Unanswered question 14863 will receive score 0.
# Unanswered question 14864 will receive score 0.
# Unanswered question 14865 will receive score 0.
# Unanswered question 14866 will receive score 0.
# Unanswered question 14867 will receive score 0.
# Unanswered question 14868 will receive score 0.
# Unanswered question 14869 will receive score 0.
# Unanswered question 14870 will receive score 0.
# Unanswered question 14871 will receive score 0.
# Unanswered question 14872 will receive score 0.
# Unanswered question 14873 will receive score 0.
# Unanswered question 14874 will receive score 0.
# Unanswered question 14875 will receive score 0.
# Unanswered question 14876 will receive score 0.
# Unanswered question 14877 will receive score 0.
# Unanswered question 14878 will receive score 0.
# Unanswered question 14879 will receive score 0.
# Unanswered question 14880 will receive score 0.
# Unanswered question 14881 will receive score 0.
# Unanswered question 14882 will receive score 0.
# Unanswered question 14883 will receive score 0.
# Unanswered question 14884 will receive score 0.
# Unanswered question 14885 will receive score 0.
# Unanswered question 14886 will receive score 0.
# Unanswered question 14887 will receive score 0.
# Unanswered question 14888 will receive score 0.
# Unanswered question 14889 will receive score 0.
# Unanswered question 14890 will receive score 0.
# Unanswered question 14891 will receive score 0.
# Unanswered question 14892 will receive score 0.
# Unanswered question 14893 will receive score 0.
# Unanswered question 14894 will receive score 0.
# Unanswered question 14895 will receive score 0.
# Unanswered question 14896 will receive score 0.
# Unanswered question 14897 will receive score 0.
# Unanswered question 14898 will receive score 0.
# Unanswered question 14899 will receive score 0.
# Unanswered question 14900 will receive score 0.
# Unanswered question 14901 will receive score 0.
# Unanswered question 14902 will receive score 0.
# Unanswered question 14903 will receive score 0.
# Unanswered question 14904 will receive score 0.
# Unanswered question 14905 will receive score 0.
# Unanswered question 14906 will receive score 0.
# Unanswered question 14907 will receive score 0.
# Unanswered question 14908 will receive score 0.
# Unanswered question 14909 will receive score 0.
# Unanswered question 14910 will receive score 0.
# Unanswered question 14911 will receive score 0.
# Unanswered question 14912 will receive score 0.
# Unanswered question 14913 will receive score 0.
# Unanswered question 14914 will receive score 0.
# Unanswered question 14915 will receive score 0.
# Unanswered question 14916 will receive score 0.
# Unanswered question 14917 will receive score 0.
# Unanswered question 14918 will receive score 0.
# Unanswered question 14919 will receive score 0.
# Unanswered question 14920 will receive score 0.
# Unanswered question 14921 will receive score 0.
# Unanswered question 14922 will receive score 0.
# Unanswered question 14923 will receive score 0.
# Unanswered question 14924 will receive score 0.
# Unanswered question 14925 will receive score 0.
# Unanswered question 14926 will receive score 0.
# Unanswered question 14927 will receive score 0.
# Unanswered question 14928 will receive score 0.
# Unanswered question 14929 will receive score 0.
# Unanswered question 14930 will receive score 0.
# Unanswered question 14931 will receive score 0.
# Unanswered question 14932 will receive score 0.
# Unanswered question 14933 will receive score 0.
# Unanswered question 14934 will receive score 0.
# Unanswered question 14935 will receive score 0.
# Unanswered question 14936 will receive score 0.
# Unanswered question 14937 will receive score 0.
# Unanswered question 14938 will receive score 0.
# Unanswered question 14939 will receive score 0.
# Unanswered question 14940 will receive score 0.
# Unanswered question 14941 will receive score 0.
# Unanswered question 5496 will receive score 0.
# Unanswered question 5497 will receive score 0.
# Unanswered question 5498 will receive score 0.
# Unanswered question 5499 will receive score 0.
# Unanswered question 5500 will receive score 0.
# Unanswered question 5501 will receive score 0.
# Unanswered question 5502 will receive score 0.
# Unanswered question 5503 will receive score 0.
# Unanswered question 5504 will receive score 0.
# Unanswered question 5505 will receive score 0.
# Unanswered question 5506 will receive score 0.
# Unanswered question 5507 will receive score 0.
# Unanswered question 5508 will receive score 0.
# Unanswered question 5509 will receive score 0.
# Unanswered question 5510 will receive score 0.
# Unanswered question 5511 will receive score 0.
# Unanswered question 5512 will receive score 0.
# Unanswered question 5513 will receive score 0.
# Unanswered question 5514 will receive score 0.
# Unanswered question 5515 will receive score 0.
# Unanswered question 5516 will receive score 0.
# Unanswered question 5517 will receive score 0.
# Unanswered question 5518 will receive score 0.
# Unanswered question 5519 will receive score 0.
# Unanswered question 5520 will receive score 0.
# Unanswered question 5521 will receive score 0.
# Unanswered question 5522 will receive score 0.
# Unanswered question 5523 will receive score 0.
# Unanswered question 5524 will receive score 0.
# Unanswered question 5525 will receive score 0.
# Unanswered question 5526 will receive score 0.
# Unanswered question 5527 will receive score 0.
# Unanswered question 5528 will receive score 0.
# Unanswered question 5529 will receive score 0.
# Unanswered question 5530 will receive score 0.
# Unanswered question 5531 will receive score 0.
# Unanswered question 5532 will receive score 0.
# Unanswered question 5533 will receive score 0.
# Unanswered question 5534 will receive score 0.
# Unanswered question 5535 will receive score 0.
# Unanswered question 5536 will receive score 0.
# Unanswered question 5537 will receive score 0.
# Unanswered question 5538 will receive score 0.
# Unanswered question 5539 will receive score 0.
# Unanswered question 5540 will receive score 0.
# Unanswered question 5541 will receive score 0.
# Unanswered question 5542 will receive score 0.
# Unanswered question 5543 will receive score 0.
# Unanswered question 5544 will receive score 0.
# Unanswered question 5545 will receive score 0.
# Unanswered question 5546 will receive score 0.
# Unanswered question 5547 will receive score 0.
# Unanswered question 5548 will receive score 0.
# Unanswered question 5549 will receive score 0.
# Unanswered question 5550 will receive score 0.
# Unanswered question 5551 will receive score 0.
# Unanswered question 5552 will receive score 0.
# Unanswered question 5553 will receive score 0.
# Unanswered question 5554 will receive score 0.
# Unanswered question 5555 will receive score 0.
# Unanswered question 5556 will receive score 0.
# Unanswered question 5557 will receive score 0.
# Unanswered question 5558 will receive score 0.
# Unanswered question 5559 will receive score 0.
# Unanswered question 5560 will receive score 0.
# Unanswered question 5561 will receive score 0.
# Unanswered question 5562 will receive score 0.
# Unanswered question 5563 will receive score 0.
# Unanswered question 5564 will receive score 0.
# Unanswered question 5565 will receive score 0.
# Unanswered question 5566 will receive score 0.
# Unanswered question 5567 will receive score 0.
# Unanswered question 5568 will receive score 0.
# Unanswered question 5569 will receive score 0.
# Unanswered question 5570 will receive score 0.
# Unanswered question 5571 will receive score 0.
# Unanswered question 5572 will receive score 0.
# Unanswered question 5573 will receive score 0.
# Unanswered question 5574 will receive score 0.
# Unanswered question 5575 will receive score 0.
# Unanswered question 5576 will receive score 0.
# Unanswered question 5577 will receive score 0.
# Unanswered question 5578 will receive score 0.
# Unanswered question 5579 will receive score 0.
# Unanswered question 5580 will receive score 0.
# Unanswered question 5581 will receive score 0.
# Unanswered question 5582 will receive score 0.
# Unanswered question 5583 will receive score 0.
# Unanswered question 5584 will receive score 0.
# Unanswered question 5585 will receive score 0.
# Unanswered question 5586 will receive score 0.
# Unanswered question 5587 will receive score 0.
# Unanswered question 5588 will receive score 0.
# Unanswered question 5589 will receive score 0.
# Unanswered question 5590 will receive score 0.
# Unanswered question 5591 will receive score 0.
# Unanswered question 5592 will receive score 0.
# Unanswered question 5593 will receive score 0.
# Unanswered question 5594 will receive score 0.
# Unanswered question 5595 will receive score 0.
# Unanswered question 5596 will receive score 0.
# Unanswered question 5597 will receive score 0.
# Unanswered question 5598 will receive score 0.
# Unanswered question 5599 will receive score 0.
# Unanswered question 5600 will receive score 0.
# Unanswered question 5601 will receive score 0.
# Unanswered question 5602 will receive score 0.
# Unanswered question 5603 will receive score 0.
# Unanswered question 5604 will receive score 0.
# Unanswered question 5605 will receive score 0.
# Unanswered question 5606 will receive score 0.
# Unanswered question 5607 will receive score 0.
# Unanswered question 5608 will receive score 0.
# Unanswered question 5609 will receive score 0.
# Unanswered question 5610 will receive score 0.
# Unanswered question 5611 will receive score 0.
# Unanswered question 5612 will receive score 0.
# Unanswered question 5613 will receive score 0.
# Unanswered question 5614 will receive score 0.
# Unanswered question 5615 will receive score 0.
# Unanswered question 5616 will receive score 0.
# Unanswered question 5617 will receive score 0.
# Unanswered question 5618 will receive score 0.
# Unanswered question 5619 will receive score 0.
# Unanswered question 5620 will receive score 0.
# Unanswered question 5621 will receive score 0.
# Unanswered question 5622 will receive score 0.
# Unanswered question 5623 will receive score 0.
# Unanswered question 5624 will receive score 0.
# Unanswered question 5625 will receive score 0.
# Unanswered question 5626 will receive score 0.
# Unanswered question 5627 will receive score 0.
# Unanswered question 5628 will receive score 0.
# Unanswered question 5629 will receive score 0.
# Unanswered question 5630 will receive score 0.
# Unanswered question 5631 will receive score 0.
# Unanswered question 5632 will receive score 0.
# Unanswered question 5633 will receive score 0.
# Unanswered question 5634 will receive score 0.
# Unanswered question 5635 will receive score 0.
# Unanswered question 5636 will receive score 0.
# Unanswered question 5637 will receive score 0.
# Unanswered question 5638 will receive score 0.
# Unanswered question 5639 will receive score 0.
# Unanswered question 5640 will receive score 0.
# Unanswered question 5641 will receive score 0.
# Unanswered question 5642 will receive score 0.
# Unanswered question 5643 will receive score 0.
# Unanswered question 5644 will receive score 0.
# Unanswered question 5645 will receive score 0.
# Unanswered question 5646 will receive score 0.
# Unanswered question 5647 will receive score 0.
# Unanswered question 5648 will receive score 0.
# Unanswered question 5649 will receive score 0.
# Unanswered question 5650 will receive score 0.
# Unanswered question 5651 will receive score 0.
# Unanswered question 5652 will receive score 0.
# Unanswered question 5653 will receive score 0.
# Unanswered question 5654 will receive score 0.
# Unanswered question 5655 will receive score 0.
# Unanswered question 5656 will receive score 0.
# Unanswered question 5657 will receive score 0.
# Unanswered question 5658 will receive score 0.
# Unanswered question 5659 will receive score 0.
# Unanswered question 5660 will receive score 0.
# Unanswered question 5661 will receive score 0.
# Unanswered question 5662 will receive score 0.
# Unanswered question 5663 will receive score 0.
# Unanswered question 5664 will receive score 0.
# Unanswered question 5665 will receive score 0.
# Unanswered question 5666 will receive score 0.
# Unanswered question 5667 will receive score 0.
# Unanswered question 5668 will receive score 0.
# Unanswered question 5669 will receive score 0.
# Unanswered question 5670 will receive score 0.
# Unanswered question 5671 will receive score 0.
# Unanswered question 5672 will receive score 0.
# Unanswered question 5673 will receive score 0.
# Unanswered question 5674 will receive score 0.
# Unanswered question 5675 will receive score 0.
# Unanswered question 5676 will receive score 0.
# Unanswered question 5677 will receive score 0.
# Unanswered question 5678 will receive score 0.
# Unanswered question 5679 will receive score 0.
# Unanswered question 5680 will receive score 0.
# Unanswered question 5681 will receive score 0.
# Unanswered question 5682 will receive score 0.
# Unanswered question 5683 will receive score 0.
# Unanswered question 5684 will receive score 0.
# Unanswered question 5685 will receive score 0.
# Unanswered question 5686 will receive score 0.
# Unanswered question 5687 will receive score 0.
# Unanswered question 5688 will receive score 0.
# Unanswered question 5689 will receive score 0.
# Unanswered question 5690 will receive score 0.
# Unanswered question 5691 will receive score 0.
# Unanswered question 5692 will receive score 0.
# Unanswered question 5693 will receive score 0.
# Unanswered question 5694 will receive score 0.
# Unanswered question 5695 will receive score 0.
# Unanswered question 5696 will receive score 0.
# Unanswered question 17395 will receive score 0.
# Unanswered question 17396 will receive score 0.
# Unanswered question 17397 will receive score 0.
# Unanswered question 17398 will receive score 0.
# Unanswered question 17399 will receive score 0.
# Unanswered question 17400 will receive score 0.
# Unanswered question 17401 will receive score 0.
# Unanswered question 17402 will receive score 0.
# Unanswered question 17403 will receive score 0.
# Unanswered question 17404 will receive score 0.
# Unanswered question 17405 will receive score 0.
# Unanswered question 17406 will receive score 0.
# Unanswered question 17407 will receive score 0.
# Unanswered question 17408 will receive score 0.
# Unanswered question 17409 will receive score 0.
# Unanswered question 17410 will receive score 0.
# Unanswered question 17411 will receive score 0.
# Unanswered question 17412 will receive score 0.
# Unanswered question 17413 will receive score 0.
# Unanswered question 17414 will receive score 0.
# Unanswered question 17415 will receive score 0.
# Unanswered question 17416 will receive score 0.
# Unanswered question 17417 will receive score 0.
# Unanswered question 17418 will receive score 0.
# Unanswered question 17419 will receive score 0.
# Unanswered question 17420 will receive score 0.
# Unanswered question 17421 will receive score 0.
# Unanswered question 17422 will receive score 0.
# Unanswered question 17423 will receive score 0.
# Unanswered question 17424 will receive score 0.
# Unanswered question 17425 will receive score 0.
# Unanswered question 17426 will receive score 0.
# Unanswered question 17427 will receive score 0.
# Unanswered question 17428 will receive score 0.
# Unanswered question 17429 will receive score 0.
# Unanswered question 17430 will receive score 0.
# Unanswered question 17431 will receive score 0.
# Unanswered question 17432 will receive score 0.
# Unanswered question 17433 will receive score 0.
# Unanswered question 17434 will receive score 0.
# Unanswered question 17435 will receive score 0.
# Unanswered question 17436 will receive score 0.
# Unanswered question 17437 will receive score 0.
# Unanswered question 17438 will receive score 0.
# Unanswered question 17439 will receive score 0.
# Unanswered question 17440 will receive score 0.
# Unanswered question 17441 will receive score 0.
# Unanswered question 17442 will receive score 0.
# Unanswered question 17443 will receive score 0.
# Unanswered question 17444 will receive score 0.
# Unanswered question 17445 will receive score 0.
# Unanswered question 17446 will receive score 0.
# Unanswered question 17447 will receive score 0.
# Unanswered question 17448 will receive score 0.
# Unanswered question 17449 will receive score 0.
# Unanswered question 17450 will receive score 0.
# Unanswered question 17451 will receive score 0.
# Unanswered question 17452 will receive score 0.
# Unanswered question 17453 will receive score 0.
# Unanswered question 17454 will receive score 0.
# Unanswered question 17455 will receive score 0.
# Unanswered question 17456 will receive score 0.
# Unanswered question 17457 will receive score 0.
# Unanswered question 17458 will receive score 0.
# Unanswered question 17459 will receive score 0.
# Unanswered question 17460 will receive score 0.
# Unanswered question 17461 will receive score 0.
# Unanswered question 17462 will receive score 0.
# Unanswered question 17463 will receive score 0.
# Unanswered question 17464 will receive score 0.
# Unanswered question 17465 will receive score 0.
# Unanswered question 17466 will receive score 0.
# Unanswered question 17467 will receive score 0.
# Unanswered question 17468 will receive score 0.
# Unanswered question 17469 will receive score 0.
# Unanswered question 17470 will receive score 0.
# Unanswered question 17471 will receive score 0.
# Unanswered question 17472 will receive score 0.
# Unanswered question 17473 will receive score 0.
# Unanswered question 17474 will receive score 0.
# Unanswered question 17475 will receive score 0.
# Unanswered question 17476 will receive score 0.
# Unanswered question 17477 will receive score 0.
# Unanswered question 17478 will receive score 0.
# Unanswered question 17479 will receive score 0.
# Unanswered question 17480 will receive score 0.
# Unanswered question 17481 will receive score 0.
# Unanswered question 17482 will receive score 0.
# Unanswered question 17483 will receive score 0.
# Unanswered question 17484 will receive score 0.
# Unanswered question 17485 will receive score 0.
# Unanswered question 17486 will receive score 0.
# Unanswered question 17487 will receive score 0.
# Unanswered question 17488 will receive score 0.
# Unanswered question 17489 will receive score 0.
# Unanswered question 17490 will receive score 0.
# Unanswered question 17491 will receive score 0.
# Unanswered question 17492 will receive score 0.
# Unanswered question 17493 will receive score 0.
# Unanswered question 17494 will receive score 0.
# Unanswered question 17495 will receive score 0.
# Unanswered question 17496 will receive score 0.
# Unanswered question 17497 will receive score 0.
# Unanswered question 17498 will receive score 0.
# Unanswered question 17499 will receive score 0.
# Unanswered question 17500 will receive score 0.
# Unanswered question 17501 will receive score 0.
# Unanswered question 17502 will receive score 0.
# Unanswered question 17503 will receive score 0.
# Unanswered question 17504 will receive score 0.
# Unanswered question 17505 will receive score 0.
# Unanswered question 17506 will receive score 0.
# Unanswered question 17507 will receive score 0.
# Unanswered question 17508 will receive score 0.
# Unanswered question 17509 will receive score 0.
# Unanswered question 17510 will receive score 0.
# Unanswered question 17511 will receive score 0.
# Unanswered question 17512 will receive score 0.
# Unanswered question 17513 will receive score 0.
# Unanswered question 17514 will receive score 0.
# Unanswered question 17515 will receive score 0.
# Unanswered question 17516 will receive score 0.
# Unanswered question 17517 will receive score 0.
# Unanswered question 17518 will receive score 0.
# Unanswered question 17519 will receive score 0.
# Unanswered question 17520 will receive score 0.
# Unanswered question 17521 will receive score 0.
# Unanswered question 17522 will receive score 0.
# Unanswered question 17523 will receive score 0.
# Unanswered question 17524 will receive score 0.
# Unanswered question 17525 will receive score 0.
# Unanswered question 17526 will receive score 0.
# Unanswered question 17527 will receive score 0.
# Unanswered question 17528 will receive score 0.
# Unanswered question 17529 will receive score 0.
# Unanswered question 17530 will receive score 0.
# Unanswered question 17531 will receive score 0.
# Unanswered question 17532 will receive score 0.
# Unanswered question 17533 will receive score 0.
# Unanswered question 17534 will receive score 0.
# Unanswered question 17535 will receive score 0.
# Unanswered question 17536 will receive score 0.
# Unanswered question 17537 will receive score 0.
# Unanswered question 17538 will receive score 0.
# Unanswered question 17539 will receive score 0.
# Unanswered question 17540 will receive score 0.
# Unanswered question 17541 will receive score 0.
# Unanswered question 17542 will receive score 0.
# Unanswered question 17543 will receive score 0.
# Unanswered question 17544 will receive score 0.
# Unanswered question 17545 will receive score 0.
# Unanswered question 17546 will receive score 0.
# Unanswered question 17547 will receive score 0.
# Unanswered question 17548 will receive score 0.
# Unanswered question 17549 will receive score 0.
# Unanswered question 17550 will receive score 0.
# Unanswered question 17551 will receive score 0.
# Unanswered question 17552 will receive score 0.
# Unanswered question 17553 will receive score 0.
# Unanswered question 17554 will receive score 0.
# Unanswered question 17555 will receive score 0.
# Unanswered question 17556 will receive score 0.
# Unanswered question 17557 will receive score 0.
# Unanswered question 17558 will receive score 0.
# Unanswered question 17559 will receive score 0.
# Unanswered question 17560 will receive score 0.
# Unanswered question 17561 will receive score 0.
# Unanswered question 17562 will receive score 0.
# Unanswered question 17563 will receive score 0.
# Unanswered question 17564 will receive score 0.
# Unanswered question 17565 will receive score 0.
# Unanswered question 17566 will receive score 0.
# Unanswered question 17567 will receive score 0.
# Unanswered question 17568 will receive score 0.
# Unanswered question 17569 will receive score 0.
# Unanswered question 17570 will receive score 0.
# Unanswered question 17571 will receive score 0.
# Unanswered question 17572 will receive score 0.
# Unanswered question 17573 will receive score 0.
# Unanswered question 17574 will receive score 0.
# Unanswered question 17575 will receive score 0.
# Unanswered question 17576 will receive score 0.
# Unanswered question 17577 will receive score 0.
# Unanswered question 11079 will receive score 0.
# Unanswered question 11080 will receive score 0.
# Unanswered question 11081 will receive score 0.
# Unanswered question 11082 will receive score 0.
# Unanswered question 11083 will receive score 0.
# Unanswered question 11084 will receive score 0.
# Unanswered question 11085 will receive score 0.
# Unanswered question 11086 will receive score 0.
# Unanswered question 11087 will receive score 0.
# Unanswered question 11088 will receive score 0.
# Unanswered question 11089 will receive score 0.
# Unanswered question 11090 will receive score 0.
# Unanswered question 11091 will receive score 0.
# Unanswered question 11092 will receive score 0.
# Unanswered question 11093 will receive score 0.
# Unanswered question 11094 will receive score 0.
# Unanswered question 11095 will receive score 0.
# Unanswered question 11096 will receive score 0.
# Unanswered question 11097 will receive score 0.
# Unanswered question 11098 will receive score 0.
# Unanswered question 11099 will receive score 0.
# Unanswered question 11100 will receive score 0.
# Unanswered question 11101 will receive score 0.
# Unanswered question 11102 will receive score 0.
# Unanswered question 11103 will receive score 0.
# Unanswered question 11104 will receive score 0.
# Unanswered question 11105 will receive score 0.
# Unanswered question 11106 will receive score 0.
# Unanswered question 11107 will receive score 0.
# Unanswered question 11108 will receive score 0.
# Unanswered question 11109 will receive score 0.
# Unanswered question 11110 will receive score 0.
# Unanswered question 11111 will receive score 0.
# Unanswered question 11112 will receive score 0.
# Unanswered question 11113 will receive score 0.
# Unanswered question 11114 will receive score 0.
# Unanswered question 11115 will receive score 0.
# Unanswered question 11116 will receive score 0.
# Unanswered question 11117 will receive score 0.
# Unanswered question 11118 will receive score 0.
# Unanswered question 11119 will receive score 0.
# Unanswered question 11120 will receive score 0.
# Unanswered question 11121 will receive score 0.
# Unanswered question 11122 will receive score 0.
# Unanswered question 11123 will receive score 0.
# Unanswered question 11124 will receive score 0.
# Unanswered question 11125 will receive score 0.
# Unanswered question 11126 will receive score 0.
# Unanswered question 11127 will receive score 0.
# Unanswered question 11128 will receive score 0.
# Unanswered question 11129 will receive score 0.
# Unanswered question 11130 will receive score 0.
# Unanswered question 11131 will receive score 0.
# Unanswered question 11132 will receive score 0.
# Unanswered question 11133 will receive score 0.
# Unanswered question 11134 will receive score 0.
# Unanswered question 11135 will receive score 0.
# Unanswered question 11136 will receive score 0.
# Unanswered question 11137 will receive score 0.
# Unanswered question 11138 will receive score 0.
# Unanswered question 11139 will receive score 0.
# Unanswered question 11140 will receive score 0.
# Unanswered question 11141 will receive score 0.
# Unanswered question 11142 will receive score 0.
# Unanswered question 11143 will receive score 0.
# Unanswered question 11144 will receive score 0.
# Unanswered question 11145 will receive score 0.
# Unanswered question 11146 will receive score 0.
# Unanswered question 11147 will receive score 0.
# Unanswered question 11148 will receive score 0.
# Unanswered question 11149 will receive score 0.
# Unanswered question 11150 will receive score 0.
# Unanswered question 11151 will receive score 0.
# Unanswered question 11152 will receive score 0.
# Unanswered question 11153 will receive score 0.
# Unanswered question 2027 will receive score 0.
# Unanswered question 2028 will receive score 0.
# Unanswered question 2029 will receive score 0.
# Unanswered question 5704 will receive score 0.
# Unanswered question 5705 will receive score 0.
# Unanswered question 5706 will receive score 0.
# Unanswered question 5707 will receive score 0.
# Unanswered question 5708 will receive score 0.
# Unanswered question 5709 will receive score 0.
# Unanswered question 5710 will receive score 0.
# Unanswered question 5711 will receive score 0.
# Unanswered question 5712 will receive score 0.
# Unanswered question 5713 will receive score 0.
# Unanswered question 5714 will receive score 0.
# Unanswered question 5715 will receive score 0.
# Unanswered question 5716 will receive score 0.
# Unanswered question 5717 will receive score 0.
# Unanswered question 5718 will receive score 0.
# Unanswered question 5719 will receive score 0.
# Unanswered question 5720 will receive score 0.
# Unanswered question 5721 will receive score 0.
# Unanswered question 5722 will receive score 0.
# Unanswered question 5723 will receive score 0.
# Unanswered question 5724 will receive score 0.
# Unanswered question 5725 will receive score 0.
# Unanswered question 11549 will receive score 0.
# Unanswered question 11550 will receive score 0.
# Unanswered question 11551 will receive score 0.
# Unanswered question 11552 will receive score 0.
# Unanswered question 11553 will receive score 0.
# Unanswered question 11554 will receive score 0.
# Unanswered question 11555 will receive score 0.
# Unanswered question 11556 will receive score 0.
# Unanswered question 11557 will receive score 0.
# Unanswered question 11558 will receive score 0.
# Unanswered question 11559 will receive score 0.
# Unanswered question 11560 will receive score 0.
# Unanswered question 483 will receive score 0.
# Unanswered question 484 will receive score 0.
# Unanswered question 485 will receive score 0.
# Unanswered question 486 will receive score 0.
# Unanswered question 487 will receive score 0.
# Unanswered question 488 will receive score 0.
# Unanswered question 489 will receive score 0.
# Unanswered question 490 will receive score 0.
# Unanswered question 491 will receive score 0.
# Unanswered question 492 will receive score 0.
# Unanswered question 493 will receive score 0.
# Unanswered question 494 will receive score 0.
# Unanswered question 495 will receive score 0.
# Unanswered question 496 will receive score 0.
# Unanswered question 497 will receive score 0.
# Unanswered question 3413 will receive score 0.
# Unanswered question 3414 will receive score 0.
# Unanswered question 3415 will receive score 0.
# Unanswered question 3416 will receive score 0.
# Unanswered question 3417 will receive score 0.
# Unanswered question 3418 will receive score 0.
# Unanswered question 3419 will receive score 0.
# Unanswered question 3420 will receive score 0.
# Unanswered question 3421 will receive score 0.
# Unanswered question 3422 will receive score 0.
# Unanswered question 3423 will receive score 0.
# Unanswered question 3424 will receive score 0.
# Unanswered question 3425 will receive score 0.
# Unanswered question 3426 will receive score 0.
# Unanswered question 3427 will receive score 0.
# Unanswered question 3428 will receive score 0.
# Unanswered question 9183 will receive score 0.
# Unanswered question 9184 will receive score 0.
# Unanswered question 9185 will receive score 0.
# Unanswered question 9186 will receive score 0.
# Unanswered question 9187 will receive score 0.
# Unanswered question 9188 will receive score 0.
# Unanswered question 9189 will receive score 0.
# Unanswered question 9190 will receive score 0.
# Unanswered question 9191 will receive score 0.
# Unanswered question 9192 will receive score 0.
# Unanswered question 9193 will receive score 0.
# Unanswered question 9194 will receive score 0.
# Unanswered question 9195 will receive score 0.
# Unanswered question 9196 will receive score 0.
# Unanswered question 9197 will receive score 0.
# Unanswered question 9198 will receive score 0.
# Unanswered question 9199 will receive score 0.
# Unanswered question 9200 will receive score 0.
# Unanswered question 9201 will receive score 0.
# Unanswered question 9202 will receive score 0.
# Unanswered question 9203 will receive score 0.
# Unanswered question 9204 will receive score 0.
# Unanswered question 9205 will receive score 0.
# ...
# Unanswered question 15701 will receive score 0.
# Unanswered question 15702 will receive score 0.
# Unanswered question 15703 will receive score 0.
# Unanswered question 15704 will receive score 0.
# Unanswered question 15705 will receive score 0.
# Unanswered question 15706 will receive score 0.
# Unanswered question 15707 will receive score 0.
# Unanswered question 15708 will receive score 0.
# Unanswered question 15709 will receive score 0.
# Unanswered question 15710 will receive score 0.
# Unanswered question 15711 will receive score 0.
# Unanswered question 15712 will receive score 0.
# Unanswered question 15713 will receive score 0.
# Unanswered question 15714 will receive score 0.
# Unanswered question 15715 will receive score 0.
# Unanswered question 15716 will receive score 0.
# Unanswered question 15717 will receive score 0.
# Unanswered question 15718 will receive score 0.
# Unanswered question 15719 will receive score 0.
# Unanswered question 15720 will receive score 0.
# Unanswered question 15721 will receive score 0.
# Unanswered question 15722 will receive score 0.
# Unanswered question 15723 will receive score 0.
# Unanswered question 15724 will receive score 0.
# Unanswered question 15725 will receive score 0.
# Unanswered question 15726 will receive score 0.
# Unanswered question 15727 will receive score 0.
# Unanswered question 15728 will receive score 0.
# Unanswered question 15729 will receive score 0.
# Unanswered question 15730 will receive score 0.
# Unanswered question 15731 will receive score 0.
# Unanswered question 15732 will receive score 0.
# Unanswered question 15733 will receive score 0.
# Unanswered question 15734 will receive score 0.
# Unanswered question 15735 will receive score 0.
# Unanswered question 15736 will receive score 0.
# Unanswered question 15737 will receive score 0.
# Unanswered question 15738 will receive score 0.
# Unanswered question 15739 will receive score 0.
# Unanswered question 15740 will receive score 0.
# Unanswered question 15741 will receive score 0.
# Unanswered question 15742 will receive score 0.
# Unanswered question 15743 will receive score 0.
# Unanswered question 15744 will receive score 0.
# Unanswered question 15745 will receive score 0.
# Unanswered question 15746 will receive score 0.
# Unanswered question 15747 will receive score 0.
# Unanswered question 15748 will receive score 0.
# Unanswered question 15749 will receive score 0.
# Unanswered question 15750 will receive score 0.
# Unanswered question 15751 will receive score 0.
# Unanswered question 15752 will receive score 0.
# Unanswered question 15753 will receive score 0.
# Unanswered question 15754 will receive score 0.
# Unanswered question 15755 will receive score 0.
# Unanswered question 15756 will receive score 0.
# Unanswered question 15757 will receive score 0.
# Unanswered question 15758 will receive score 0.
# Unanswered question 15759 will receive score 0.
# Unanswered question 15760 will receive score 0.
# Unanswered question 15761 will receive score 0.
# Unanswered question 15762 will receive score 0.
# Unanswered question 15763 will receive score 0.
# Unanswered question 15764 will receive score 0.
# Unanswered question 15765 will receive score 0.
# Unanswered question 15766 will receive score 0.
# Unanswered question 15767 will receive score 0.
# Unanswered question 15768 will receive score 0.
# Unanswered question 15769 will receive score 0.
# Unanswered question 15770 will receive score 0.
# Unanswered question 15771 will receive score 0.
# Unanswered question 15772 will receive score 0.
# Unanswered question 15773 will receive score 0.
# Unanswered question 15774 will receive score 0.
# Unanswered question 15775 will receive score 0.
# Unanswered question 15776 will receive score 0.
# Unanswered question 15777 will receive score 0.
# Unanswered question 15778 will receive score 0.
# Unanswered question 15779 will receive score 0.
# Unanswered question 15780 will receive score 0.
# Unanswered question 15781 will receive score 0.
# Unanswered question 15782 will receive score 0.
# Unanswered question 15783 will receive score 0.
# Unanswered question 15784 will receive score 0.
# Unanswered question 15785 will receive score 0.
# Unanswered question 15786 will receive score 0.
# Unanswered question 15787 will receive score 0.
# Unanswered question 11210 will receive score 0.
# Unanswered question 11211 will receive score 0.
# Unanswered question 11212 will receive score 0.
# Unanswered question 11213 will receive score 0.
# Unanswered question 11214 will receive score 0.
# Unanswered question 11215 will receive score 0.
# Unanswered question 11216 will receive score 0.
# Unanswered question 11217 will receive score 0.
# Unanswered question 11218 will receive score 0.
# Unanswered question 11219 will receive score 0.
# Unanswered question 11220 will receive score 0.
# Unanswered question 11221 will receive score 0.
# Unanswered question 11222 will receive score 0.
# Unanswered question 11223 will receive score 0.
# Unanswered question 11224 will receive score 0.
# Unanswered question 11225 will receive score 0.
# Unanswered question 11226 will receive score 0.
# Unanswered question 11227 will receive score 0.
# Unanswered question 11228 will receive score 0.
# Unanswered question 11229 will receive score 0.
# Unanswered question 11230 will receive score 0.
# Unanswered question 11231 will receive score 0.
# Unanswered question 11232 will receive score 0.
# Unanswered question 11233 will receive score 0.
# Unanswered question 11234 will receive score 0.
# Unanswered question 11235 will receive score 0.
# Unanswered question 11236 will receive score 0.
# Unanswered question 11237 will receive score 0.
# Unanswered question 11238 will receive score 0.
# Unanswered question 11239 will receive score 0.
# Unanswered question 11240 will receive score 0.
# Unanswered question 11241 will receive score 0.
# Unanswered question 11242 will receive score 0.
# Unanswered question 11243 will receive score 0.
# Unanswered question 11244 will receive score 0.
# Unanswered question 11245 will receive score 0.
# Unanswered question 11246 will receive score 0.
# Unanswered question 11247 will receive score 0.
# Unanswered question 11248 will receive score 0.
# Unanswered question 11249 will receive score 0.
# Unanswered question 11250 will receive score 0.
# Unanswered question 11251 will receive score 0.
# Unanswered question 11252 will receive score 0.
# Unanswered question 11253 will receive score 0.
# Unanswered question 11254 will receive score 0.
# Unanswered question 11255 will receive score 0.
# Unanswered question 11256 will receive score 0.
# Unanswered question 11257 will receive score 0.
# Unanswered question 11258 will receive score 0.
# Unanswered question 11259 will receive score 0.
# Unanswered question 11260 will receive score 0.
# Unanswered question 11261 will receive score 0.
# Unanswered question 11262 will receive score 0.
# Unanswered question 11263 will receive score 0.
# Unanswered question 11264 will receive score 0.
# Unanswered question 11265 will receive score 0.
# Unanswered question 11266 will receive score 0.
# Unanswered question 11267 will receive score 0.
# Unanswered question 11268 will receive score 0.
# Unanswered question 11269 will receive score 0.
# Unanswered question 11270 will receive score 0.
# Unanswered question 11271 will receive score 0.
# Unanswered question 11272 will receive score 0.
# Unanswered question 11273 will receive score 0.
# Unanswered question 11274 will receive score 0.
# Unanswered question 11275 will receive score 0.
# Unanswered question 11276 will receive score 0.
# Unanswered question 11277 will receive score 0.
# Unanswered question 11278 will receive score 0.
# Unanswered question 11279 will receive score 0.
# Unanswered question 11280 will receive score 0.
# Unanswered question 11281 will receive score 0.
# Unanswered question 11282 will receive score 0.
# Unanswered question 11283 will receive score 0.
# Unanswered question 11284 will receive score 0.
# Unanswered question 11285 will receive score 0.
# Unanswered question 11286 will receive score 0.
# Unanswered question 11287 will receive score 0.
# Unanswered question 11288 will receive score 0.
# Unanswered question 11289 will receive score 0.
# Unanswered question 11290 will receive score 0.
# Unanswered question 11291 will receive score 0.
# Unanswered question 11292 will receive score 0.
# Unanswered question 11293 will receive score 0.
# Unanswered question 11294 will receive score 0.
# Unanswered question 11295 will receive score 0.
# Unanswered question 11296 will receive score 0.
# Unanswered question 11297 will receive score 0.
# Unanswered question 11298 will receive score 0.
# Unanswered question 11299 will receive score 0.
# Unanswered question 11300 will receive score 0.
# Unanswered question 11301 will receive score 0.
# Unanswered question 11302 will receive score 0.
# Unanswered question 11303 will receive score 0.
# Unanswered question 11304 will receive score 0.
# Unanswered question 11305 will receive score 0.
# Unanswered question 11306 will receive score 0.
# Unanswered question 11307 will receive score 0.
# Unanswered question 11308 will receive score 0.
# Unanswered question 11309 will receive score 0.
# Unanswered question 11310 will receive score 0.
# Unanswered question 11311 will receive score 0.
# Unanswered question 11312 will receive score 0.
# Unanswered question 11313 will receive score 0.
# Unanswered question 11314 will receive score 0.
# Unanswered question 11315 will receive score 0.
# Unanswered question 11316 will receive score 0.
# Unanswered question 11317 will receive score 0.
# Unanswered question 11318 will receive score 0.
# Unanswered question 11319 will receive score 0.
# Unanswered question 11320 will receive score 0.
# Unanswered question 11321 will receive score 0.
# Unanswered question 11322 will receive score 0.
# Unanswered question 11323 will receive score 0.
# Unanswered question 11324 will receive score 0.
# Unanswered question 11325 will receive score 0.
# Unanswered question 11326 will receive score 0.
# Unanswered question 11327 will receive score 0.
# Unanswered question 11328 will receive score 0.
# Unanswered question 11329 will receive score 0.
# Unanswered question 11330 will receive score 0.
# Unanswered question 11331 will receive score 0.
# Unanswered question 11332 will receive score 0.
# Unanswered question 11333 will receive score 0.
# Unanswered question 11334 will receive score 0.
# Unanswered question 11335 will receive score 0.
# Unanswered question 11336 will receive score 0.
# Unanswered question 11337 will receive score 0.
# Unanswered question 11338 will receive score 0.
# Unanswered question 11339 will receive score 0.
# Unanswered question 11340 will receive score 0.
# Unanswered question 11341 will receive score 0.
# Unanswered question 11342 will receive score 0.
# Unanswered question 11343 will receive score 0.
# Unanswered question 11344 will receive score 0.
# Unanswered question 11345 will receive score 0.
# Unanswered question 11346 will receive score 0.
# Unanswered question 11347 will receive score 0.
# Unanswered question 11348 will receive score 0.
# Unanswered question 11349 will receive score 0.
# Unanswered question 11350 will receive score 0.
# Unanswered question 11351 will receive score 0.
# Unanswered question 11352 will receive score 0.
# Unanswered question 11353 will receive score 0.
# Unanswered question 11354 will receive score 0.
# Unanswered question 11355 will receive score 0.
# Unanswered question 11356 will receive score 0.
# Unanswered question 11357 will receive score 0.
# Unanswered question 11358 will receive score 0.
# Unanswered question 11359 will receive score 0.
# Unanswered question 11360 will receive score 0.
# Unanswered question 11361 will receive score 0.
# Unanswered question 11362 will receive score 0.
# Unanswered question 11363 will receive score 0.
# Unanswered question 11364 will receive score 0.
# Unanswered question 11365 will receive score 0.
# Unanswered question 11366 will receive score 0.
# Unanswered question 11367 will receive score 0.
# Unanswered question 11368 will receive score 0.
# Unanswered question 11369 will receive score 0.
# Unanswered question 11370 will receive score 0.
# Unanswered question 11371 will receive score 0.
# Unanswered question 11372 will receive score 0.
# Unanswered question 11373 will receive score 0.
# Unanswered question 11374 will receive score 0.
# Unanswered question 11375 will receive score 0.
# Unanswered question 1539 will receive score 0.
# Unanswered question 1540 will receive score 0.
# Unanswered question 1541 will receive score 0.
# Unanswered question 1542 will receive score 0.
# Unanswered question 1543 will receive score 0.
# Unanswered question 1544 will receive score 0.
# Unanswered question 1545 will receive score 0.
# Unanswered question 1546 will receive score 0.
# Unanswered question 1547 will receive score 0.
# Unanswered question 1548 will receive score 0.
# Unanswered question 1549 will receive score 0.
# Unanswered question 14473 will receive score 0.
# Unanswered question 14474 will receive score 0.
# Unanswered question 14475 will receive score 0.
# Unanswered question 14476 will receive score 0.
# Unanswered question 14477 will receive score 0.
# Unanswered question 14478 will receive score 0.
# Unanswered question 14479 will receive score 0.
# Unanswered question 14480 will receive score 0.
# Unanswered question 14481 will receive score 0.
# Unanswered question 14482 will receive score 0.
# Unanswered question 4942 will receive score 0.
# Unanswered question 4943 will receive score 0.
# Unanswered question 4944 will receive score 0.
# Unanswered question 4945 will receive score 0.
# Unanswered question 4946 will receive score 0.
# Unanswered question 4947 will receive score 0.
# Unanswered question 3864 will receive score 0.
# Unanswered question 3865 will receive score 0.
# Unanswered question 3866 will receive score 0.
# Unanswered question 3867 will receive score 0.
# Unanswered question 3868 will receive score 0.
# Unanswered question 3869 will receive score 0.
# Unanswered question 3870 will receive score 0.
# Unanswered question 3871 will receive score 0.
# Unanswered question 3872 will receive score 0.
# Unanswered question 3873 will receive score 0.
# Unanswered question 3874 will receive score 0.
# Unanswered question 3875 will receive score 0.
# Unanswered question 3876 will receive score 0.
# Unanswered question 3877 will receive score 0.
# Unanswered question 3878 will receive score 0.
# Unanswered question 3879 will receive score 0.
# Unanswered question 3880 will receive score 0.
# Unanswered question 3881 will receive score 0.
# Unanswered question 3882 will receive score 0.
# Unanswered question 3883 will receive score 0.
# Unanswered question 3884 will receive score 0.
# Unanswered question 3885 will receive score 0.
# Unanswered question 3886 will receive score 0.
# Unanswered question 3887 will receive score 0.
# Unanswered question 696 will receive score 0.
# Unanswered question 697 will receive score 0.
# Unanswered question 698 will receive score 0.
# Unanswered question 699 will receive score 0.
# Unanswered question 700 will receive score 0.
# Unanswered question 701 will receive score 0.
# Unanswered question 702 will receive score 0.
# Unanswered question 703 will receive score 0.
# Unanswered question 704 will receive score 0.
# Unanswered question 705 will receive score 0.
# Unanswered question 706 will receive score 0.
# Unanswered question 707 will receive score 0.
# Unanswered question 708 will receive score 0.
# Unanswered question 709 will receive score 0.
# Unanswered question 710 will receive score 0.
# Unanswered question 711 will receive score 0.
# Unanswered question 712 will receive score 0.
# Unanswered question 713 will receive score 0.
# Unanswered question 714 will receive score 0.
# Unanswered question 715 will receive score 0.
# Unanswered question 716 will receive score 0.
# Unanswered question 717 will receive score 0.
# Unanswered question 718 will receive score 0.
# total examples 1926, total have answers 0 total have no answers 0
# Exact Match {exact_match}, f1 Score {f1}, Same Sentence {exact_sentence} total {total}
# <class 'dict'>
# {'exact_match': 0.0, 'f1': 0.0, 'exact_sentence': 0.0, 'exact_match_ans': 0, 'f1_ans': 0, 'exact_sentence_ans': 0, 'exact_match_noans': 0, 'f1_noans': 0, 'exact_sentence_noans': 0}

# %%
print(resv1)
print(resv2)
# Out:
# {'exact_match': 0.0, 'f1': 0.0, 'exact_sentence': 0.0}
# {'exact_match': 0.0, 'f1': 0.0, 'exact_sentence': 0.0, 'exact_match_ans': 0, 'f1_ans': 0, 'exact_sentence_ans': 0, 'exact_match_noans': 0, 'f1_noans': 0, 'exact_sentence_noans': 0}
